# %%
import re

def convert_google_sheet_url(url):
    pattern = r'https://docs\.google\.com/spreadsheets/d/([a-zA-Z0-9-_]+)(/edit#gid=(\d+)|/edit.*)?'

    replacement = lambda m: f'https://docs.google.com/spreadsheets/d/{m.group(1)}/export?' + (f'gid={m.group(3)}&' if m.group(3) else '') + 'format=csv'

    new_url = re.sub(pattern, replacement, url)

    return new_url

# %%
import pandas as pd

url = 'https://docs.google.com/spreadsheets/d/1CzpQGGeGzVZ0sv-pUm6jfaQ2dB6vecDpXeotMhIpUnQ/edit#gid=0'

new_url = convert_google_sheet_url(url)

print(new_url)
# Out:
# https://docs.google.com/spreadsheets/d/1CzpQGGeGzVZ0sv-pUm6jfaQ2dB6vecDpXeotMhIpUnQ/export?gid=0&format=csv

# %%
df = pd.read_csv(new_url)

df.dropna(subset=['F Group'], inplace=True)

# %%
df
# Out:
#      Entry F Group    Amine/Acid ID                    Amine/Acid SMILES  \
# 1      1.0       H           1{2,0}                                   NC
# 2      2.0       H           1{2,0}                                  NCC
# 3      3.0       H           1{2,0}                                 NCCC
# 4      4.0       H           1{2,0}                                CCCCN
# 5      5.0       H           1{3,0}                               NC1CC1
# ..     ...     ...              ...                                  ...
# 191  171.0     F^F        β-3{13,6}                OC(C1C2(CC2)C1(F)F)=O
# 192  172.0     F^F        δ-3{13,6}                OC(C1C2(CC2(F)F)C1)=O
# 193  173.0     F^F        ε-3{14,6}            O=C(O)C(C1)CC21CC(F)(F)C2
# 194  174.0     F^F    cis-δ-3{15,6}   OC([C@H]1C[C@H]2C(F)(F)[C@H]2C1)=O
# 195  175.0     F^F  trans-δ-3{15,6}  OC([C@@H]1C[C@H]2C(F)(F)[C@H]2C1)=O
#
#        pKa  F Group Weight         Amide ID  \
# 1    10,78             NaN           4{2,0}
# 2    10,75             NaN           4{2,0}
# 3    10,03             NaN           4{2,0}
# 4     10,5             NaN           4{2,0}
# 5     8,76             NaN           4{3,0}
# ..     ...             ...              ...
# 191   3,51             NaN        β-6{13,6}
# 192   3,85             NaN        δ-6{13,6}
# 193   4,35             NaN        ε-6{14,6}
# 194    3,8             NaN    cis-δ-6{15,6}
# 195   3,76             NaN  trans-δ-6{15,6}
#
#                                         Amide SMILES  logP F Group Weight.1  \
# 1                                 CNC(=O)C1=CC=CC=C1  1,03              NaN
# 2                                CCNC(=O)C1=CC=CC=C1  1,31              NaN
# 3                               CCCNC(=O)C1=CC=CC=C1  1,72              NaN
# 4                              CCCCNC(=O)C1=CC=CC=C1  2,23              NaN
# 5                             O=C(NC1CC1)C1=CC=CC=C1  1,29              NaN
# ..                                               ...   ...              ...
# 191                 FC1(F)C(C(=O)NC2=CC=CC=C2)C11CC1  2,42              NaN
# 192                   FC1(F)CC11CC1C(=O)NC1=CC=CC=C1  2,66              NaN
# 193             FC1(F)CC2(CC(C2)C(=O)NC2=CC=CC=C2)C1  2,93              NaN
# 194   FC1(F)[C@H]2C[C@H](C[C@@H]12)C(=O)NC1=CC=CC=C1  2,37              NaN
# 195  FC1(F)[C@H]2C[C@@H](C[C@@H]12)C(=O)NC1=CC=CC=C1  2,88              NaN
#
#     Unnamed: 10
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# ..          ...
# 191         NaN
# 192         NaN
# 193         NaN
# 194         NaN
# 195         NaN
#
# [175 rows x 11 columns]
