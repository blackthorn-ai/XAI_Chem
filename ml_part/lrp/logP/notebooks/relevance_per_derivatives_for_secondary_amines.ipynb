# %% [markdown]
# **Relevances sum and entire fluorine derivatives**

# %%
import pandas as pd

def prepare_data():
    df_main = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\init_data\pKa_Prediction_Starting data_2024.01.25.csv', index_col=0)

    SMILES_to_fgroup = {}
    SMILES_to_identificator = {}
    SMILES_to_cycle_type = {}
    SMILES_to_logP = {}
    for index, row in df_main.iterrows():
        SMILES = row['Amides for LogP']
        if pd.isnull(SMILES):
            continue
        
        SMILES_to_fgroup[SMILES] = row['F group']
        SMILES_to_identificator[SMILES] = row['identificator']
        SMILES_to_cycle_type[SMILES] = row['Framework']
        SMILES_to_logP[SMILES] = row['LogP']
    
    return SMILES_to_fgroup, SMILES_to_identificator, SMILES_to_cycle_type, SMILES_to_logP

# %%
molecules_fluorine_derivatives_relevance = {'FC(F)(F)C12CC(C1)CN2C(=O)C1=CC=CC=C1': 9.01, 'FC(F)(F)C1CCCN1C(=O)C1=CC=CC=C1': 6.69, 'O=C(N1CC2CC1C2)C1=CC=CC=C1': 3.56, 'O=C(N1CCCC1)C1=CC=CC=C1': 6.67, 'CC12CC(C1)CN2C(=O)C1=CC=CC=C1': 5.81, 'FC(F)(F)C12CCC(CN1C(=O)C1=CC=CC=C1)C2': -5.08, 'FC(F)(F)C12CCC(CC1)CN2C(=O)C1=CC=CC=C1': 10.52, 'FC(F)(F)C1CCCCN1C(=O)C1=CC=CC=C1': 7.77, 'O=C(N1CC2CCC1C2)C1=CC=CC=C1': 1.35, 'CC12CCC(CC1)CN2C(=O)C1=CC=CC=C1': 8.54, 'O=C(N1CC2CCC1CC2)C1=CC=CC=C1': 6.84, 'O=C(N1CCCCC1)C1=CC=CC=C1': 7.45, 'FC(F)(F)C12CC(CN1C(=O)C1=CC=CC=C1)CCC2': 0.62, 'O=C(N1CC2CC1CCC2)C1=CC=CC=C1': 4.08, 'CC12CC(CN1C(=O)C1=CC=CC=C1)CCC2': 3.59, 'FC1(F)CC2CC(CN(C2)C(=O)C2=CC=CC=C2)C1': 5.89, 'FC1(F)CC2CN(CC(C1)C2(F)F)C(=O)C1=CC=CC=C1': 4.55, 'FC1(F)C2CCCC1CN(C2)C(=O)C1=CC=CC=C1': 2.05, 'FC1(F)C2COCC1CN(C2)C(=O)C1=CC=CC=C1': -4.65, 'O=C(N1CC2COCC(C2)C1)C1=CC=CC=C1': 5.55, 'FC1(F)C2CCC1CN(C2)C(=O)C1=CC=CC=C1': 1.99, 'O=C(N1CC2CCC(C2)C1)C1=CC=CC=C1': 2.44, 'O=C(N1CCC1)C1=CC=CC=C1': 5.62, 'FC1CN(C1)C(=O)C1=CC=CC=C1': 5.49, 'FC1CCN(C1)C(=O)C1=CC=CC=C1': 4.11, 'FC1(F)CCN(C1)C(=O)C1=CC=CC=C1': -0.24, 'F[C@H]1CN(C[C@H]1F)C(=O)C1=CC=CC=C1': -2.42, 'F[C@@H]1CN(C[C@H]1F)C(=O)C1=CC=CC=C1': 1.4, 'FC1CCCN(C1)C(=O)C1=CC=C
    f_group = SMILES_to_fgroup[SMILES]

    fluorine_groups_amount[f_group] += 1
    fluorine_groups_relevance[f_group] += relevance

fluorine_groups_relevance_average = {}
for fluorine_group in fluorine_groups_relevance.keys():
    fluorine_groups_relevance_average[fluorine_group] = \
        round(fluorine_groups_relevance[fluorine_group] / fluorine_groups_amount[fluorine_group], 2)

# %%
import matplotlib.pyplot as plt

groups = list(fluorine_groups_relevance_average.keys())
values = list(fluorine_groups_relevance_average.values())

plt.plot(groups, values, marker='o', linestyle='-')

for i in range(len(groups)):
    plt.annotate(str(values[i]), (groups[i], values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

plt.xlabel('Fluorine groups')
plt.ylabel('Average relevance')
plt.title('All fluorine derivatives relevance')

plt.ylim(0, 10)
plt.show()

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# **Relevances sum and only fluorine relevances**

# %%
fluorine_groups = ['non-F', 'CHF', 'CH2F', 'gem-CF2', 'CHF2', 'CF3']
fluorine_groups_relevance = {group: 0 for group in fluorine_groups}
fluorine_groups_amount = {group: 0 for group in fluorine_groups}

for SMILES, relevance in molecules_only_fluor_derivatives.items():
    f_group = SMILES_to_fgroup[SMILES]

    fluorine_groups_amount[f_group] += 1
    fluorine_groups_relevance[f_group] += relevance

fluorine_groups_relevance_average = {}
for fluorine_group in fluorine_groups_relevance.keys():
    fluorine_groups_relevance_average[fluorine_group] = \
        round(fluorine_groups_relevance[fluorine_group] / fluorine_groups_amount[fluorine_group], 2)

# %%
import matplotlib.pyplot as plt

groups = list(fluorine_groups_relevance_average.keys())
values = list(fluorine_groups_relevance_average.values())

plt.plot(groups, values, marker='o', linestyle='-')

for i in range(len(groups)):
    plt.annotate(str(values[i]), (groups[i], values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

plt.xlabel('Fluorine groups')
plt.ylabel('Average relevance')
plt.title('Only fluorine relevances')

plt.ylim(-2, 3)
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# -----

# %%
fluorine_groups = ['non-F', 'CHF', 'CH2F', 'gem-CF2', 'CHF2', 'CF3']
fluorine_groups_relevance = {group: 0 for group in fluorine_groups}
fluorine_groups_amount = {group: 0 for group in fluorine_groups}

for SMILES, relevance in molecules_only_atom_in_cycle.items():
    f_group = SMILES_to_fgroup[SMILES]

    fluorine_groups_amount[f_group] += 1
    fluorine_groups_relevance[f_group] += relevance

fluorine_groups_relevance_average = {}
for fluorine_group in fluorine_groups_relevance.keys():
    fluorine_groups_relevance_average[fluorine_group] = \
        round(fluorine_groups_relevance[fluorine_group] / fluorine_groups_amount[fluorine_group], 2)

# %%
import matplotlib.pyplot as plt

groups = list(fluorine_groups_relevance_average.keys())
values = list(fluorine_groups_relevance_average.values())

plt.plot(groups, values, marker='o', linestyle='-')

for i in range(len(groups)):
    plt.annotate(str(values[i]), (groups[i], values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

plt.xlabel('Fluorine groups')
plt.ylabel('Average relevance')
plt.title('Only fluorine relevances')

plt.ylim(-2, 3)
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# Obtain molecule type (alpha, beta, gamma)

# %%
molecules_only_fluor_derivatives = Molecules_all_fluorine_group

# %%
from collections import deque

functional_group_to_smiles = {
    "CF3": "CC(F)(F)F", 
    "CH2F": "CCF", 
    "gem-CF2": "CF", 
    "CHF2": "CC(F)(F)",
    "CHF": "CF",
    "non-F": ""
}

def find_the_closest_nitrogen_atom(
        mol, atom_id: int, 
        atoms_not_to_visit: list = []):

    queue = deque([(atom_id, 0)])

    visited = set()
    
    while queue:
        current_atom, distance = queue.popleft()
        if mol.GetAtomWithIdx(current_atom).GetSymbol().lower() == 'n':
            break

        visited.add(current_atom)
        
        neighbors = []
        for atom in mol.GetAtomWithIdx(current_atom).GetNeighbors():
            if atom.GetSymbol().lower() == 'h':
                continue
            if atom.GetIdx() in atoms_not_to_visit:
                continue
            neighbors.append(atom.GetIdx())
        
        for neighbor in neighbors:
            if neighbor not in visited:
                queue.append((neighbor, distance + 1))
    
    return current_atom, distance

# %%
from rdkit import Chem
import math

smiles_to_distance_to_nitrogen = {}

def is_secondary_amine(mol):
    # find nitrogen atom
    for atom in mol.GetAtoms():
        if atom.GetSymbol().lower() == 'n':
            nitrogen_atom_idx = atom.GetIdx()

    logP_ring_mol = Chem.MolFromSmiles('C1=CC=CC=C1')

    logP_ring_mol_match = list(mol.GetSubstructMatches(logP_ring_mol)[0])

    for atom in mol.GetAtomWithIdx(nitrogen_atom_idx).GetNeighbors():
        if atom.GetIdx() in logP_ring_mol_match:
            return False
    
    return True


for SMILES, relevance in molecules_only_fluor_derivatives.items():
    f_group_smiles = functional_group_to_smiles[SMILES_to_fgroup[SMILES]]

    mol = Chem.MolFromSmiles(SMILES)

    fluorine_deratives_mol = Chem.MolFromSmiles(f_group_smiles)

    derivatives_matches = mol.GetSubstructMatches(fluorine_deratives_mol)
    

    min_distance_to_nitrogen = math.inf
    is_secondary_amine_mol = is_secondary_amine(mol)
    
    for match in derivatives_matches:
        from_atom = match[0]

        target_atom, distance = find_the_closest_nitrogen_atom(mol=mol, atom_id=from_atom)
        
        if distance < min_distance_to_nitrogen:
            min_distance_to_nitrogen = distance

    smiles_to_distance_to_nitrogen[SMILES] = min_distance_to_nitrogen

    if SMILES_to_cycle_type[SMILES] == 'methane' and f_group_smiles == "":
        smiles_to_distance_to_nitrogen[SMILES] = len(mol.GetAtoms()) - 2 - 8

    # print(SMILES, is_secondary_amine_mol)
    if not is_secondary_amine_mol:
        smiles_to_distance_to_nitrogen[SMILES] = math.inf
    # print(SMILES, derivatives_matches, SMILES_to_fgroup[SMILES], min_distance_to_nitrogen)

# %%
smiles_to_distance_to_nitrogen
# Out:
# {'CCC(F)(F)CC(=O)NC1=CC=CC=C1': inf,
#  'FC(F)CCCC(=O)NC1=CC=CC=C1': inf,
#  'CCCCC(=O)NC1=CC=CC=C1': inf,
#  'FC(F)(F)C12CC(C1)CN2C(=O)C1=CC=CC=C1': 1,
#  'FC(F)(F)C1CCCN1C(=O)C1=CC=CC=C1': 1,
#  'O=C(N1CC2CC1C2)C1=CC=CC=C1': inf,
#  'O=C(N1CCCC1)C1=CC=CC=C1': inf,
#  'CC12CC(C1)CN2C(=O)C1=CC=CC=C1': inf,
#  'FC(F)(F)C12CCC(CN1C(=O)C1=CC=CC=C1)C2': 1,
#  'FC(F)(F)C12CCC(CC1)CN2C(=O)C1=CC=CC=C1': 1,
#  'FC(F)(F)C1CCCCN1C(=O)C1=CC=CC=C1': 1,
#  'O=C(N1CC2CCC1C2)C1=CC=CC=C1': inf,
#  'CC12CCC(CC1)CN2C(=O)C1=CC=CC=C1': inf,
#  'O=C(N1CC2CCC1CC2)C1=CC=CC=C1': inf,
#  'O=C(N1CCCCC1)C1=CC=CC=C1': inf,
#  'FC(F)(F)C12CC(CN1C(=O)C1=CC=CC=C1)CCC2': 1,
#  'O=C(N1CC2CC1CCC2)C1=CC=CC=C1': inf,
#  'CC12CC(CN1C(=O)C1=CC=CC=C1)CCC2': inf,
#  'FC1(F)CC2CC(CN(C2)C(=O)C2=CC=CC=C2)C1': 4,
#  'FC1(F)CC2CN(CC(C1)C2(F)F)C(=O)C1=CC=CC=C1': 3,
#  'FC1(F)C2CCCC1CN(C2)C(=O)C1=CC=CC=C1': 3,
#  'FC1(F)C2COCC1CN(C2)C(=O)C1=CC=CC=C1': 3,
#  'O=C(N1CC2COCC(C2)C1)C1=CC=CC=C1': inf,
# ...

# %%
SMILES_to_logP['FC(F)(F)CNC(=O)C1=CC=CC=C1']
# Out:
# 1.76

# %%
cyclobutane = {'H': [0.18]}
cyclopentane = {'H': [0.27]}
cyclohexan = {'H': [0.14]}
methane = {'H': [0.68], 'CF3': [0.44]}

cyclobutane_logP = {'H': [1.13]}
cyclopentane_logP = {'H': [1.19]}
cyclohexan_logP = {'H': [1.39]}
methane_logP = {'H': [1.03], 'CF3': [1.76]}

for SMILES, distance in smiles_to_distance_to_nitrogen.items():
    
    if distance != 1:
        continue
    
    if 'cyclohexane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclohexan:
            cyclohexan[f_group].append(molecules_only_fluor_derivatives[SMILES])
            cyclohexan_logP[f_group].append(SMILES_to_logP[SMILES])
        else:
            cyclohexan[f_group] = [molecules_only_fluor_derivatives[SMILES]]
            cyclohexan_logP[f_group] = [SMILES_to_logP[SMILES]]

    elif 'cyclopentane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclopentane:
            cyclopentane[f_group].append(molecules_only_fluor_derivatives[SMILES])
            cyclopentane_logP[f_group].append(SMILES_to_logP[SMILES])
        else:
            cyclopentane[f_group] = [molecules_only_fluor_derivatives[SMILES]]
            cyclopentane_logP[f_group] = [SMILES_to_logP[SMILES]]

    elif 'cyclobutane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclobutane:
            cyclobutane[f_group].append(molecules_only_fluor_derivatives[SMILES])
            cyclobutane_logP[f_group].append(SMILES_to_logP[SMILES])
        else:
            cyclobutane[f_group] = [molecules_only_fluor_derivatives[SMILES]]
            cyclobutane_logP[f_group] = [SMILES_to_logP[SMILES]]
    
    elif 'methane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group == 'non-F':
            continue
        if f_group in methane:
            methane[f_group].append(molecules_only_fluor_derivatives[SMILES])
            methane_logP[f_group].append(SMILES_to_logP[SMILES])
        else:
            methane[f_group] = [molecules_only_fluor_derivatives[SMILES]]
            methane_logP[f_group] = [SMILES_to_logP[SMILES]]
        
        # print("methane", SMILES, molecules_only_fluor_derivatives[SMILES], f_group)

# %%
fluorine_groups = ['H', 'CH2F', 'CHF2', 'CF3',]
fluorine_groups_for_plot = ['H', 'CH2F', 'gem-CF2', 'CHF2', 'CF3',]
cyclopentane_values = [sum(cyclopentane[fluorine_group]) for fluorine_group in fluorine_groups]
cyclohexan_values = [sum(cyclohexan[fluorine_group]) for fluorine_group in fluorine_groups]
cyclobutane_values = [sum(cyclobutane[fluorine_group]) for fluorine_group in fluorine_groups]
methane_values = [sum(methane[fluorine_group]) for fluorine_group in fluorine_groups]

cyclopentane_logP_values = [sum(cyclopentane_logP[fluorine_group]) for fluorine_group in fluorine_groups]
cyclohexan_logP_values = [sum(cyclohexan_logP[fluorine_group]) for fluorine_group in fluorine_groups]
cyclobutane_logP_values = [sum(cyclobutane_logP[fluorine_group]) for fluorine_group in fluorine_groups]
methane_logP_values = [sum(methane_logP[fluorine_group]) for fluorine_group in fluorine_groups]

# %%
# fluorine_groups = ['H', 'CH2F', 'gem-CF2', 'CHF2', 'CF3',]
# cyclopentane_values = [sum(cyclopentane[fluorine_group]) if fluorine_group in cyclopentane  else None for fluorine_group in fluorine_groups]
# cyclohexan_values = [sum(cyclohexan[fluorine_group]) if fluorine_group in cyclohexan  else None for fluorine_group in fluorine_groups]
# cyclobutane_values = [sum(cyclobutane[fluorine_group]) if fluorine_group in cyclobutane  else None  for fluorine_group in fluorine_groups]
# methane_values = [sum(methane[fluorine_group]) if fluorine_group in methane  else None   for fluorine_group in fluorine_groups]

# cyclopentane_logP_values = [sum(cyclopentane_logP[fluorine_group]) if fluorine_group in cyclopentane_logP  else None for fluorine_group in fluorine_groups]
# cyclohexan_logP_values = [sum(cyclohexan_logP[fluorine_group]) if fluorine_group in cyclohexan_logP  else None for fluorine_group in fluorine_groups]
# cyclobutane_logP_values = [sum(cyclobutane_logP[fluorine_group]) if fluorine_group in cyclobutane_logP  else None for fluorine_group in fluorine_groups]
# methane_logP_values = [sum(methane_logP[fluorine_group]) if fluorine_group in methane_logP  else None for fluorine_group in fluorine_groups]

# %%
import matplotlib.pyplot as plt

plt.plot(fluorine_groups, cyclopentane_values, marker='o', linestyle='-', color="plum", label="cyclopentane")
plt.plot(fluorine_groups, cyclohexan_values, marker='o', linestyle='-', color="turquoise", label="cyclohexan")
plt.plot(fluorine_groups, cyclobutane_values, marker='o', linestyle='-', color="indigo", label="cyclobutane")
plt.plot(fluorine_groups, methane_values, marker='o', linestyle='-', color="grey", label="methane")

for i in range(len(fluorine_groups)):
    plt.annotate(str(cyclopentane_values[i]), (fluorine_groups[i], cyclopentane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    plt.annotate(str(cyclohexan_values[i]), (fluorine_groups[i], cyclohexan_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    plt.annotate(str(cyclobutane_values[i]), (fluorine_groups[i], cyclobutane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    plt.annotate(f"{str(methane_values[i])}", (fluorine_groups[i], methane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

plt.xlabel('Fluorine groups')
plt.ylabel('Average relevance')
plt.title('Only fluorine relevances with distance to N = 1')

plt.ylim(-1, 2.2)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(12, 5))

ax1.plot(fluorine_groups, cyclopentane_logP_values, marker='o', linestyle='-', color="plum", label="cyclopentane")
ax1.plot(fluorine_groups, cyclohexan_logP_values, marker='o', linestyle='-', color="turquoise", label="cyclohexan")
ax1.plot(fluorine_groups, cyclobutane_logP_values, marker='o', linestyle='-', color="indigo", label="cyclobutane")
ax1.plot(fluorine_groups, methane_logP_values, marker='o', linestyle='-', color="grey", label="methane")

for i in range(len(fluorine_groups)):
    ax1.annotate(str(cyclopentane_logP_values[i]), (fluorine_groups[i], cyclopentane_logP_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    ax1.annotate(str(cyclohexan_logP_values[i]), (fluorine_groups[i], cyclohexan_logP_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    ax1.annotate(str(cyclobutane_logP_values[i]), (fluorine_groups[i], cyclobutane_logP_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    ax1.annotate(f"{str(methane_logP_values[i])}", (fluorine_groups[i], methane_logP_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

ax1.set_xlabel('Fluorine groups')
ax1.set_ylabel('logP')
ax1.set_title('logP')

ax1.set_ylim(0.5, 3)
ax1.legend()
# ------------------------------------------------
ax2.plot(fluorine_groups, cyclopentane_values, marker='o', linestyle='-', color="plum", label="cyclopentane")
ax2.plot(fluorine_groups, cyclohexan_values, marker='o', linestyle='-', color="turquoise", label="cyclohexan")
ax2.plot(fluorine_groups, cyclobutane_values, marker='o', linestyle='-', color="indigo", label="cyclobutane")
ax2.plot(fluorine_groups, methane_values, marker='o', linestyle='-', color="grey", label="methane")

for i in range(len(fluorine_groups)):
    ax2.annotate(str(cyclopentane_values[i]), (fluorine_groups[i], cyclopentane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    ax2.annotate(str(cyclohexan_values[i]), (fluorine_groups[i], cyclohexan_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    ax2.annotate(str(cyclobutane_values[i]), (fluorine_groups[i], cyclobutane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    ax2.annotate(f"{str(methane_values[i])}", (fluorine_groups[i], methane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

ax2.set_xlabel('Fluorine groups')
ax2.set_ylabel('Average relevance')
ax2.set_title('Relevance')

ax2.set_ylim(-1, 1)
ax2.legend()

plt.show()

# %%
cyclobutane = {'H': [0.53]}
cyclopentane = {'H': [0.62]}
cyclohexan = {'H': [0.53]}
methane = {'H': [-0.03]}

cyclobutane_logP = {'H': [1.13]}
cyclopentane_logP = {'H': [1.19]}
cyclohexan_logP = {'H': [1.39]}
methane_logP = {'H': [1.31]}

for SMILES, distance in smiles_to_distance_to_nitrogen.items():
    
    if distance != 2:
        continue
    
    if 'cyclohexane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclohexan:
            cyclohexan[f_group].append(molecules_only_fluor_derivatives[SMILES])
            cyclohexan_logP[f_group].append(SMILES_to_logP[SMILES])
        else:
            cyclohexan[f_group] = [molecules_only_fluor_derivatives[SMILES]]
            cyclohexan_logP[f_group] = [SMILES_to_logP[SMILES]]

    elif 'cyclopentane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclopentane:
            cyclopentane[f_group].append(molecules_only_fluor_derivatives[SMILES])
            cyclopentane_logP[f_group].append(SMILES_to_logP[SMILES])
        else:
            cyclopentane[f_group] = [molecules_only_fluor_derivatives[SMILES]]
            cyclopentane_logP[f_group] = [SMILES_to_logP[SMILES]]

    elif 'cyclobutane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclobutane:
            cyclobutane[f_group].append(molecules_only_fluor_derivatives[SMILES])
            cyclobutane_logP[f_group].append(SMILES_to_logP[SMILES])
        else:
            cyclobutane[f_group] = [molecules_only_fluor_derivatives[SMILES]]
            cyclobutane_logP[f_group] = [SMILES_to_logP[SMILES]]
    
    elif 'methane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group == 'non-F':
            continue
        if f_group in methane:
            methane[f_group].append(molecules_only_fluor_derivatives[SMILES])
            methane_logP[f_group].append(SMILES_to_logP[SMILES])
        else:
            methane[f_group] = [molecules_only_fluor_derivatives[SMILES]]
            methane_logP[f_group] = [SMILES_to_logP[SMILES]]

# %%
fluorine_groups = ['H', 'CH2F', 'gem-CF2', 'CHF2', 'CF3', 'CHF']
fluorine_groups_methane = ['H', 'CH2F', 'gem-CF2', 'CHF2', 'CF3']
cyclopentane_values = [round(sum(cyclopentane[fluorine_group]) / len(cyclopentane[fluorine_group]), 2) for fluorine_group in fluorine_groups]
cyclohexan_values = [round(sum(cyclohexan[fluorine_group]) / len(cyclohexan[fluorine_group]), 2) for fluorine_group in fluorine_groups]
cyclobutane_values = [round(sum(cyclobutane[fluorine_group]) / len(cyclobutane[fluorine_group]), 2) for fluorine_group in fluorine_groups]
methane_values = [round(sum(methane[fluorine_group]) / len(methane[fluorine_group]), 2) for fluorine_group in fluorine_groups_methane]

cyclopentane_logP_values = [sum(cyclopentane_logP[fluorine_group]) for fluorine_group in fluorine_groups]
cyclohexan_logP_values = [sum(cyclohexan_logP[fluorine_group]) for fluorine_group in fluorine_groups]
cyclobutane_logP_values = [sum(cyclobutane_logP[fluorine_group]) for fluorine_group in fluorine_groups]
methane_logP_values = [sum(methane_logP[fluorine_group]) for fluorine_group in fluorine_groups_methane]

# %%
import matplotlib.pyplot as plt

plt.plot(fluorine_groups, cyclopentane_values, marker='o', linestyle='-', color="darkorange", label="cyclopentane")
plt.plot(fluorine_groups, cyclohexan_values, marker='o', linestyle='-', color="gold", label="cyclohexan")
plt.plot(fluorine_groups, cyclobutane_values, marker='o', linestyle='-', color="deeppink", label="cyclobutane")
plt.plot(fluorine_groups_methane, methane_values, marker='o', linestyle='-', color="tan", label="methane")

for i in range(len(fluorine_groups)):
    plt.annotate(f"{str(cyclopentane_values[i])}", (fluorine_groups[i], cyclopentane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    plt.annotate(f"{str(cyclohexan_values[i])}", (fluorine_groups[i], cyclohexan_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    plt.annotate(f"{str(cyclobutane_values[i])}", (fluorine_groups[i], cyclobutane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

for i in range(len(fluorine_groups_methane)):
    plt.annotate(f"{str(methane_values[i])}", (fluorine_groups_methane[i], methane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

plt.xlabel('Fluorine groups')
plt.ylabel('Average relevance')
plt.title('Only fluorine relevances with distance to N = 2')

plt.ylim(-1, 2)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(12, 5))

ax1.plot(fluorine_groups, cyclopentane_logP_values, marker='o', linestyle='-', color="darkorange", label="cyclopentane")
ax1.plot(fluorine_groups, cyclohexan_logP_values, marker='o', linestyle='-', color="gold", label="cyclohexan")
ax1.plot(fluorine_groups, cyclobutane_logP_values, marker='o', linestyle='-', color="deeppink", label="cyclobutane")
ax1.plot(fluorine_groups_methane, methane_logP_values, marker='o', linestyle='-', color="tan", label="methane")

for i in range(len(fluorine_groups)):
    ax1.annotate(str(cyclopentane_logP_values[i]), (fluorine_groups[i], cyclopentane_logP_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    ax1.annotate(str(cyclohexan_logP_values[i]), (fluorine_groups[i], cyclohexan_logP_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    ax1.annotate(str(cyclobutane_logP_values[i]), (fluorine_groups[i], cyclobutane_logP_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
for i in range(len(fluorine_groups_methane)):
    ax1.annotate(f"{str(methane_logP_values[i])}", (fluorine_groups_methane[i], methane_logP_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

ax1.set_xlabel('Fluorine groups')
ax1.set_ylabel('logP')
ax1.set_title('logP')

ax1.set_ylim(0.5, 3)
ax1.legend()
# ------------------------------------------------
ax2.plot(fluorine_groups, cyclopentane_values, marker='o', linestyle='-', color="darkorange", label="cyclopentane")
ax2.plot(fluorine_groups, cyclohexan_values, marker='o', linestyle='-', color="gold", label="cyclohexan")
ax2.plot(fluorine_groups, cyclobutane_values, marker='o', linestyle='-', color="deeppink", label="cyclobutane")
ax2.plot(fluorine_groups_methane, methane_values, marker='o', linestyle='-', color="tan", label="methane")

for i in range(len(fluorine_groups)):
    ax2.annotate(str(cyclopentane_values[i]), (fluorine_groups[i], cyclopentane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    ax2.annotate(str(cyclohexan_values[i]), (fluorine_groups[i], cyclohexan_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    ax2.annotate(str(cyclobutane_values[i]), (fluorine_groups[i], cyclobutane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
for i in range(len(fluorine_groups_methane)):
    ax2.annotate(f"{str(methane_values[i])}", (fluorine_groups_methane[i], methane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

ax2.set_xlabel('Fluorine groups')
ax2.set_ylabel('Average relevance')
ax2.set_title('Relevance')

ax2.set_ylim(-1, 1.5)
ax2.legend()

plt.show()

# %%
cyclohexan = {'H': [0.58]}
methane = {'H': [-0.17]}

cyclohexan_logP = {'H': [1.39]}
methane_logP = {'H': [1.72]}

for SMILES, distance in smiles_to_distance_to_nitrogen.items():
    
    if distance != 3:
        continue
    
    if 'cyclohexane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclohexan:
            cyclohexan[f_group].append(molecules_only_fluor_derivatives[SMILES])
            cyclohexan_logP[f_group].append(SMILES_to_logP[SMILES])
        else:
            cyclohexan[f_group] = [molecules_only_fluor_derivatives[SMILES]]
            cyclohexan_logP[f_group] = [SMILES_to_logP[SMILES]]

    elif 'cyclopentane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclopentane:
            cyclopentane[f_group].append(molecules_only_fluor_derivatives[SMILES])
            cyclopentane_logP[f_group].append(SMILES_to_logP[SMILES])
        else:
            cyclopentane[f_group] = [molecules_only_fluor_derivatives[SMILES]]
            cyclopentane_logP[f_group] = [SMILES_to_logP[SMILES]]

    elif 'cyclobutane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclobutane:
            cyclobutane[f_group].append(molecules_only_fluor_derivatives[SMILES])
            cyclobutane_logP[f_group].append(SMILES_to_logP[SMILES])
        else:
            cyclobutane[f_group] = [molecules_only_fluor_derivatives[SMILES]]
            cyclobutane_logP[f_group] = [SMILES_to_logP[SMILES]]
    
    elif 'methane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group == 'non-F':
            continue
        if f_group in methane:
            methane[f_group].append(molecules_only_fluor_derivatives[SMILES])
            methane_logP[f_group].append(SMILES_to_logP[SMILES])
        else:
            methane[f_group] = [molecules_only_fluor_derivatives[SMILES]]
            methane_logP[f_group] = [SMILES_to_logP[SMILES]]

# %%
fluorine_groups = ['H', 'CH2F', 'gem-CF2', 'CHF2', 'CF3']
cyclohexan_values = [round(sum(cyclohexan[fluorine_group]) / len(cyclohexan[fluorine_group]), 2) for fluorine_group in fluorine_groups]
methane_values = [round(sum(methane[fluorine_group]) / len(methane[fluorine_group]), 2) for fluorine_group in fluorine_groups]

cyclohexan_logP_values = [round(sum(cyclohexan_logP[fluorine_group]) / len(cyclohexan_logP[fluorine_group]), 2) for fluorine_group in fluorine_groups]
methane_logP_values = [round(sum(methane_logP[fluorine_group]) / len(methane_logP[fluorine_group]), 2) for fluorine_group in fluorine_groups]

# %%
import matplotlib.pyplot as plt

plt.plot(fluorine_groups, cyclohexan_values, marker='o', linestyle='-', color="seagreen", label="cyclohexan")
plt.plot(fluorine_groups, methane_values, marker='o', linestyle='-', color="sienna", label="methane")

for i in range(len(fluorine_groups)):
    plt.annotate(f"{str(cyclohexan_values[i])}", (fluorine_groups[i], cyclohexan_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    plt.annotate(f"{str(methane_values[i])}", (fluorine_groups[i], methane_values[i]), xytext=(0, 7), textcoords='offset points', ha='center')

plt.xlabel('Fluorine groups')
plt.ylabel('Average relevance')
plt.title('Only fluorine relevances with distance to N = 3')

plt.ylim(-1, 2)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(12, 5))

ax1.plot(fluorine_groups, cyclohexan_logP_values, marker='o', linestyle='-', color="seagreen", label="cyclohexan")
ax1.plot(fluorine_groups, methane_logP_values, marker='o', linestyle='-', color="sienna", label="methane")

for i in range(len(fluorine_groups)):
    ax1.annotate(f"{str(cyclohexan_logP_values[i])}", (fluorine_groups[i], cyclohexan_logP_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    ax1.annotate(f"{str(methane_logP_values[i])}", (fluorine_groups[i], methane_logP_values[i]), xytext=(0, 7), textcoords='offset points', ha='center')

ax1.set_xlabel('Fluorine groups')
ax1.set_ylabel('logP')
ax1.set_title('logP')

ax1.set_ylim(0.5, 3)
ax1.legend()
# ------------------------------------------------
ax2.plot(fluorine_groups, cyclohexan_values, marker='o', linestyle='-', color="seagreen", label="cyclohexan")
ax2.plot(fluorine_groups, methane_values, marker='o', linestyle='-', color="sienna", label="methane")

for i in range(len(fluorine_groups)):
    ax2.annotate(f"{str(cyclohexan_values[i])}", (fluorine_groups[i], cyclohexan_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    ax2.annotate(f"{str(methane_values[i])}", (fluorine_groups[i], methane_values[i]), xytext=(0, 7), textcoords='offset points', ha='center')

ax2.set_xlabel('Fluorine groups')
ax2.set_ylabel('Average relevance')
ax2.set_title('Relevance')

ax2.set_ylim(-1, 1.3)
ax2.legend()

plt.show()

# %%
methane_logP_values
# Out:
# [1.72, 1.56, 1.81, 3.52, 2.28]

# %%
max(list(SMILES_to_logP.values()))
# Out:
# 3.27

# %%
SMILES_to_logP['[H]C(F)(F)CCNC(=O)C1=CC=CC=C1']
# Out:
# 1.49
