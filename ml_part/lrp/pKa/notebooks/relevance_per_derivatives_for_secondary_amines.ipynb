# %% [markdown]
# **Relevances sum and entire fluorine derivatives**

# %%
import pandas as pd

def prepare_data():
    df_main = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\init_data\pKa_Prediction_Starting data_2024.01.25.csv', index_col=0)

    SMILES_to_fgroup = {}
    SMILES_to_identificator = {}
    SMILES_to_cycle_type = {}
    SMILES_to_pKa = {}
    for index, row in df_main.iterrows():
        SMILES = row['Smiles']
        if pd.isnull(SMILES):
            continue
        
        SMILES_to_fgroup[SMILES] = row['F group']
        SMILES_to_identificator[SMILES] = row['identificator']
        SMILES_to_cycle_type[SMILES] = row['Framework']
        SMILES_to_pKa[SMILES] = row['pKa']
    
    return SMILES_to_fgroup, SMILES_to_identificator, SMILES_to_cycle_type, SMILES_to_pKa

# %% [markdown]
# **Instruction:**
# Uncomment "molecules_fluorine_derivatives_relevance" and "molecules_only_fluor_derivatives" in which experiments you are intrested in.

# %%
# relevance sum with relevances normalization
molecules_fluorine_derivatives_relevance = {'FC(F)(C1(NC2)CC2C1)F': 1.12, 'FC(F)(C1CCCN1)F': 2.94, 'C1CCCN1': 2.06, 'FC(F)(F)C12CCC(C2)CN1': 5.37, 'FC(F)(F)C12CCC(CC2)CN1': 6.53, 'FC(F)(F)C1CCCCN1': 4.57, 'C12CCC(C2)CN1': 1.73, 'CC12CCC(CC2)CN1': 0.55, 'C1CCNCC1': 2.83, 'FC(F)(F)C12CCCC(C2)CN1': 5.15, 'C12CCCC(C2)CN1': 2.05, 'CC12CCCC(C2)CN1': 0.2, 'FC1(F)CC2CC(C1)CNC2': 2.55, 'FC1(F)C2CNCC1CC(F)(F)C2': 6.35, 'FC1(F)C2CNCC1CCC2': 6.94, 'C1(CCC2)CC2CNC1': 1.84, 'FC1(F)C2CNCC1COC2': 5.4, 'C1(COC2)CC2CNC1': 6.23, 'FC1(F)C2CNCC1CC2': 5.04, 'C1(CC2)CC2CNC1': 2.84, 'FC1(F)CCNCC1': 1.22, 'C1CCN1': 0.6, 'FC1CNC1': 2.32, 'FC1(F)CNC1': -0.55, 'C1NCCC1': 2.06, 'FC1CNCC1': 2.7, 'FC1(F)CNCC1': -1.12, 'F[C@H]1CNC[C@H]1F': 1.1, 'FC1CNCCC1': 3.58, 'F[C@@H]1CNC[C@H](F)C1': 1.79, 'F[C@@H]1CNC[C@@H](F)C1': 1.79, 'FC1CCNCC1': 3.47, 'F[C@H]1[C@@H](F)CNCC1': 2.44, 'F[C@H]1[C@H](F)CNCC1': 2.44, 'FC(F)(F)C1NCCCC1': 4.57, 'FC([H])(F)C1NCCCC1': 0.9, '[H]C([H])(F)C1NCCCC1': 4.49, 'C1CNCCC1': 2.83, 'FC(F)(F)C1NCCC1': 2.94, 'FC([H])(F)C1NCCC1': 0.33, '[H]C([H])(F)C1NCCC1': 3.69, 'C1CNCC1': 2.06, 'FC(F)(F)C1NCC1': 0.92, 'FC([
SMILES_to_fgroup, SMILES_to_identificator, SMILES_to_cycle_type, SMILES_to_pKa = prepare_data()

# %%
fluorine_groups = ['non-F', 'CHF', 'CH2F', 'CHF2', 'CF3', 'gem-CF2']
fluorine_groups_relevance = {group: 0 for group in fluorine_groups}
fluorine_groups_amount = {group: 0 for group in fluorine_groups}

for SMILES, relevance in molecules_fluorine_derivatives_relevance.items():
    f_group = SMILES_to_fgroup[SMILES]

    fluorine_groups_amount[f_group] += 1
    fluorine_groups_relevance[f_group] += relevance

fluorine_groups_relevance_average = {}
for fluorine_group in fluorine_groups_relevance.keys():
    fluorine_groups_relevance_average[fluorine_group] = \
        round(fluorine_groups_relevance[fluorine_group] / fluorine_groups_amount[fluorine_group], 2)

# %%
import matplotlib.pyplot as plt

groups = list(fluorine_groups_relevance_average.keys())
values = list(fluorine_groups_relevance_average.values())

plt.plot(groups, values, marker='o', linestyle='-')

for i in range(len(groups)):
    plt.annotate(str(values[i]), (groups[i], values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

plt.xlabel('Fluorine groups')
plt.ylabel('Average relevance')
plt.title('All fluorine derivatives relevance')

plt.ylim(min(values) - 0.5, max(values) + 0.5)
plt.show()

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# **Relevances sum and only fluorine relevances**

# %%
fluorine_groups = ['non-F', 'CHF', 'CH2F', 'CHF2', 'CF3', 'gem-CF2']
fluorine_groups_relevance = {group: 0 for group in fluorine_groups}
fluorine_groups_amount = {group: 0 for group in fluorine_groups}

for SMILES, relevance in molecules_only_fluor_derivatives.items():
    f_group = SMILES_to_fgroup[SMILES]

    fluorine_groups_amount[f_group] += 1
    fluorine_groups_relevance[f_group] += relevance

fluorine_groups_relevance_average = {}
for fluorine_group in fluorine_groups_relevance.keys():
    fluorine_groups_relevance_average[fluorine_group] = \
        round(fluorine_groups_relevance[fluorine_group] / fluorine_groups_amount[fluorine_group], 2)

# %%
import matplotlib.pyplot as plt

groups = list(fluorine_groups_relevance_average.keys())
values = list(fluorine_groups_relevance_average.values())

plt.plot(groups, values, marker='o', linestyle='-')

for i in range(len(groups)):
    plt.annotate(str(values[i]), (groups[i], values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

plt.xlabel('Fluorine groups')
plt.ylabel('Average relevance')
plt.title('Only fluorine relevances')

plt.ylim(min(values) - 0.5, max(values) + 0.5)
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# -----

# %% [markdown]
# ATOM IN CYCLE AND ONE EDGE

# %%
fluorine_groups = ['non-F', 'CHF', 'CH2F', 'CHF2', 'CF3', 'gem-CF2']
fluorine_groups_relevance = {group: 0 for group in fluorine_groups}
fluorine_groups_amount = {group: 0 for group in fluorine_groups}

for SMILES, relevance in molecules_atom_in_cycle_and_edge_to_fluor_relevance.items():
    f_group = SMILES_to_fgroup[SMILES]

    fluorine_groups_amount[f_group] += 1
    fluorine_groups_relevance[f_group] += relevance

fluorine_groups_relevance_average = {}
for fluorine_group in fluorine_groups_relevance.keys():
    fluorine_groups_relevance_average[fluorine_group] = \
        round(fluorine_groups_relevance[fluorine_group] / fluorine_groups_amount[fluorine_group], 2)

# %%
import matplotlib.pyplot as plt

groups = list(fluorine_groups_relevance_average.keys())
values = list(fluorine_groups_relevance_average.values())

plt.plot(groups, values, marker='o', linestyle='-')

for i in range(len(groups)):
    plt.annotate(str(values[i]), (groups[i], values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

plt.xlabel('Fluorine groups')
plt.ylabel('Average relevance')
plt.title('Only fluorine relevances')

plt.ylim(min(values) - 0.5, max(values) + 0.5)
plt.show()

# %% [markdown]
# Obtain molecule type (alpha, beta, gamma)

# %%
# SMILES_to_relevances = molecules_fluorine_derivatives_relevance
# SMILES_to_relevances = molecules_only_fluor_derivatives
SMILES_to_relevances = molecules_atom_in_cycle_and_edge_to_fluor_relevance

# %%
from collections import deque

functional_group_to_smiles = {
    "CF3": "CC(F)(F)F", 
    "CH2F": "CCF", 
    "gem-CF2": "CF", 
    "CHF2": "CC(F)(F)",
    "CHF": "CF",
    "non-F": ""
}

def find_the_closest_nitrogen_atom(
        mol, atom_id: int, 
        atoms_not_to_visit: list = []):

    queue = deque([(atom_id, 0)])

    visited = set()
    
    while queue:
        current_atom, distance = queue.popleft()
        if mol.GetAtomWithIdx(current_atom).GetSymbol().lower() == 'n':
            break

        visited.add(current_atom)
        
        neighbors = []
        for atom in mol.GetAtomWithIdx(current_atom).GetNeighbors():
            if atom.GetSymbol().lower() == 'h':
                continue
            if atom.GetIdx() in atoms_not_to_visit:
                continue
            neighbors.append(atom.GetIdx())
        
        for neighbor in neighbors:
            if neighbor not in visited:
                queue.append((neighbor, distance + 1))
    
    return current_atom, distance

# %%
from rdkit import Chem
import math

smiles_to_distance_to_nitrogen = {}

for SMILES, relevance in SMILES_to_relevances.items():
    mol = Chem.MolFromSmiles(SMILES)

    fluorine_deratives_mol = Chem.MolFromSmiles(functional_group_to_smiles[SMILES_to_fgroup[SMILES]])

    derivatives_matches = mol.GetSubstructMatches(fluorine_deratives_mol)
    

    min_distance_to_nitrogen = math.inf
    for match in derivatives_matches:
        from_atom = match[0]

        target_atom, distance = find_the_closest_nitrogen_atom(mol=mol, atom_id=from_atom)
        if distance < min_distance_to_nitrogen:
            min_distance_to_nitrogen = distance

    smiles_to_distance_to_nitrogen[SMILES] = min_distance_to_nitrogen
    # print(SMILES, derivatives_matches, SMILES_to_fgroup[SMILES], min_distance_to_nitrogen)

# %%
cyclobutane = {}
cyclopentane = {}
cyclohexan = {}

for SMILES, distance in smiles_to_distance_to_nitrogen.items():
    
    if distance != 1:
        continue
    
    if 'cyclohexane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclohexan:
            cyclohexan[f_group].append(SMILES_to_relevances[SMILES])
        else:
            cyclohexan[f_group] = [SMILES_to_relevances[SMILES]]
        print("cyclohexane", SMILES, SMILES_to_relevances[SMILES])

    elif 'cyclopentane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclopentane:
            cyclopentane[f_group].append(SMILES_to_relevances[SMILES])
        else:
            cyclopentane[f_group] = [SMILES_to_relevances[SMILES]]
        print("cyclopentane", SMILES, SMILES_to_relevances[SMILES])

    elif 'cyclobutane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclobutane:
            cyclobutane[f_group].append(SMILES_to_relevances[SMILES])
        else:
            cyclobutane[f_group] = [SMILES_to_relevances[SMILES]]
        print("cyclobutane", SMILES, SMILES_to_relevances[SMILES])
# Out:
# cyclopentane FC(F)(C1CCCN1)F 0.58
# cyclohexane FC(F)(F)C1CCCCN1 0.89
# cyclohexane FC(F)(F)C1NCCCC1 0.89
# cyclohexane FC([H])(F)C1NCCCC1 1.28
# cyclohexane [H]C([H])(F)C1NCCCC1 1.64
# cyclopentane FC(F)(F)C1NCCC1 0.66
# cyclopentane FC([H])(F)C1NCCC1 1.21
# cyclopentane [H]C([H])(F)C1NCCC1 1.63
# cyclobutane FC(F)(F)C1NCC1 0.31
# cyclobutane FC([H])(F)C1NCC1 0.91
# cyclobutane [H]C([H])(F)C1NCC1 1.63

# %%
cyclohexan
# Out:
# {'CF3': [0.89, 0.89], 'CHF2': [1.28], 'CH2F': [1.64]}

# %%
cyclopentane
# Out:
# {'CF3': [0.58, 0.66], 'CHF2': [1.21], 'CH2F': [1.63]}

# %%
cyclobutane
# Out:
# {'CF3': [0.31], 'CHF2': [0.91], 'CH2F': [1.63]}

# %%
fluorine_groups = ['CH2F', 'CHF2', 'CF3']
cyclopentane_values = [round(sum(cyclopentane[fluorine_group]) / len(cyclopentane[fluorine_group]), 2) for fluorine_group in fluorine_groups]
cyclohexan_values = [round(sum(cyclohexan[fluorine_group]) / len(cyclohexan[fluorine_group]), 2) for fluorine_group in fluorine_groups]
cyclobutane_values = [round(sum(cyclobutane[fluorine_group]) / len(cyclobutane[fluorine_group]), 2) for fluorine_group in fluorine_groups]

# %%
import matplotlib.pyplot as plt

combined_values = cyclopentane_values + cyclohexan_values + cyclobutane_values

plt.plot(fluorine_groups, cyclopentane_values, marker='o', linestyle='-', color="plum", label="cyclopentane")
plt.plot(fluorine_groups, cyclohexan_values, marker='o', linestyle='-', color="turquoise", label="cyclohexan")
plt.plot(fluorine_groups, cyclobutane_values, marker='o', linestyle='-', color="indigo", label="cyclobutane")

for i in range(len(fluorine_groups)):
    plt.annotate(str(cyclopentane_values[i]), (fluorine_groups[i], cyclopentane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    plt.annotate(str(cyclohexan_values[i]), (fluorine_groups[i], cyclohexan_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    plt.annotate(str(cyclobutane_values[i]), (fluorine_groups[i], cyclobutane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

plt.xlabel('Fluorine groups')
plt.ylabel('Average relevance')
plt.title('Only fluorine relevances with distance to N = 1')

plt.ylim(min(combined_values) - 0.1, max(combined_values) + 0.1)
# plt.ylim(-2.5, 2)
plt.legend()
plt.show()

# %%
cyclobutane = {}
cyclopentane = {}
cyclohexan = {}

for SMILES, distance in smiles_to_distance_to_nitrogen.items():
    
    if distance != 2:
        continue
    
    if 'cyclohexane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclohexan:
            cyclohexan[f_group].append(SMILES_to_relevances[SMILES])
        else:
            cyclohexan[f_group] = [SMILES_to_relevances[SMILES]]
        # print("cyclohexane", SMILES, SMILES_to_relevances[SMILES], f_group)

    elif 'cyclopentane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclopentane:
            cyclopentane[f_group].append(SMILES_to_relevances[SMILES])
        else:
            cyclopentane[f_group] = [SMILES_to_relevances[SMILES]]
        # print("cyclopentane", SMILES, SMILES_to_relevances[SMILES])

    elif 'cyclobutane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclobutane:
            cyclobutane[f_group].append(SMILES_to_relevances[SMILES])
        else:
            cyclobutane[f_group] = [SMILES_to_relevances[SMILES]]
        print(f"cyclobutane, SMILES: {SMILES}, relevance: {SMILES_to_relevances[SMILES]}, pKa: {SMILES_to_pKa[SMILES]}, f group: {f_group}")
# Out:
# cyclobutane, SMILES: FC1CNC1, relevance: 1.44, pKa: 8.55, f group: CHF
# cyclobutane, SMILES: FC1(F)CNC1, relevance: 0.9, pKa: 6.44, f group: gem-CF2
# cyclobutane, SMILES: FC(F)(F)C1CNC1, relevance: -0.43, pKa: 8.67, f group: CF3
# cyclobutane, SMILES: FC([H])(F)C1CNC1, relevance: 1.52, pKa: 9.57, f group: CHF2
# cyclobutane, SMILES: FC([H])([H])C1CNC1, relevance: 1.74, pKa: 10.05, f group: CH2F

# %%
print(cyclohexan)
print(cyclopentane)
print(cyclobutane)
# Out:
# {'CHF': [1.14, 0.96, 0.96, 1.14, 1.14], 'CH2F': [1.73], 'CF3': [-0.22], 'CHF2': [1.31], 'gem-CF2': [-0.91]}
# {'CHF': [1.14, 1.35, 1.35], 'gem-CF2': [-0.7], 'CHF2': [1.03], 'CH2F': [1.71], 'CF3': [0.39]}
# {'CHF': [1.44], 'gem-CF2': [0.9], 'CF3': [-0.43], 'CHF2': [1.52], 'CH2F': [1.74]}

# %%
fluorine_groups = ['CHF', 'CH2F', 'CHF2', 'CF3', 'gem-CF2']
cyclopentane_values = [round(sum(cyclopentane[fluorine_group]) / len(cyclopentane[fluorine_group]), 2) for fluorine_group in fluorine_groups]
cyclohexan_values = [round(sum(cyclohexan[fluorine_group]) / len(cyclohexan[fluorine_group]), 2) for fluorine_group in fluorine_groups]
cyclobutane_values = [round(sum(cyclobutane[fluorine_group]) / len(cyclobutane[fluorine_group]), 2) for fluorine_group in fluorine_groups]

# %%
import matplotlib.pyplot as plt

combined_values = cyclopentane_values + cyclohexan_values + cyclobutane_values

plt.plot(fluorine_groups, cyclopentane_values, marker='o', linestyle='-', color="darkorange", label="cyclopentane")
plt.plot(fluorine_groups, cyclohexan_values, marker='o', linestyle='-', color="gold", label="cyclohexan")
plt.plot(fluorine_groups, cyclobutane_values, marker='o', linestyle='-', color="deeppink", label="cyclobutane")

for i in range(len(fluorine_groups)):
    plt.annotate(str(cyclopentane_values[i]), (fluorine_groups[i], cyclopentane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    plt.annotate(str(cyclohexan_values[i]), (fluorine_groups[i], cyclohexan_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')
    plt.annotate(str(cyclobutane_values[i]), (fluorine_groups[i], cyclobutane_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

plt.xlabel('Fluorine groups')
plt.ylabel('Average relevance')
plt.title('Only fluorine relevances with distance to N = 2')

plt.ylim(min(combined_values) - 0.2, max(combined_values) + 0.2)
# plt.ylim(-2.5, 2)
plt.legend()
plt.show()

# %%
cyclobutane = {}
cyclopentane = {}
cyclohexan = {}

for SMILES, distance in smiles_to_distance_to_nitrogen.items():
    
    if distance != 3:
        continue
    
    if 'cyclohexane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclohexan:
            cyclohexan[f_group].append(SMILES_to_relevances[SMILES])
        else:
            cyclohexan[f_group] = [SMILES_to_relevances[SMILES]]
        print(SMILES, SMILES_to_relevances[SMILES], f_group)

    elif 'cyclopentane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclopentane:
            cyclopentane[f_group].append(SMILES_to_relevances[SMILES])
        else:
            cyclopentane[f_group] = [SMILES_to_relevances[SMILES]]

    elif 'cyclobutane' == SMILES_to_cycle_type[SMILES]:
        
        f_group = SMILES_to_fgroup[SMILES]
        if f_group in cyclobutane:
            cyclobutane[f_group].append(SMILES_to_relevances[SMILES])
        else:
            cyclobutane[f_group] = [SMILES_to_relevances[SMILES]]

print("cyclobutane:", cyclobutane)
print("cyclopentane:", cyclopentane)
print("cyclohexan:", cyclohexan)
# Out:
# FC1(F)CCNCC1 -0.73 gem-CF2
# FC1CCNCC1 1.08 CHF
# FC(F)(F)C1CCNCC1 0.59 CF3
# [H]C(F)(F)C1CCNCC1 1.4 CHF2
# [H]C(F)([H])C1CCNCC1 1.7 CH2F
# cyclobutane: {}
# cyclopentane: {}
# cyclohexan: {'gem-CF2': [-0.73], 'CHF': [1.08], 'CF3': [0.59], 'CHF2': [1.4], 'CH2F': [1.7]}

# %%
fluorine_groups = ['CHF', 'CH2F', 'CHF2', 'CF3', 'gem-CF2']
# cyclopentane_values = [round(sum(cyclopentane[fluorine_group]) / len(cyclopentane[fluorine_group]), 2) for fluorine_group in fluorine_groups]
cyclohexan_values = [round(sum(cyclohexan[fluorine_group]) / len(cyclohexan[fluorine_group]), 2) for fluorine_group in fluorine_groups]
# cyclobutane_values = [round(sum(cyclobutane[fluorine_group]) / len(cyclobutane[fluorine_group]), 2) for fluorine_group in fluorine_groups]

# %%
import matplotlib.pyplot as plt

combined_values = cyclohexan_values

plt.plot(fluorine_groups, cyclohexan_values, marker='o', linestyle='-', color="seagreen", label="cyclohexan")

for i in range(len(fluorine_groups)):
    plt.annotate(str(cyclohexan_values[i]), (fluorine_groups[i], cyclohexan_values[i]), xytext=(0, 10), textcoords='offset points', ha='center')

plt.xlabel('Fluorine groups')
plt.ylabel('Average relevance')
plt.title('Only fluorine relevances with distance to N = 3')

plt.ylim(min(combined_values) - 0.1, max(combined_values) + 0.1)
# plt.ylim(-2.5, 2)
plt.legend()
plt.show()
