# %% [markdown]
# logP

# %%
import os
import sys
import glob 

target_path = r'images/gnn_SME/SME_grouped_molecules_by_type/logp'
images_path = r'C:\work\DrugDiscovery\article\images for article\SME each molecule for supplementary\logP'

# %%
logP_images_names = os.listdir(images_path)

# %%
latex_code_for_image = r"""
\begin{figure*}[ht]
    \centering
    \includegraphics[width=image_widthcm]{images/gnn_SME/SME_grouped_molecules_by_type/logp/image_name}
    \caption{caption_name}
    \label{label_name}
\end{figure*}
"""

# %%
print(latex_code_for_image)
# Out:
# \begin{figure*}[ht]
#     \centering
#     \includegraphics[width=image_widthcm]{images/gnn_SME/SME_grouped_molecules_by_type/logp/image_name}
#     \caption{caption_name}
#     \label{label_name}
# \end{figure*}

# %%
from PIL import Image
import time

for logP_image_name in logP_images_names:
    img_filepath = os.path.join(images_path, logP_image_name)
    img_width = Image.open(img_filepath).width
    width = "17.4" if img_width > 600 else "8.6"

    # if width == "8.6":
    #     continue

    caption_name = logP_image_name.replace("β", r"$\beta$").replace("γ", r"$\gamma$").replace("δ", r"$\delta$").replace("α", r"$\alpha$").replace("ε", r"$\epsilon$").replace("_", " ").replace(".png", "").replace("{", "\{").replace("}", "\}") + "."
    label_name = logP_image_name.replace("-", "_").replace(".png", "")
    logP_image_name = logP_image_name
    # print(logP_image_name, label_name, caption_name, width)

    text = (latex_code_for_image + '.')[:-1].replace("image_width", width).replace("caption_name", caption_name).replace("label_name", label_name).replace("image_name", logP_image_name)
    # latex_code_for_image.replace("image_width", width).replace("caption_name", caption_name).replace("label_name", label_name).replace("image_name", logP_image_name)
    print(text)

    # print("-" * 30)

    time.sleep(0.2)
    # break
# Out:
# \begin{figure*}[ht]
#     \centering
#     \includegraphics[width=8.6cm]{images/gnn_SME/SME_grouped_molecules_by_type/logp/logP_cis-β,γ-5{5,[2]}.png}
#     \caption{logP cis-$\beta$,$\gamma$-5\{5,[2]\}.}
#     \label{logP_cis_β,γ_5{5,[2]}}
# \end{figure*}
#
#
# \begin{figure*}[ht]
#     \centering
#     \includegraphics[width=8.6cm]{images/gnn_SME/SME_grouped_molecules_by_type/logp/logP_cis-β,γ-5{6,[2]}.png}
#     \caption{logP cis-$\beta$,$\gamma$-5\{6,[2]\}.}
#     \label{logP_cis_β,γ_5{6,[2]}}
# \end{figure*}
#
#
# \begin{figure*}[ht]
#     \centering
#     \includegraphics[width=8.6cm]{images/gnn_SME/SME_grouped_molecules_by_type/logp/logP_cis-β,δ-5{6,[2]}.png}
#     \caption{logP cis-$\beta$,$\delta$-5\{6,[2]\}.}
#     \label{logP_cis_β,δ_5{6,[2]}}
# \end{figure*}
#
#
# \begin{figure*}[ht]
#     \centering
#     \includegraphics[width=17.4cm]{images/gnn_SME/SME_grouped_molecules_by_type/logp/logP_cis-β-4{3,[4,5]}.png}
#     \caption{logP cis-$\beta$-4\{3,[4,5]\}.}
# ...

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# -------------

# %% [markdown]
# pKa

# %%
import os 

target_path = r'images/gnn_SME/SME_grouped_molecules_by_type/pka'
images_path = r'C:\work\DrugDiscovery\article\images for article\SME each molecule for supplementary\pKa'

pKa_images_names = os.listdir(images_path)

# %%
latex_code_for_image = r"""
\begin{figure*}[ht]
    \centering
    \includegraphics[width=image_widthcm]{images/gnn_SME/SME_grouped_molecules_by_type/pka/image_name}
    \caption{caption_name}
    \label{label_name}
\end{figure*}
"""

# %%
from PIL import Image
import time

for pKa_image_name in pKa_images_names:
    img_filepath = os.path.join(images_path, pKa_image_name)
    img_width = Image.open(img_filepath).width
    width = "17.4" if img_width > 600 else "8.6"

    # if width == "8.6":
    #     continue

    caption_name = pKa_image_name.replace("β", r"$\beta$").replace("γ", r"$\gamma$").replace("δ", r"$\delta$").replace("α", r"$\alpha$").replace("ε", r"$\epsilon$").replace("_", " ").replace(".png", "").replace("{", "\{").replace("}", "\}") + "."
    label_name = pKa_image_name.replace("-", "_").replace(".png", "")
    pKa_image_name = pKa_image_name

    text = (latex_code_for_image + '.')[:-1].replace("image_width", width).replace("caption_name", caption_name).replace("label_name", label_name).replace("image_name", pKa_image_name)
    print(text)

    time.sleep(0.2)
    # break
# Out:
# \begin{figure*}[ht]
#     \centering
#     \includegraphics[width=8.6cm]{images/gnn_SME/SME_grouped_molecules_by_type/pka/pKa_cis-β,γ-2{5,[2]}.png}
#     \caption{pKa cis-$\beta$,$\gamma$-2\{5,[2]\}.}
#     \label{pKa_cis_β,γ_2{5,[2]}}
# \end{figure*}
#
#
# \begin{figure*}[ht]
#     \centering
#     \includegraphics[width=8.6cm]{images/gnn_SME/SME_grouped_molecules_by_type/pka/pKa_cis-β,γ-2{6,[2]}.png}
#     \caption{pKa cis-$\beta$,$\gamma$-2\{6,[2]\}.}
#     \label{pKa_cis_β,γ_2{6,[2]}}
# \end{figure*}
#
#
# \begin{figure*}[ht]
#     \centering
#     \includegraphics[width=8.6cm]{images/gnn_SME/SME_grouped_molecules_by_type/pka/pKa_cis-β,δ-2{6,[2]}.png}
#     \caption{pKa cis-$\beta$,$\delta$-2\{6,[2]\}.}
#     \label{pKa_cis_β,δ_2{6,[2]}}
# \end{figure*}
#
#
# \begin{figure*}[ht]
#     \centering
#     \includegraphics[width=17.4cm]{images/gnn_SME/SME_grouped_molecules_by_type/pka/pKa_cis-β-1{3,[4,5]}.png}
#     \caption{pKa cis-$\beta$-1\{3,[4,5]\}.}
# ...
