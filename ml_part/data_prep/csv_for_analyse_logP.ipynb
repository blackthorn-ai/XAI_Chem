# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

def calculate_metrics(true_values, pred_values):
    mse = round(mean_squared_error(true_values, pred_values),3)
    mae = round(mean_absolute_error(true_values, pred_values),3)
    r_score = round(r2_score(true_values, pred_values),3)

    return {"mse": mse,
            "mae": mae,
            "r^2": r_score,}

# %%
import h2o

h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM (build 21.0.1+12-LTS-29, mixed mode, sharing)
#   Starting server from C:\work\DrugDiscovery\drug-discovery-venv\Lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\38066\AppData\Local\Temp\tmppl5q0n6x
#   JVM stdout: C:\Users\38066\AppData\Local\Temp\tmppl5q0n6x\h2o_38066_started_from_python.out
#   JVM stderr: C:\Users\38066\AppData\Local\Temp\tmppl5q0n6x\h2o_38066_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Europe/Kiev
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.44.0.3
# H2O_cluster_version_age:    1 month and 16 days
# H2O_cluster_name:           H2O_from_python_38066_ypozg7
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.950 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  8
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.11.7 final
# --------------------------  -----------------------------

# %%
import pandas as pd
import numpy as np

import h2o

import sys
import os
sys.path.insert(0, os.path.dirname('C:\work\DrugDiscovery\main_git\XAI_Chem\ml_part'))

from ml_part.random_forest.data_prep.preparation import DataPreparation
from ml_part.random_forest.train import RFTrain
from ml_part.molecule_features.constants import identificator_to_molecule_type, cis_trans_id_to_str

CSV_PATH = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\remained_features_logP_01.02_v3.csv'
smiles_filepath = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\smiles_to_index.pkl'

dataPreparation = DataPreparation(CSV_PATH)

unimportant_features_to_drop = []
X, y = dataPreparation.prepare_data_for_RF(is_pKa=False,
                                           use_mandatory_features=True,
                                           is_remove_outliers=True,
                                           is_remove_nan=False,
                                           outliers_features_to_skip=unimportant_features_to_drop)

correlated_features = ['f_atom_fraction', 'naHRing', 'nFaRing', 'nFaHRing', 'tpsa+f']
features_to_drop = []
for feature_name in X.columns:
    if feature_name in correlated_features:
        features_to_drop.append(feature_name)

X = X.drop(features_to_drop, axis=1)

rf_train = RFTrain(X=X, 
                   y=y,
                   smiles_filepath=smiles_filepath,
                   is_pKa=False,
                   k_folds=2)
smiles_to_index_dict = rf_train.smiles_to_index

y_train = rf_train.y_train
X_train = rf_train.X_train

y_test = rf_train.y_test
X_test = rf_train.X_test

train_df = pd.concat([X_train, y_train], axis=1)
test_df = pd.concat([X_test, y_test], axis=1)

train = h2o.H2OFrame(train_df)
test = h2o.H2OFrame(test_df)
# Out:
# True
# 183
# ['nC', 'FPSA3', 'nFARing', 'RPCS', 'dipole_moment', 'angle_R1X1R2', 'nFAHRing', 'angle_X2X1R1', 'nFHRing', 'naHRing', 'chirality', 'cis/trans', 'nHRing', 'TASA', 'angle_X1X2R2', 'nO', 'nF', 'PNSA5', 'dihedral_angle', 'f_atom_fraction', 'f_to_fg', 'nARing', 'angle_R2X2R1', 'identificator', 'naRing', 'nFaRing', 'nFaHRing', 'mol_volume', 'tpsa+f', 'mol_weight', 'avg_atoms_in_cycle', 'mol_num_cycles', 'nN', 'nAHRing', 'PBF', 'nFRing', 'WPSA5', 'f_freedom', 'distance_between_atoms_in_f_group_centers', 'PPSA5', 'GeomShapeIndex', 'pKa', 'logP']
# dipole_moment outliers indexes: [19, 21, 23, 27, 61, 66, 67, 73, 82, 136, 152, 182]
# f_atom_fraction outliers indexes: [124]
# mol_volume outliers indexes: [127]
# distance_between_atoms_in_f_group_centers outliers indexes: [168]
# logP outliers indexes: [82, 83]
# Remains rows:162, amount of features: 43
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
logP_model = h2o.load_model(r'C:\\work\\DrugDiscovery\\main_git\\XAI_Chem\\ml_part\\h2o_model\\models\\01.02.24_features_2.1\\logP\\all_molecules(without_angle_feature)_identificator_without_outliers_sorted_by_cv\\StackedEnsemble_BestOfFamily_3_AutoML_2_20240205_132350')

# %%
preds = logP_model.predict(test)
true = test.as_data_frame()['logP']
predicted_values = preds.as_data_frame()['predict']

print(calculate_metrics(true, predicted_values))

predicted_values = [round(pred, 2) for pred in list(preds.as_data_frame()['predict'])]

test_df['predicted_pKa'] = predicted_values
# Out:
# stackedensemble prediction progress: |
# ███████████████████████████████████████████| (done) 100%
# {'mse': 0.044, 'mae': 0.168, 'r^2': 0.83}
# c:\work\DrugDiscovery\drug-discovery-venv\Lib\site-packages\h2o\frame.py:1979: H2ODependencyWarning: converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install datatable (for Python 3.9 or lower), or polars and pyarrow (for Python 3.10 or above).
#   warnings.warn("converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# c:\work\DrugDiscovery\drug-discovery-venv\Lib\site-packages\h2o\frame.py:1979: H2ODependencyWarning: converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install datatable (for Python 3.9 or lower), or polars and pyarrow (for Python 3.10 or above).
#   warnings.warn("converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# c:\work\DrugDiscovery\drug-discovery-venv\Lib\site-packages\h2o\frame.py:1979: H2ODependencyWarning: converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install datatable (for Python 3.9 or lower), or polars and pyarrow (for Python 3.10 or above).
#   warnings.warn("converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"

# %%
preds = logP_model.predict(train)
true = train.as_data_frame()['logP']
predicted_values = preds.as_data_frame()['predict']

print(calculate_metrics(true, predicted_values))

predicted_values = [round(pred, 2) for pred in list(preds.as_data_frame()['predict'])]

train_df['predicted_pKa'] = predicted_values
# Out:
# stackedensemble prediction progress: |
# ███████████████████████████████████████████| (done) 100%
# {'mse': 0.016, 'mae': 0.084, 'r^2': 0.958}
# c:\work\DrugDiscovery\drug-discovery-venv\Lib\site-packages\h2o\frame.py:1979: H2ODependencyWarning: converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install datatable (for Python 3.9 or lower), or polars and pyarrow (for Python 3.10 or above).
#   warnings.warn("converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# c:\work\DrugDiscovery\drug-discovery-venv\Lib\site-packages\h2o\frame.py:1979: H2ODependencyWarning: converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install datatable (for Python 3.9 or lower), or polars and pyarrow (for Python 3.10 or above).
#   warnings.warn("converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# c:\work\DrugDiscovery\drug-discovery-venv\Lib\site-packages\h2o\frame.py:1979: H2ODependencyWarning: converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install datatable (for Python 3.9 or lower), or polars and pyarrow (for Python 3.10 or above).
#   warnings.warn("converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"

# %%
train_df['used_for'] = ['Train'] * len(train_df)
test_df['used_for'] = ['Out of sample'] * len(test_df)

df = pd.concat([train_df, test_df])
df['cis/trans'] = [cis_trans_id_to_str[param] for param in df['cis/trans']]
df['identificator'] = [identificator_to_molecule_type[param] for param in df['identificator']]
df.rename(columns = {'pKa': 'true_pKa'}, inplace=True)

# %%
for feature_name in df.columns:
    if "angle" in feature_name or "distance" in feature_name:
        df[feature_name] = [np.NaN if value == 0.000 else value for value in df[feature_name]]

# %%
df['identificator']
# Out:
# 1      Carboxylic acid
# 2      Carboxylic acid
# 3      Carboxylic acid
# 4      Carboxylic acid
# 5      Carboxylic acid
#             ...
# 55       Primary amine
# 126      Primary amine
# 103      Primary amine
# 49     Carboxylic acid
# 22     Carboxylic acid
# Name: identificator, Length: 162, dtype: object

# %%
import pandas as pd
import numpy as np

import h2o

import sys
import os
sys.path.insert(0, os.path.dirname('C:\work\DrugDiscovery\main_git\XAI_Chem\ml_part'))

from ml_part.random_forest.data_prep.preparation import DataPreparation
from ml_part.random_forest.train import RFTrain
from ml_part.molecule_features.constants import identificator_to_molecule_type, cis_trans_id_to_str

CSV_PATH = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\remained_features_logP_01.02_v3.csv'
smiles_filepath = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\smiles_to_index.pkl'

dataPreparation = DataPreparation(CSV_PATH)

unimportant_features_to_drop = []
X, y = dataPreparation.prepare_data_for_RF(is_pKa=False,
                                           use_mandatory_features=True,
                                           is_remove_outliers=False,
                                           is_remove_nan=False,
                                           outliers_features_to_skip=unimportant_features_to_drop)

correlated_features = ['f_atom_fraction', 'naHRing', 'nFaRing', 'nFaHRing', 'tpsa+f']
features_to_drop = []
for feature_name in X.columns:
    if feature_name in correlated_features:
        features_to_drop.append(feature_name)

X = X.drop(features_to_drop, axis=1)

rf_train = RFTrain(X=X, 
                   y=y,
                   smiles_filepath=smiles_filepath,
                   is_pKa=False,
                   k_folds=2)
smiles_to_index_dict = rf_train.smiles_to_index

y_train_all = rf_train.y_train
X_train_all = rf_train.X_train

y_test_all = rf_train.y_test
X_test_all = rf_train.X_test

train_df_all = pd.concat([X_train_all, y_train_all], axis=1)
test_df_all = pd.concat([X_test_all, y_test_all], axis=1)

df_all = pd.concat([train_df_all, test_df_all], axis=0)
# Out:
# True
# 183
# ['nC', 'FPSA3', 'nFARing', 'RPCS', 'dipole_moment', 'angle_R1X1R2', 'nFAHRing', 'angle_X2X1R1', 'nFHRing', 'naHRing', 'chirality', 'cis/trans', 'nHRing', 'TASA', 'angle_X1X2R2', 'nO', 'nF', 'PNSA5', 'dihedral_angle', 'f_atom_fraction', 'f_to_fg', 'nARing', 'angle_R2X2R1', 'identificator', 'naRing', 'nFaRing', 'nFaHRing', 'mol_volume', 'tpsa+f', 'mol_weight', 'avg_atoms_in_cycle', 'mol_num_cycles', 'nN', 'nAHRing', 'PBF', 'nFRing', 'WPSA5', 'f_freedom', 'distance_between_atoms_in_f_group_centers', 'PPSA5', 'GeomShapeIndex', 'pKa', 'logP']
# Remains rows:178, amount of features: 43

# %%
indexes_to_drop = []
for index, _ in df_all.iterrows():
    if index in df.index:
        indexes_to_drop.append(index)

df_outliers = df_all.drop(index=indexes_to_drop)

df_all_h2o = h2o.H2OFrame(df_outliers)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
preds = logP_model.predict(df_all_h2o)
true = df_all_h2o.as_data_frame()['logP']
predicted_values = preds.as_data_frame()['predict']

print(calculate_metrics(true, predicted_values))

predicted_values = [round(pred, 2) for pred in list(preds.as_data_frame()['predict'])]

df_outliers['predicted_pKa'] = predicted_values
# Out:
# stackedensemble prediction progress: |
# ███████████████████████████████████████████| (done) 100%
# {'mse': 0.067, 'mae': 0.184, 'r^2': 0.914}
# c:\work\DrugDiscovery\drug-discovery-venv\Lib\site-packages\h2o\frame.py:1979: H2ODependencyWarning: converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install datatable (for Python 3.9 or lower), or polars and pyarrow (for Python 3.10 or above).
#   warnings.warn("converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# c:\work\DrugDiscovery\drug-discovery-venv\Lib\site-packages\h2o\frame.py:1979: H2ODependencyWarning: converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install datatable (for Python 3.9 or lower), or polars and pyarrow (for Python 3.10 or above).
#   warnings.warn("converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# c:\work\DrugDiscovery\drug-discovery-venv\Lib\site-packages\h2o\frame.py:1979: H2ODependencyWarning: converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install datatable (for Python 3.9 or lower), or polars and pyarrow (for Python 3.10 or above).
#   warnings.warn("converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"

# %%
df_outliers['used_for'] = ['outliers'] * len(df_outliers)

df_outliers['cis/trans'] = [cis_trans_id_to_str[param] for param in df_outliers['cis/trans']]
df_outliers['identificator'] = [identificator_to_molecule_type[param] for param in df_outliers['identificator']]
df_outliers.rename(columns = {'pKa': 'true_pKa'}, inplace=True)

# %%
MAIN_CSV_PATH = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\init_data\pKa_Prediction_Starting data_2024.01.25.csv'

df_for_logP_smiles = pd.read_csv(MAIN_CSV_PATH, index_col=0)

index_to_logP_smiles = {}

for index, row in df_for_logP_smiles.iterrows():
    if pd.isnull(row['Amides for LogP']):
        continue

    index_to_logP_smiles[index - 1] = row['Amides for LogP']
index_to_logP_smiles
# Out:
# {0: 'FC1(F)CCC(CC1)C(=O)NC1=CC=CC=C1',
#  1: 'O=C(NC1=CC=CC=C1)C1CCCCC1',
#  2: 'O=C(NC1=CC=CC=C1)[C@H]1C[C@@H]2C[C@@H]2C1',
#  3: 'O=C(NC1=CC=CC=C1)[C@@H]1C[C@@H]2C[C@@H]2C1',
#  4: 'FC1(F)[C@H]2C[C@H](C[C@@H]12)C(=O)NC1=CC=CC=C1',
#  5: 'FC1(F)[C@H]2C[C@@H](C[C@@H]12)C(=O)NC1=CC=CC=C1',
#  6: 'O=C(NC1=CC=CC=C1)C1CCC1',
#  7: 'FCC1(CCC1)C(=O)NC1=CC=CC=C1',
#  8: 'FC(F)C1(CCC1)C(=O)NC1=CC=CC=C1',
#  9: 'FC(F)(F)C1(CCC1)C(=O)NC1=CC=CC=C1',
#  10: 'FC(F)(F)[C@H]1C[C@@H](C1)C(=O)NC1=CC=CC=C1',
#  11: 'FC(F)(F)[C@@H]1C[C@@H](C1)C(=O)NC1=CC=CC=C1',
#  12: '[H]C(F)(F)[C@H]1C[C@@H](C1)C(=O)NC1=CC=CC=C1',
#  13: '[H]C(F)(F)[C@@H]1C[C@@H](C1)C(=O)NC1=CC=CC=C1',
#  14: '[H]C([H])(F)[C@H]1C[C@@H](C1)C(=O)NC1=CC=CC=C1',
#  15: '[H]C([H])(F)[C@@H]1C[C@@H](C1)C(=O)NC1=CC=CC=C1',
#  16: 'FC1(F)CC1C(=O)NC1=CC=CC=C1',
#  17: 'FC1(F)CCC1C(=O)NC1=CC=CC=C1',
#  18: 'FC1(F)CC(C1)C(=O)NC1=CC=CC=C1',
#  19: 'FC1(F)CCCC1C(=O)NC1=CC=CC=C1',
#  20: 'FC1(F)CCC(C1)C(=O)NC1=CC=CC=C1',
#  21: 'FC1(F)CCCCC1C(=O)NC1=CC=CC=C1',
#  22: 'FC1(F)CCCC(C1)C(=O)NC1=CC=CC=C1',
#  23: 'FC1(F)CCCCCC1C(=O)NC1=CC=CC=C1',
#  24: 'FC1(F)CCCCC(C1)C(=O)NC1=CC=CC=C1',
#  25: 'FC1(F)CCCC(CC1)C(=O)NC1=CC=CC=C1',
#  26: 'CCC(F)(F)CC(=O)NC1=CC=CC=C1',
#  27: 'CC(F)(F)CCC(=O)NC1=CC=CC=C1',
#  28: 'FC(F)CCCC(=O)NC1=CC=CC=C1',
#  29: 'O=C(NC1=CC=CC=C1)C1CC1',
#  30: 'O=C(NC1=CC=CC=C1)C1CCC1',
#  31: 'O=C(NC1=CC=CC=C1)C1CCCC1',
#  32: 'O=C(NC1=CC=CC=C1)C1CCCCCC1',
#  33: 'CCCCC(=O)NC1=CC=CC=C1',
#  34: 'O=C(NC1=CC=CC=C1)C1CC2(CCC2)C1',
#  35: 'FC1CC2(C1)CC(C2)C(=O)NC1=CC=CC=C1',
#  36: 'FC1(F)CC2(CC(C2)C(=O)NC2=CC=CC=C2)C1',
#  37: 'FC(F)(F)C12CC(C1)(OC2)C(=O)NC1=CC=CC=C1',
#  38: '[H]C(F)(F)C12CC(C1)(OC2)C(=O)NC1=CC=CC=C1',
#  39: 'O=C(NC1=CC=CC=C1)C12CC(C1)CO2',
#  40: 'O=C(NC1=CC=CC=C1)C1=CC=CC=C1',
#  41: 'FC(F)(F)[C@@H]1CC[C@H]1C(=O)NC1=CC=CC=C1',
#  42: '[H]C(F)(F)[C@@H]1CC[C@H]1C(=O)NC1=CC=CC=C1',
#  43: '[H]C([H])(F)[C@@H]1CC[C@H]1C(=O)NC1=CC=CC=C1',
#  44: 'FC(F)(F)[C@@H]1C[C@H]1C(=O)NC1=CC=CC=C1',
#  45: 'FC(F)(F)[C@@H]1C[C@@H]1C(=O)NC1=CC=CC=C1',
#  46: '[H]C(F)(F)[C@@H]1C[C@H]1C(=O)NC1=CC=CC=C1',
#  47: '[H]C(F)(F)[C@@H]1C[C@@H]1C(=O)NC1=CC=CC=C1',
#  48: '[H]C([H])(F)[C@@H]1C[C@H]1C(=O)NC1=CC=CC=C1',
#  49: 'C[C@@H]1C[C@H]1C(=O)NC1=CC=CC=C1',
#  50: 'C[C@@H]1C[C@@H]1C(=O)NC1=CC=CC=C1',
#  51: '[H]C([H])(F)[C@H]1C[C@H]1C(=O)NC1=CC=CC=C1',
#  52: 'O=C(NC1=CC=CC=C1)C1CC11CC1',
#  53: 'FC1(F)C(C(=O)NC2=CC=CC=C2)C11CC1',
#  54: 'FC1(F)CC11CC1C(=O)NC1=CC=CC=C1',
#  55: 'FC1(F)[C@H]2C[C@@H](C[C@@H]12)NC(=O)C1=CC=CC=C1',
#  56: 'FC1(F)[C@H]2C[C@H](C[C@@H]12)NC(=O)C1=CC=CC=C1',
#  57: 'FC1(F)CCC(CC1)NC(=O)C1=CC=CC=C1',
#  58: 'O=C(NC1CCCCC1)C1=CC=CC=C1',
#  59: 'O=C(N[C@@H]1C[C@@H]2C[C@@H]2C1)C1=CC=CC=C1',
#  60: 'O=C(N[C@H]1C[C@@H]2C[C@@H]2C1)C1=CC=CC=C1',
#  61: 'FC(F)(F)C12CC(C1)CN2C(=O)C1=CC=CC=C1',
#  62: 'FC(F)(F)C1CCCN1C(=O)C1=CC=CC=C1',
#  63: 'O=C(N1CC2CC1C2)C1=CC=CC=C1',
#  64: 'O=C(N1CCCC1)C1=CC=CC=C1',
#  65: 'CC12CC(C1)CN2C(=O)C1=CC=CC=C1',
#  66: 'FC(F)(F)C12CCC(CN1C(=O)C1=CC=CC=C1)C2',
#  67: 'FC(F)(F)C12CCC(CC1)CN2C(=O)C1=CC=CC=C1',
#  68: 'FC(F)(F)C1CCCCN1C(=O)C1=CC=CC=C1',
#  69: 'O=C(N1CC2CCC1C2)C1=CC=CC=C1',
#  70: 'CC12CCC(CC1)CN2C(=O)C1=CC=CC=C1',
#  71: 'O=C(N1CC2CCC1CC2)C1=CC=CC=C1',
#  72: 'O=C(N1CCCCC1)C1=CC=CC=C1',
#  73: 'FC(F)(F)C12CC(CN1C(=O)C1=CC=CC=C1)CCC2',
#  74: 'O=C(N1CC2CC1CCC2)C1=CC=CC=C1',
#  75: 'CC12CC(CN1C(=O)C1=CC=CC=C1)CCC2',
#  76: 'FC1(F)CC2CC(CN(C2)C(=O)C2=CC=CC=C2)C1',
#  77: 'FC1(F)CC2CN(CC(C1)C2(F)F)C(=O)C1=CC=CC=C1',
#  78: 'FC1(F)C2CCCC1CN(C2)C(=O)C1=CC=CC=C1',
#  79: 'O=C(N1CC2CCCC(C2)C1)C1=CC=CC=C1',
#  80: 'FC1(F)C2COCC1CN(C2)C(=O)C1=CC=CC=C1',
#  81: 'O=C(N1CC2COCC(C2)C1)C1=CC=CC=C1',
#  82: 'O=C(N1CC2CC(C1)CS(=O)(=O)C2)C1=CC=CC=C1',
#  83: 'FC1(F)C2CN(CC1CS(=O)(=O)C2)C(=O)C1=CC=CC=C1',
#  84: 'FC1(F)C2CCC1CN(C2)C(=O)C1=CC=CC=C1',
#  85: 'O=C(N1CC2CCC(C2)C1)C1=CC=CC=C1',
#  86: 'FC1(F)CCN(CC1)C(=O)C1=CC=CC=C1',
#  87: 'O=C(N1CCC1)C1=CC=CC=C1',
#  88: 'FC1CN(C1)C(=O)C1=CC=CC=C1',
#  89: 'FC1(F)CN(C1)C(=O)C1=CC=CC=C1',
#  90: 'O=C(N1CCCC1)C1=CC=CC=C1',
#  91: 'FC1CCN(C1)C(=O)C1=CC=CC=C1',
#  92: 'FC1(F)CCN(C1)C(=O)C1=CC=CC=C1',
#  93: 'F[C@H]1CN(C[C@H]1F)C(=O)C1=CC=CC=C1',
#  94: 'F[C@@H]1CN(C[C@H]1F)C(=O)C1=CC=CC=C1',
#  95: 'FC1CCCN(C1)C(=O)C1=CC=CC=C1',
#  96: 'FC1(F)CCCN(C1)C(=O)C1=CC=CC=C1',
#  97: 'F[C@H]1C[C@@H](F)CN(C1)C(=O)C1=CC=CC=C1',
#  98: 'F[C@H]1C[C@H](F)CN(C1)C(=O)C1=CC=CC=C1',
#  99: 'FC1CCN(CC1)C(=O)C1=CC=CC=C1',
#  100: 'F[C@@H]1CCN(C[C@@H]1F)C(=O)C1=CC=CC=C1',
#  101: 'F[C@@H]1CCN(C[C@H]1F)C(=O)C1=CC=CC=C1',
#  102: 'FC(F)(F)C1(CCC1)NC(=O)C1=CC=CC=C1',
#  103: 'FC(F)C1(CCC1)NC(=O)C1=CC=CC=C1',
#  104: 'FCC1(CCC1)NC(=O)C1=CC=CC=C1',
#  105: 'O=C(NC1CCC1)C1=CC=CC=C1',
#  106: 'FC(F)(F)[C@H]1C[C@@H](C1)NC(=O)C1=CC=CC=C1',
#  107: 'FC(F)(F)[C@@H]1C[C@@H](C1)NC(=O)C1=CC=CC=C1',
#  108: '[H]C(F)(F)[C@H]1C[C@@H](C1)NC(=O)C1=CC=CC=C1',
#  109: '[H]C(F)(F)[C@@H]1C[C@@H](C1)NC(=O)C1=CC=CC=C1',
#  110: '[H]C([H])(F)[C@H]1C[C@@H](C1)NC(=O)C1=CC=CC=C1',
#  111: '[H]C([H])(F)[C@@H]1C[C@@H](C1)NC(=O)C1=CC=CC=C1',
#  112: 'FC(F)(F)C1CCCCN1C(=O)C1=CC=CC=C1',
#  113: '[H]C(F)(F)C1CCCCN1C(=O)C1=CC=CC=C1',
#  114: '[H]C([H])(F)C1CCCCN1C(=O)C1=CC=CC=C1',
#  115: 'O=C(N1CCCCC1)C1=CC=CC=C1',
#  116: 'FC(F)(F)C1CCCN1C(=O)C1=CC=CC=C1',
#  117: '[H]C(F)(F)C1CCCN1C(=O)C1=CC=CC=C1',
#  118: '[H]C([H])(F)C1CCCN1C(=O)C1=CC=CC=C1',
#  119: 'O=C(N1CCCC1)C1=CC=CC=C1',
#  120: 'FC(F)(F)C1CCN1C(=O)C1=CC=CC=C1',
#  121: '[H]C(F)(F)C1CCN1C(=O)C1=CC=CC=C1',
#  122: '[H]C([H])(F)C1CCN1C(=O)C1=CC=CC=C1',
#  123: 'O=C(N1CCC1)C1=CC=CC=C1',
#  124: 'FC(F)(F)CNC(=O)C1=CC=CC=C1',
#  125: '[H]C(F)(F)CNC(=O)C1=CC=CC=C1',
#  126: '[H]C([H])(F)CNC(=O)C1=CC=CC=C1',
#  127: 'CNC(=O)C1=CC=CC=C1',
#  128: 'FC(F)(F)C1CCCN(C1)C(=O)C1=CC=CC=C1',
#  129: '[H]C(F)(F)C1CCCN(C1)C(=O)C1=CC=CC=C1',
#  130: '[H]C([H])(F)C1CCCN(C1)C(=O)C1=CC=CC=C1',
#  131: 'FC(F)(F)C1CCN(C1)C(=O)C1=CC=CC=C1',
#  132: '[H]C(F)(F)C1CCN(C1)C(=O)C1=CC=CC=C1',
#  133: '[H]C([H])(F)C1CCN(C1)C(=O)C1=CC=CC=C1',
#  134: 'FC(F)(F)C1CN(C1)C(=O)C1=CC=CC=C1',
#  135: '[H]C(F)(F)C1CN(C1)C(=O)C1=CC=CC=C1',
#  136: '[H]C([H])(F)C1CN(C1)C(=O)C1=CC=CC=C1',
#  137: 'FC(F)(F)CCNC(=O)C1=CC=CC=C1',
#  138: '[H]C(F)(F)CCNC(=O)C1=CC=CC=C1',
#  139: '[H]C([H])(F)CCNC(=O)C1=CC=CC=C1',
#  140: 'CCNC(=O)C1=CC=CC=C1',
#  141: 'FC(F)(F)C1CCN(CC1)C(=O)C1=CC=CC=C1',
#  142: '[H]C(F)(F)C1CCN(CC1)C(=O)C1=CC=CC=C1',
#  143: '[H]C([H])(F)C1CCN(CC1)C(=O)C1=CC=CC=C1',
#  144: '[H]C([H])(F)CCCNC(=O)C1=CC=CC=C1',
#  145: '[H]C(F)(F)CCCNC(=O)C1=CC=CC=C1',
#  146: 'FC(F)(F)CCCNC(=O)C1=CC=CC=C1',
#  147: 'CCCNC(=O)C1=CC=CC=C1',
#  148: 'FC1(F)CC1NC(=O)C1=CC=CC=C1',
#  149: 'FC1(F)CCC1NC(=O)C1=CC=CC=C1',
#  150: 'FC1(F)CC(C1)NC(=O)C1=CC=CC=C1',
#  151: 'FC1(F)CCCC1NC(=O)C1=CC=CC=C1',
#  152: 'FC1(F)CCC(C1)NC(=O)C1=CC=CC=C1',
#  153: 'FC1(F)CCCCC1NC(=O)C1=CC=CC=C1',
#  154: 'FC1(F)CCCC(C1)NC(=O)C1=CC=CC=C1',
#  155: 'FC1(F)CCC(CC1)NC(=O)C1=CC=CC=C1',
#  156: 'FC1(F)CCCCCC1NC(=O)C1=CC=CC=C1',
#  157: 'FC1(F)CCCCC(C1)NC(=O)C1=CC=CC=C1',
#  158: 'FC1(F)CCCC(CC1)NC(=O)C1=CC=CC=C1',
#  159: 'CCC(F)(F)CNC(=O)C1=CC=CC=C1',
#  160: 'CC(F)(F)CCNC(=O)C1=CC=CC=C1',
#  161: 'FC(F)CCCNC(=O)C1=CC=CC=C1',
#  162: 'O=C(NC1CC1)C1=CC=CC=C1',
#  163: 'O=C(NC1CCCC1)C1=CC=CC=C1',
#  164: 'O=C(NC1CCCCCC1)C1=CC=CC=C1',
#  165: 'CCCCNC(=O)C1=CC=CC=C1',
#  166: 'O=C(NC1CC2(CCC2)C1)C1=CC=CC=C1',
#  167: 'FC1CC2(C1)CC(C2)NC(=O)C1=CC=CC=C1',
#  168: 'FC1(F)CC2(CC(C2)NC(=O)C2=CC=CC=C2)C1',
#  169: 'FC(F)(F)[C@@H]1CC[C@H]1NC(=O)C1=CC=CC=C1',
#  170: '[H]C(F)(F)[C@@H]1CC[C@H]1NC(=O)C1=CC=CC=C1',
#  171: '[H]C([H])(F)[C@@H]1CC[C@H]1NC(=O)C1=CC=CC=C1',
#  172: 'FC(F)(F)[C@@H]1C[C@H]1NC(=O)C1=CC=CC=C1',
#  173: 'FC(F)(F)[C@@H]1C[C@@H]1NC(=O)C1=CC=CC=C1',
#  174: '[H]C(F)(F)[C@@H]1C[C@H]1NC(=O)C1=CC=CC=C1',
#  175: '[H]C(F)(F)[C@@H]1C[C@@H]1NC(=O)C1=CC=CC=C1',
#  176: 'C[C@@H]1C[C@H]1NC(=O)C1=CC=CC=C1',
#  177: 'C[C@@H]1C[C@@H]1NC(=O)C1=CC=CC=C1',
#  178: '[H]C([H])(F)[C@@H]1C[C@H]1NC(=O)C1=CC=CC=C1',
#  179: '[H]C([H])(F)[C@H]1C[C@H]1NC(=O)C1=CC=CC=C1',
#  180: 'O=C(NC1CC11CC1)C1=CC=CC=C1',
#  181: 'FC1(F)C(NC(=O)C2=CC=CC=C2)C11CC1',
#  182: 'FC1(F)CC11CC1NC(=O)C1=CC=CC=C1'}

# %%
df_combined = pd.concat([df, df_outliers])

zero_despertion_features = []
for feature_name in df_combined.columns:
    if len(df_combined[feature_name].unique()) == 1:       
        zero_despertion_features.append(feature_name)

df_combined.drop(zero_despertion_features, axis=1, inplace=True)

smiles_values = []
for index, row in df_combined.iterrows():
    if index == 0:
        print(row)
    SMILES = index_to_logP_smiles[index]
    print(index, SMILES, row['logP'])
    smiles_values.append(SMILES)

df_combined['smiles'] = smiles_values
# Out:
# 1 O=C(NC1=CC=CC=C1)C1CCCCC1 2.88
# 2 O=C(NC1=CC=CC=C1)[C@H]1C[C@@H]2C[C@@H]2C1 2.87
# 3 O=C(NC1=CC=CC=C1)[C@@H]1C[C@@H]2C[C@@H]2C1 2.92
# 4 FC1(F)[C@H]2C[C@H](C[C@@H]12)C(=O)NC1=CC=CC=C1 2.37
# 5 FC1(F)[C@H]2C[C@@H](C[C@@H]12)C(=O)NC1=CC=CC=C1 2.88
# 6 O=C(NC1=CC=CC=C1)C1CCC1 2.26
# 7 FCC1(CCC1)C(=O)NC1=CC=CC=C1 1.88
# 8 FC(F)C1(CCC1)C(=O)NC1=CC=CC=C1 2.19
# 9 FC(F)(F)C1(CCC1)C(=O)NC1=CC=CC=C1 2.51
# 10 FC(F)(F)[C@H]1C[C@@H](C1)C(=O)NC1=CC=CC=C1 3.02
# 11 FC(F)(F)[C@@H]1C[C@@H](C1)C(=O)NC1=CC=CC=C1 2.72
# 12 [H]C(F)(F)[C@H]1C[C@@H](C1)C(=O)NC1=CC=CC=C1 2.39
# 13 [H]C(F)(F)[C@@H]1C[C@@H](C1)C(=O)NC1=CC=CC=C1 2.23
# 14 [H]C([H])(F)[C@H]1C[C@@H](C1)C(=O)NC1=CC=CC=C1 2.14
# 15 [H]C([H])(F)[C@@H]1C[C@@H](C1)C(=O)NC1=CC=CC=C1 1.96
# 18 FC1(F)CC(C1)C(=O)NC1=CC=CC=C1 2.26
# 20 FC1(F)CCC(C1)C(=O)NC1=CC=CC=C1 2.5
# 24 FC1(F)CCCCC(C1)C(=O)NC1=CC=CC=C1 3.03
# 25 FC1(F)CCCC(CC1)C(=O)NC1=CC=CC=C1 2.95
# 26 CCC(F)(F)CC(=O)NC1=CC=CC=C1 2.26
# 28 FC(F)CCCC(=O)NC1=CC=CC=C1 2.06
# 29 O=C(NC1=CC=CC=C1)C1CC1 1.92
# 30 O=C(NC1=CC=CC=C1)C1CCC1 2.26
# 31 O=C(NC1=CC=CC=C1)C1CCCC1 2.68
# 32 O=C(NC1=CC=CC=C1)C1CCCCCC1 3.24
# 33 CCCCC(=O)NC1=CC=CC=C1 2.29
# 35 FC1CC2(C1)CC(C2)C(=O)NC1=CC=CC=C1 2.69
# 37 FC(F)(F)C12CC(C1)(OC2)C(=O)NC1=CC=CC=C1 2.05
# 39 O=C(NC1=CC=CC=C1)C12CC(C1)CO2 1.54
# 40 O=C(NC1=CC=CC=C1)C1=CC=CC=C1 2.49
# 41 FC(F)(F)[C@@H]1CC[C@H]1C(=O)NC1=CC=CC=C1 2.88
# 42 [H]C(F)(F)[C@@H]1CC[C@H]1C(=O)NC1=CC=CC=C1 2.22
# 43 [H]C([H])(F)[C@@H]1CC[C@H]1C(=O)NC1=CC=CC=C1 2.11
# 44 FC(F)(F)[C@@H]1C[C@H]1C(=O)NC1=CC=CC=C1 2.98
# 45 FC(F)(F)[C@@H]1C[C@@H]1C(=O)NC1=CC=CC=C1 2.12
# 46 [H]C(F)(F)[C@@H]1C[C@H]1C(=O)NC1=CC=CC=C1 2.28
# 47 [H]C(F)(F)[C@@H]1C[C@@H]1C(=O)NC1=CC=CC=C1 2.35
# 48 [H]C([H])(F)[C@@H]1C[C@H]1C(=O)NC1=CC=CC=C1 1.12
# 52 O=C(NC1=CC=CC=C1)C1CC11CC1 2.35
# 53 FC1(F)C(C(=O)NC2=CC=CC=C2)C11CC1 2.42
# 54 FC1(F)CC11CC1C(=O)NC1=CC=CC=C1 2.66
# 56 FC1(F)[C@H]2C[C@H](C[C@@H]12)NC(=O)C1=CC=CC=C1 2.47
# 57 FC1(F)CCC(CC1)NC(=O)C1=CC=CC=C1 2.31
# 58 O=C(NC1CCCCC1)C1=CC=CC=C1 2.72
# 59 O=C(N[C@@H]1C[C@@H]2C[C@@H]2C1)C1=CC=CC=C1 2.3
# 60 O=C(N[C@H]1C[C@@H]2C[C@@H]2C1)C1=CC=CC=C1 2.19
# 62 FC(F)(F)C1CCCN1C(=O)C1=CC=CC=C1 2.12
# 63 O=C(N1CC2CC1C2)C1=CC=CC=C1 1.47
# 64 O=C(N1CCCC1)C1=CC=CC=C1 1.19
# 65 CC12CC(C1)CN2C(=O)C1=CC=CC=C1 1.75
# 68 FC(F)(F)C1CCCCN1C(=O)C1=CC=CC=C1 2.54
# 69 O=C(N1CC2CCC1C2)C1=CC=CC=C1 1.65
# 70 CC12CCC(CC1)CN2C(=O)C1=CC=CC=C1 2.66
# 71 O=C(N1CC2CCC1CC2)C1=CC=CC=C1 2.01
# 72 O=C(N1CCCCC1)C1=CC=CC=C1 1.39
# 74 O=C(N1CC2CC1CCC2)C1=CC=CC=C1 1.88
# 75 CC12CC(CN1C(=O)C1=CC=CC=C1)CCC2 2.41
# 76 FC1(F)CC2CC(CN(C2)C(=O)C2=CC=CC=C2)C1 1.59
# 77 FC1(F)CC2CN(CC(C1)C2(F)F)C(=O)C1=CC=CC=C1 1.84
# 78 FC1(F)C2CCCC1CN(C2)C(=O)C1=CC=CC=C1 2.18
# 80 FC1(F)C2COCC1CN(C2)C(=O)C1=CC=CC=C1 1.19
# 81 O=C(N1CC2COCC(C2)C1)C1=CC=CC=C1 0.84
# 84 FC1(F)C2CCC1CN(C2)C(=O)C1=CC=CC=C1 2.09
# 85 O=C(N1CC2CCC(C2)C1)C1=CC=CC=C1 2.31
# 87 O=C(N1CCC1)C1=CC=CC=C1 1.13
# 88 FC1CN(C1)C(=O)C1=CC=CC=C1 0.94
# 90 O=C(N1CCCC1)C1=CC=CC=C1 1.19
# 91 FC1CCN(C1)C(=O)C1=CC=CC=C1 0.91
# 92 FC1(F)CCN(C1)C(=O)C1=CC=CC=C1 1.35
# 93 F[C@H]1CN(C[C@H]1F)C(=O)C1=CC=CC=C1 1.01
# 94 F[C@@H]1CN(C[C@H]1F)C(=O)C1=CC=CC=C1 1.08
# 95 FC1CCCN(C1)C(=O)C1=CC=CC=C1 1.26
# 96 FC1(F)CCCN(C1)C(=O)C1=CC=CC=C1 1.65
# 97 F[C@H]1C[C@@H](F)CN(C1)C(=O)C1=CC=CC=C1 0.58
# 98 F[C@H]1C[C@H](F)CN(C1)C(=O)C1=CC=CC=C1 1.35
# 100 F[C@@H]1CCN(C[C@@H]1F)C(=O)C1=CC=CC=C1 1.15
# 101 F[C@@H]1CCN(C[C@H]1F)C(=O)C1=CC=CC=C1 1.26
# 102 FC(F)(F)C1(CCC1)NC(=O)C1=CC=CC=C1 2.51
# 104 FCC1(CCC1)NC(=O)C1=CC=CC=C1 2.03
# 106 FC(F)(F)[C@H]1C[C@@H](C1)NC(=O)C1=CC=CC=C1 2.82
# 107 FC(F)(F)[C@@H]1C[C@@H](C1)NC(=O)C1=CC=CC=C1 2.62
# 108 [H]C(F)(F)[C@H]1C[C@@H](C1)NC(=O)C1=CC=CC=C1 1.97
# 109 [H]C(F)(F)[C@@H]1C[C@@H](C1)NC(=O)C1=CC=CC=C1 1.98
# 110 [H]C([H])(F)[C@H]1C[C@@H](C1)NC(=O)C1=CC=CC=C1 1.78
# 111 [H]C([H])(F)[C@@H]1C[C@@H](C1)NC(=O)C1=CC=CC=C1 1.77
# 112 FC(F)(F)C1CCCCN1C(=O)C1=CC=CC=C1 2.54
# 113 [H]C(F)(F)C1CCCCN1C(=O)C1=CC=CC=C1 2.04
# 114 [H]C([H])(F)C1CCCCN1C(=O)C1=CC=CC=C1 2.0
# 115 O=C(N1CCCCC1)C1=CC=CC=C1 1.39
# 116 FC(F)(F)C1CCCN1C(=O)C1=CC=CC=C1 2.12
# 117 [H]C(F)(F)C1CCCN1C(=O)C1=CC=CC=C1 1.88
# 118 [H]C([H])(F)C1CCCN1C(=O)C1=CC=CC=C1 1.75
# 119 O=C(N1CCCC1)C1=CC=CC=C1 1.19
# 120 FC(F)(F)C1CCN1C(=O)C1=CC=CC=C1 1.75
# 121 [H]C(F)(F)C1CCN1C(=O)C1=CC=CC=C1 1.51
# 122 [H]C([H])(F)C1CCN1C(=O)C1=CC=CC=C1 1.4
# 123 O=C(N1CCC1)C1=CC=CC=C1 1.13
# 125 [H]C(F)(F)CNC(=O)C1=CC=CC=C1 1.37
# 128 FC(F)(F)C1CCCN(C1)C(=O)C1=CC=CC=C1 2.21
# 129 [H]C(F)(F)C1CCCN(C1)C(=O)C1=CC=CC=C1 1.73
# 130 [H]C([H])(F)C1CCCN(C1)C(=O)C1=CC=CC=C1 1.52
# 131 FC(F)(F)C1CCN(C1)C(=O)C1=CC=CC=C1 1.7
# 132 [H]C(F)(F)C1CCN(C1)C(=O)C1=CC=CC=C1 1.4
# 134 FC(F)(F)C1CN(C1)C(=O)C1=CC=CC=C1 1.66
# 135 [H]C(F)(F)C1CN(C1)C(=O)C1=CC=CC=C1 1.4
# 138 [H]C(F)(F)CCNC(=O)C1=CC=CC=C1 1.49
# 139 [H]C([H])(F)CCNC(=O)C1=CC=CC=C1 1.28
# 140 CCNC(=O)C1=CC=CC=C1 1.31
# 141 FC(F)(F)C1CCN(CC1)C(=O)C1=CC=CC=C1 2.2
# 143 [H]C([H])(F)C1CCN(CC1)C(=O)C1=CC=CC=C1 1.45
# 144 [H]C([H])(F)CCCNC(=O)C1=CC=CC=C1 1.56
# 145 [H]C(F)(F)CCCNC(=O)C1=CC=CC=C1 1.76
# 146 FC(F)(F)CCCNC(=O)C1=CC=CC=C1 2.28
# 147 CCCNC(=O)C1=CC=CC=C1 1.72
# 150 FC1(F)CC(C1)NC(=O)C1=CC=CC=C1 1.94
# 151 FC1(F)CCCC1NC(=O)C1=CC=CC=C1 1.87
# 153 FC1(F)CCCCC1NC(=O)C1=CC=CC=C1 2.16
# 154 FC1(F)CCCC(C1)NC(=O)C1=CC=CC=C1 2.31
# 155 FC1(F)CCC(CC1)NC(=O)C1=CC=CC=C1 2.32
# 156 FC1(F)CCCCCC1NC(=O)C1=CC=CC=C1 2.56
# 157 FC1(F)CCCCC(C1)NC(=O)C1=CC=CC=C1 2.57
# 158 FC1(F)CCCC(CC1)NC(=O)C1=CC=CC=C1 2.5
# 159 CCC(F)(F)CNC(=O)C1=CC=CC=C1 2.04
# 160 CC(F)(F)CCNC(=O)C1=CC=CC=C1 1.81
# 161 FC(F)CCCNC(=O)C1=CC=CC=C1 1.76
# 162 O=C(NC1CC1)C1=CC=CC=C1 1.29
# 163 O=C(NC1CCCC1)C1=CC=CC=C1 2.23
# 164 O=C(NC1CCCCCC1)C1=CC=CC=C1 3.03
# 165 CCCCNC(=O)C1=CC=CC=C1 2.23
# 166 O=C(NC1CC2(CCC2)C1)C1=CC=CC=C1 3.26
# 169 FC(F)(F)[C@@H]1CC[C@H]1NC(=O)C1=CC=CC=C1 2.54
# 172 FC(F)(F)[C@@H]1C[C@H]1NC(=O)C1=CC=CC=C1 1.79
# 173 FC(F)(F)[C@@H]1C[C@@H]1NC(=O)C1=CC=CC=C1 2.16
# 174 [H]C(F)(F)[C@@H]1C[C@H]1NC(=O)C1=CC=CC=C1 1.64
# 175 [H]C(F)(F)[C@@H]1C[C@@H]1NC(=O)C1=CC=CC=C1 1.36
# 176 C[C@@H]1C[C@H]1NC(=O)C1=CC=CC=C1 1.83
# 177 C[C@@H]1C[C@@H]1NC(=O)C1=CC=CC=C1 1.64
# 180 O=C(NC1CC11CC1)C1=CC=CC=C1 2.08
# 105 O=C(NC1CCC1)C1=CC=CC=C1 1.95
# 16 FC1(F)CC1C(=O)NC1=CC=CC=C1 2.07
# 36 FC1(F)CC2(CC(C2)C(=O)NC2=CC=CC=C2)C1 2.93
# 99 FC1CCN(CC1)C(=O)C1=CC=CC=C1 1.31
# nC                                                        13
# FPSA3                                               0.029613
# nFARing                                                    0
# RPCS                                                     0.0
# dipole_moment                                       0.707067
# angle_R1X1R2                                      116.758869
# nFAHRing                                                   0
# angle_X2X1R1                                      111.411909
# nFHRing                                                    0
# chirality                                                  0
# cis/trans
# nHRing                                                     0
# TASA                                              329.897047
# angle_X1X2R2                                      154.698743
# nO                                                         1
# nF                                                         2
# PNSA5                                             -22.153081
# dihedral_angle                                     176.65806
# f_to_fg                                                  2.0
# nARing                                                     1
# angle_R2X2R1                                      176.494963
# identificator                                Carboxylic acid
# naRing                                                     1
# mol_volume                                             213.1
# mol_weight                                            164.15
# avg_atoms_in_cycle                                       6.0
# mol_num_cycles                                             2
# nAHRing                                                    0
# PBF                                                 0.644373
# nFRing                                                     0
# WPSA5                                                 7.0037
# f_freedom                                                  0
# distance_between_atoms_in_f_group_centers           4.173806
# PPSA5                                              16.161259
# GeomShapeIndex                                       0.87579
# fold_id                                                  NaN
# logP                                                    2.63
# predicted_pKa                                           2.63
# used_for                                       Out of sample
# Name: 0, dtype: object
# 0 FC1(F)CCC(CC1)C(=O)NC1=CC=CC=C1 2.63
# 170 [H]C(F)(F)[C@@H]1CC[C@H]1NC(=O)C1=CC=CC=C1 1.94
# 34 O=C(NC1=CC=CC=C1)C1CC2(CCC2)C1 3.27
# 79 O=C(N1CC2CCCC(C2)C1)C1=CC=CC=C1 2.36
# 86 FC1(F)CCN(CC1)C(=O)C1=CC=CC=C1 1.51
# 142 [H]C(F)(F)C1CCN(CC1)C(=O)C1=CC=CC=C1 1.67
# 50 C[C@@H]1C[C@@H]1C(=O)NC1=CC=CC=C1 2.31
# 137 FC(F)(F)CCNC(=O)C1=CC=CC=C1 1.93
# 38 [H]C(F)(F)C12CC(C1)(OC2)C(=O)NC1=CC=CC=C1 1.93
# 149 FC1(F)CCC1NC(=O)C1=CC=CC=C1 1.7
# 133 [H]C([H])(F)C1CCN(C1)C(=O)C1=CC=CC=C1 1.4
# 89 FC1(F)CN(C1)C(=O)C1=CC=CC=C1 1.34
# 171 [H]C([H])(F)[C@@H]1CC[C@H]1NC(=O)C1=CC=CC=C1 1.85
# 167 FC1CC2(C1)CC(C2)NC(=O)C1=CC=CC=C1 2.39
# 17 FC1(F)CCC1C(=O)NC1=CC=CC=C1 2.03
# 55 FC1(F)[C@H]2C[C@@H](C[C@@H]12)NC(=O)C1=CC=CC=C1 2.23
# 126 [H]C([H])(F)CNC(=O)C1=CC=CC=C1 1.07
# 103 FC(F)C1(CCC1)NC(=O)C1=CC=CC=C1 2.48
# 49 C[C@@H]1C[C@H]1C(=O)NC1=CC=CC=C1 2.42
# 22 FC1(F)CCCC(C1)C(=O)NC1=CC=CC=C1 2.72
# 19 FC1(F)CCCC1C(=O)NC1=CC=CC=C1 2.25
# 21 FC1(F)CCCCC1C(=O)NC1=CC=CC=C1 2.5
# 23 FC1(F)CCCCCC1C(=O)NC1=CC=CC=C1 2.9
# 61 FC(F)(F)C12CC(C1)CN2C(=O)C1=CC=CC=C1 1.93
# 66 FC(F)(F)C12CCC(CN1C(=O)C1=CC=CC=C1)C2 2.2
# 67 FC(F)(F)C12CCC(CC1)CN2C(=O)C1=CC=CC=C1 2.51
# 73 FC(F)(F)C12CC(CN1C(=O)C1=CC=CC=C1)CCC2 2.67
# 82 O=C(N1CC2CC(C1)CS(=O)(=O)C2)C1=CC=CC=C1 -0.34
# 83 FC1(F)C2CN(CC1CS(=O)(=O)C2)C(=O)C1=CC=CC=C1 0.2
# 124 FC(F)(F)CNC(=O)C1=CC=CC=C1 1.76
# 127 CNC(=O)C1=CC=CC=C1 1.03
# 136 [H]C([H])(F)C1CN(C1)C(=O)C1=CC=CC=C1 0.93
# 168 FC1(F)CC2(CC(C2)NC(=O)C2=CC=CC=C2)C1 2.53
# 182 FC1(F)CC11CC1NC(=O)C1=CC=CC=C1 2.04
# 152 FC1(F)CCC(C1)NC(=O)C1=CC=CC=C1 2.02
# 27 CC(F)(F)CCC(=O)NC1=CC=CC=C1 2.12

# %%
df_combined.sort_index(inplace=True)

# %%
df_combined
# Out:
#      nC     FPSA3  nFARing       RPCS  dipole_moment  angle_R1X1R2  nFAHRing  \
# 0    13  0.029613        0   0.000000       0.707067    116.758869         0
# 1    13  0.033183        0  27.282695       0.507854           NaN         0
# 2    13  0.029652        1  16.638718       0.501031           NaN         0
# 3    13  0.032625        1  20.164804       0.505852           NaN         0
# 4    13  0.030749        1  11.184998       0.493885    103.610503         0
# ..   ..       ...      ...        ...            ...           ...       ...
# 175  11  0.034830        0  44.792851       0.473569     93.627775         0
# 176  11  0.033483        0  34.695093       0.449349           NaN         0
# 177  11  0.032038        0  36.029520       0.454426           NaN         0
# 180  12  0.033000        0  35.464215       0.457185           NaN         0
# 182  12  0.030327        0  13.388847       0.967361    138.812664         0
#
#      angle_X2X1R1  nFHRing  chirality  ...     WPSA5  f_freedom  \
# 0      111.411909        0          0  ...  7.003700          0
# 1             NaN        0          0  ...  6.805737          1
# 2             NaN        0          3  ...  6.398578          1
# 3             NaN        0          3  ...  6.565329          1
# 4      111.876204        0          3  ...  7.112882          0
# ..            ...      ...        ...  ...       ...        ...
# 175    122.429092        0          2  ...  6.974581          1
# 176           NaN        0          2  ...  5.894519          1
# 177           NaN        0          2  ...  6.056597          1
# 180           NaN        0          0  ...  6.269730          1
# 182    131.978026        0          0  ...  7.206489          0
#
#      distance_between_atoms_in_f_group_centers      PPSA5  GeomShapeIndex  \
# 0                                     4.173806  16.161259        0.875790
# 1                                          NaN  16.178954        0.860000
# 2                                          NaN  15.488153        0.958274
# 3                                          NaN  15.945793        0.754336
# 4                                     4.245568  16.472886        0.891772
# ..                                         ...        ...             ...
# 175                                   2.671617  17.390764        0.761236
# 176                                        NaN  15.156861        0.887202
# 177                                        NaN  15.457994        0.782160
# 180                                        NaN  15.517112        0.797100
# 182                                   4.985153  16.898148        0.802947
#
#      fold_id  logP  predicted_pKa       used_for  \
# 0        NaN  2.63           2.63  Out of sample
# 1        1.0  2.88           2.92          Train
# 2        0.0  2.87           3.09          Train
# 3        1.0  2.92           3.06          Train
# 4        1.0  2.37           2.58          Train
# ..       ...   ...            ...            ...
# 175      1.0  1.36           1.36          Train
# 176      0.0  1.83           1.83          Train
# 177      1.0  1.64           1.65          Train
# 180      1.0  2.08           2.10          Train
# 182      1.0  2.04           2.15       outliers
#
#                                              smiles
# 0                   FC1(F)CCC(CC1)C(=O)NC1=CC=CC=C1
# 1                         O=C(NC1=CC=CC=C1)C1CCCCC1
# 2         O=C(NC1=CC=CC=C1)[C@H]1C[C@@H]2C[C@@H]2C1
# 3        O=C(NC1=CC=CC=C1)[C@@H]1C[C@@H]2C[C@@H]2C1
# 4    FC1(F)[C@H]2C[C@H](C[C@@H]12)C(=O)NC1=CC=CC=C1
# ..                                              ...
# 175      [H]C(F)(F)[C@@H]1C[C@@H]1NC(=O)C1=CC=CC=C1
# 176                C[C@@H]1C[C@H]1NC(=O)C1=CC=CC=C1
# 177               C[C@@H]1C[C@@H]1NC(=O)C1=CC=CC=C1
# 180                      O=C(NC1CC11CC1)C1=CC=CC=C1
# 182                  FC1(F)CC11CC1NC(=O)C1=CC=CC=C1
#
# [178 rows x 40 columns]

# %%
df_combined.to_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\csv_for_analyse\logP_analyse.csv')
