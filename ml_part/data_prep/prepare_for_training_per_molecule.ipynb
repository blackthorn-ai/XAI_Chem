# %%
from rdkit import Chem

def convert_to_canon(smi):
    try:
        canon_smi = Chem.CanonSmiles(smi)
    except:
        canon_smi = smi
    return canon_smi

# %%
import pandas as pd

train_df = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\logP_lipophilicity_data\gnn_cv\train.csv', index_col=0)
test_df = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\logP_lipophilicity_data\gnn_cv\test.csv', index_col=0)

df = pd.concat([train_df, test_df], axis=0)
df['Smiles'] = df['Smiles'].apply(convert_to_canon)

# %%
df_init = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\init_data\pKa_Prediction_Starting data_2024.01.25.csv', index_col=0)

df_init['Amides for LogP'] = df_init['Amides for LogP'].apply(convert_to_canon)

# %%
SMILES_to_functional_group = {}

for index, row in df_init.iterrows():
    if pd.isnull(row['Smiles']):
        continue

    SMILES_to_functional_group[row['Amides for LogP']] = row['F group']

# %%
functional_group_to_smiles = {
    "CF3": "C(F)(F)F", 
    "CH2F": "CF", 
    "gem-CF2": "F", 
    "CHF2": "C(F)(F)",
    "CHF": "F",
    "non-F": ""
}

# %%
from rdkit import Chem

def remove_functional_group_from_smiles(smiles, f_group):
    f_group_smiles = functional_group_to_smiles[f_group]

    mol = Chem.MolFromSmiles(smiles)
    mol_f_group = Chem.MolFromSmiles(f_group_smiles)

    if mol.HasSubstructMatch(mol_f_group):
        mol = Chem.DeleteSubstructs(mol, mol_f_group)

    smiles_without_group = Chem.MolToSmiles(mol)
    return Chem.CanonSmiles(smiles_without_group)

canon_smiles = []
functional_groups = []
smiles_with_removed_flurine = []
for SMILES in df['Smiles']:
    functional_group = SMILES_to_functional_group[SMILES]
    functional_groups.append(functional_group)

    canon_smile = Chem.CanonSmiles(SMILES)
    canon_smiles.append(canon_smile)
    
    SMILES_without_fluorine_group = remove_functional_group_from_smiles(smiles=canon_smile, f_group=functional_group)
    smiles_with_removed_flurine.append(SMILES_without_fluorine_group)

df['Smiles'] = canon_smiles
df['F group'] = functional_groups
df['non-F Smiles'] = smiles_with_removed_flurine

# %%
main_df_for_train = df.copy()

# %%
main_df_for_train
# Out:
#      fold_id  logP                                        Smiles  F group  \
# 1        0.0  2.88                        O=C(Nc1ccccc1)C1CCCCC1    non-F
# 2        1.0  2.87        O=C(Nc1ccccc1)[C@H]1C[C@@H]2C[C@@H]2C1    non-F
# 3        1.0  2.92       O=C(Nc1ccccc1)[C@@H]1C[C@@H]2C[C@@H]2C1    non-F
# 4        0.0  2.37   O=C(Nc1ccccc1)[C@H]1C[C@@H]2[C@H](C1)C2(F)F  gem-CF2
# 5        0.0  2.88  O=C(Nc1ccccc1)[C@@H]1C[C@@H]2[C@H](C1)C2(F)F  gem-CF2
# ..       ...   ...                                           ...      ...
# 126      NaN  1.07                             O=C(NCCF)c1ccccc1     CH2F
# 103      NaN  2.48                   O=C(NC1(C(F)F)CCC1)c1ccccc1     CHF2
# 49       NaN  2.42                 C[C@@H]1C[C@H]1C(=O)Nc1ccccc1    non-F
# 22       NaN  2.72                  O=C(Nc1ccccc1)C1CCCC(F)(F)C1  gem-CF2
# 27       NaN  2.12                      CC(F)(F)CCC(=O)Nc1ccccc1  gem-CF2
#
#                                 non-F Smiles
# 1                     O=C(Nc1ccccc1)C1CCCCC1
# 2     O=C(Nc1ccccc1)[C@H]1C[C@@H]2C[C@@H]2C1
# 3    O=C(Nc1ccccc1)[C@@H]1C[C@@H]2C[C@@H]2C1
# 4    O=C(Nc1ccccc1)[C@@H]1C[C@@H]2C[C@@H]2C1
# 5     O=C(Nc1ccccc1)[C@H]1C[C@@H]2C[C@@H]2C1
# ..                                       ...
# 126                          CNC(=O)c1ccccc1
# 103                     O=C(NC1CCC1)c1ccccc1
# 49             C[C@@H]1C[C@H]1C(=O)Nc1ccccc1
# 22                    O=C(Nc1ccccc1)C1CCCCC1
# 27                        CCCCC(=O)Nc1ccccc1
#
# [172 rows x 5 columns]

# %%
index_to_remain = []
for index_non_F, row_non_F in main_df_for_train.iterrows():
    SMILES_to_find = row_non_F['non-F Smiles']
    is_on_train = False
     
    for index, row in main_df_for_train.iterrows():
        if row['Smiles'] == SMILES_to_find:
            is_on_train = True
    
    # if row_non_F['F group'] != 'non-F':
    index_to_remain.append(index_non_F)
        # print(row_non_F['Smiles'], SMILES_to_find, row_non_F['F group'], is_on_train)

# %%
df_for_train = main_df_for_train.copy().loc[index_to_remain]

for index, row in df_for_train.iterrows():
    SMILES = row['Smiles']
    SMILES_non_F = row['non-F Smiles']

    indexes_to_remove = []
    for index_train, row_train in df.iterrows():
        if row_train['Smiles'] == SMILES:
            indexes_to_remove.append(index_train)
        if row_train['Smiles'] == SMILES_non_F and SMILES_non_F != SMILES:
            indexes_to_remove.append(index_train)
    
    print(indexes_to_remove)
    df_train = df.drop(indexes_to_remove, axis=0, inplace=False)
    df_test = df.loc[indexes_to_remove]

    print(df_test['F group'].unique())

    # break
# Out:
# [1]
# ['non-F']
# [2]
# ['non-F']
# [3]
# ['non-F']
# [3, 4]
# ['non-F' 'gem-CF2']
# [2, 5]
# ['non-F' 'gem-CF2']
# [6, 30]
# ['non-F']
# [6, 7, 30]
# ['non-F' 'CH2F']
# [6, 8, 30]
# ['non-F' 'CHF2']
# [6, 9, 30]
# ['non-F' 'CF3']
# [6, 10, 30]
# ['non-F' 'CF3']
# [6, 11, 30]
# ['non-F' 'CF3']
# [6, 12, 30]
# ['non-F' 'CHF2']
# [6, 13, 30]
# ['non-F' 'CHF2']
# [6, 14, 30]
# ['non-F' 'CH2F']
# [6, 15, 30]
# ['non-F' 'CH2F']
# [6, 18, 30]
# ['non-F' 'gem-CF2']
# [19, 31]
# ['gem-CF2' 'non-F']
# [20, 31]
# ['gem-CF2' 'non-F']
# [1, 21]
# ['non-F' 'gem-CF2']
# [23, 32]
# ['gem-CF2' 'non-F']
# [24, 32]
# ['gem-CF2' 'non-F']
# [25, 32]
# ['gem-CF2' 'non-F']
# [26, 33]
# ['gem-CF2' 'non-F']
# [28]
# ['CHF2']
# [29]
# ['non-F']
# [6, 30]
# ['non-F']
# [31]
# ['non-F']
# [32]
# ['non-F']
# [33]
# ['non-F']
# [37, 39]
# ['CF3' 'non-F']
# [39]
# ['non-F']
# [40]
# ['non-F']
# [6, 30, 41]
# ['non-F' 'CF3']
# [6, 30, 42]
# ['non-F' 'CHF2']
# [6, 30, 43]
# ['non-F' 'CH2F']
# [29, 44]
# ['non-F' 'CF3']
# [29, 45]
# ['non-F' 'CF3']
# [29, 46]
# ['non-F' 'CHF2']
# [29, 47]
# ['non-F' 'CHF2']
# [29, 48]
# ['non-F' 'CH2F']
# [52]
# ['non-F']
# [52, 53]
# ['non-F' 'gem-CF2']
# [52, 54]
# ['non-F' 'gem-CF2']
# [56, 59]
# ['gem-CF2' 'non-F']
# [57, 58, 155]
# ['gem-CF2' 'non-F']
# [58]
# ['non-F']
# [59]
# ['non-F']
# [60]
# ['non-F']
# [61, 63]
# ['CF3' 'non-F']
# [62, 64, 90, 116, 119]
# ['CF3' 'non-F']
# [63]
# ['non-F']
# [64, 90, 119]
# ['non-F']
# [65]
# ['non-F']
# [66, 69]
# ['CF3' 'non-F']
# [67, 71]
# ['CF3' 'non-F']
# [68, 72, 112, 115]
# ['CF3' 'non-F']
# [69]
# ['non-F']
# [70]
# ['non-F']
# [71]
# ['non-F']
# [72, 115]
# ['non-F']
# [73, 74]
# ['CF3' 'non-F']
# [74]
# ['non-F']
# [75]
# ['non-F']
# [76, 79]
# ['gem-CF2' 'non-F']
# [77, 79]
# ['gem-CF2' 'non-F']
# [78, 79]
# ['gem-CF2' 'non-F']
# [80, 81]
# ['gem-CF2' 'non-F']
# [81]
# ['non-F']
# [84, 85]
# ['gem-CF2' 'non-F']
# [85]
# ['non-F']
# [87, 123]
# ['non-F']
# [87, 88, 123]
# ['non-F' 'CHF']
# [64, 90, 119]
# ['non-F']
# [64, 90, 91, 119]
# ['non-F' 'CHF']
# [64, 90, 92, 119]
# ['non-F' 'gem-CF2']
# [64, 90, 93, 119]
# ['non-F' 'CHF']
# [64, 90, 94, 119]
# ['non-F' 'CHF']
# [72, 95, 115]
# ['non-F' 'CHF']
# [72, 96, 115]
# ['non-F' 'gem-CF2']
# [72, 97, 115]
# ['non-F' 'CHF']
# [72, 98, 115]
# ['non-F' 'CHF']
# [72, 100, 115]
# ['non-F' 'CHF']
# [72, 101, 115]
# ['non-F' 'CHF']
# [102, 105]
# ['CF3' 'non-F']
# [104, 105]
# ['CH2F' 'non-F']
# [106, 105]
# ['CF3' 'non-F']
# [107, 105]
# ['CF3' 'non-F']
# [108, 105]
# ['CHF2' 'non-F']
# [109, 105]
# ['CHF2' 'non-F']
# [110, 105]
# ['CH2F' 'non-F']
# [111, 105]
# ['CH2F' 'non-F']
# [68, 72, 112, 115]
# ['CF3' 'non-F']
# [72, 113, 115]
# ['non-F' 'CHF2']
# [72, 114, 115]
# ['non-F' 'CH2F']
# [72, 115]
# ['non-F']
# [62, 64, 90, 116, 119]
# ['CF3' 'non-F']
# [64, 90, 117, 119]
# ['non-F' 'CHF2']
# [64, 90, 118, 119]
# ['non-F' 'CH2F']
# [64, 90, 119]
# ['non-F']
# [87, 120, 123]
# ['non-F' 'CF3']
# [87, 121, 123]
# ['non-F' 'CHF2']
# [87, 122, 123]
# ['non-F' 'CH2F']
# [87, 123]
# ['non-F']
# [125]
# ['CHF2']
# [72, 115, 128]
# ['non-F' 'CF3']
# [72, 115, 129]
# ['non-F' 'CHF2']
# [72, 115, 130]
# ['non-F' 'CH2F']
# [64, 90, 119, 131]
# ['non-F' 'CF3']
# [64, 90, 119, 132]
# ['non-F' 'CHF2']
# [87, 123, 134]
# ['non-F' 'CF3']
# [87, 123, 135]
# ['non-F' 'CHF2']
# [87, 123, 136]
# ['non-F' 'CH2F']
# [138, 140]
# ['CHF2' 'non-F']
# [139, 140]
# ['CH2F' 'non-F']
# [140]
# ['non-F']
# [72, 115, 141]
# ['non-F' 'CF3']
# [72, 115, 143]
# ['non-F' 'CH2F']
# [144, 147]
# ['CH2F' 'non-F']
# [145, 147, 161]
# ['CHF2' 'non-F']
# [146, 147]
# ['CF3' 'non-F']
# [147]
# ['non-F']
# [150, 105]
# ['gem-CF2' 'non-F']
# [151, 163]
# ['gem-CF2' 'non-F']
# [58, 153]
# ['non-F' 'gem-CF2']
# [58, 154]
# ['non-F' 'gem-CF2']
# [57, 58, 155]
# ['gem-CF2' 'non-F']
# [156, 164]
# ['gem-CF2' 'non-F']
# [157, 164]
# ['gem-CF2' 'non-F']
# [158, 164]
# ['gem-CF2' 'non-F']
# [159, 165]
# ['gem-CF2' 'non-F']
# [160, 165]
# ['gem-CF2' 'non-F']
# [145, 147, 161]
# ['CHF2' 'non-F']
# [162]
# ['non-F']
# [163]
# ['non-F']
# [164]
# ['non-F']
# [165]
# ['non-F']
# [166]
# ['non-F']
# [166, 168]
# ['non-F' 'gem-CF2']
# [169, 105]
# ['CF3' 'non-F']
# [162, 172]
# ['non-F' 'CF3']
# [162, 173]
# ['non-F' 'CF3']
# [162, 174]
# ['non-F' 'CHF2']
# [162, 175]
# ['non-F' 'CHF2']
# [176]
# ['non-F']
# [177]
# ['non-F']
# [180]
# ['non-F']
# [180, 182]
# ['non-F' 'gem-CF2']
# [105]
# ['non-F']
# [29, 16]
# ['non-F' 'gem-CF2']
# [36, 34]
# ['gem-CF2' 'non-F']
# [72, 115, 99]
# ['non-F' 'CHF']
# [1, 0]
# ['non-F' 'gem-CF2']
# [105, 170]
# ['non-F' 'CHF2']
# [34]
# ['non-F']
# [79]
# ['non-F']
# [72, 115, 86]
# ['non-F' 'gem-CF2']
# [72, 115, 142]
# ['non-F' 'CHF2']
# [50]
# ['non-F']
# [140, 137]
# ['non-F' 'CF3']
# [39, 38]
# ['non-F' 'CHF2']
# [105, 149]
# ['non-F' 'gem-CF2']
# [64, 90, 119, 133]
# ['non-F' 'CH2F']
# [87, 123, 89]
# ['non-F' 'gem-CF2']
# [163, 152]
# ['non-F' 'gem-CF2']
# [105, 171]
# ['non-F' 'CH2F']
# [6, 30, 17]
# ['non-F' 'gem-CF2']
# [60, 55]
# ['non-F' 'gem-CF2']
# [126]
# ['CH2F']
# [105, 103]
# ['non-F' 'CHF2']
# [49]
# ['non-F']
# [1, 22]
# ['non-F' 'gem-CF2']
# [33, 27]
# ['non-F' 'gem-CF2']

# %%
df_for_train
# Out:
#      fold_id  logP                                        Smiles  F group  \
# 1        0.0  2.88                        O=C(Nc1ccccc1)C1CCCCC1    non-F
# 2        1.0  2.87        O=C(Nc1ccccc1)[C@H]1C[C@@H]2C[C@@H]2C1    non-F
# 3        1.0  2.92       O=C(Nc1ccccc1)[C@@H]1C[C@@H]2C[C@@H]2C1    non-F
# 4        0.0  2.37   O=C(Nc1ccccc1)[C@H]1C[C@@H]2[C@H](C1)C2(F)F  gem-CF2
# 5        0.0  2.88  O=C(Nc1ccccc1)[C@@H]1C[C@@H]2[C@H](C1)C2(F)F  gem-CF2
# ..       ...   ...                                           ...      ...
# 126      NaN  1.07                             O=C(NCCF)c1ccccc1     CH2F
# 103      NaN  2.48                   O=C(NC1(C(F)F)CCC1)c1ccccc1     CHF2
# 49       NaN  2.42                 C[C@@H]1C[C@H]1C(=O)Nc1ccccc1    non-F
# 22       NaN  2.72                  O=C(Nc1ccccc1)C1CCCC(F)(F)C1  gem-CF2
# 27       NaN  2.12                      CC(F)(F)CCC(=O)Nc1ccccc1  gem-CF2
#
#                                 non-F Smiles
# 1                     O=C(Nc1ccccc1)C1CCCCC1
# 2     O=C(Nc1ccccc1)[C@H]1C[C@@H]2C[C@@H]2C1
# 3    O=C(Nc1ccccc1)[C@@H]1C[C@@H]2C[C@@H]2C1
# 4    O=C(Nc1ccccc1)[C@@H]1C[C@@H]2C[C@@H]2C1
# 5     O=C(Nc1ccccc1)[C@H]1C[C@@H]2C[C@@H]2C1
# ..                                       ...
# 126                          CNC(=O)c1ccccc1
# 103                     O=C(NC1CCC1)c1ccccc1
# 49             C[C@@H]1C[C@H]1C(=O)Nc1ccccc1
# 22                    O=C(Nc1ccccc1)C1CCCCC1
# 27                        CCCCC(=O)Nc1ccccc1
#
# [172 rows x 5 columns]

# %%
df_for_train.to_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\logP_lipophilicity_data\gnn_cv\train_test_for_SMILES_per_model.csv')

# %%
df_for_train = main_df_for_train.copy().loc[index_to_remain]

for index, row in df_for_train.iterrows():
    SMILES = row['Smiles']
    SMILES_non_F = row['non-F Smiles']

    indexes_to_remove = []
    for index_train, row_train in df.iterrows():
        if row_train['Smiles'] == SMILES:
            indexes_to_remove.append(index_train)
        if row_train['Smiles'] == SMILES_non_F and SMILES_non_F != SMILES:
            indexes_to_remove.append(index_train)
    
    print(indexes_to_remove)
    df_train = df.drop(indexes_to_remove, axis=0, inplace=False)
    df_test = df.loc[indexes_to_remove]

    print(df_test['F group'].unique())

    # break
# Out:
# [1]
# ['non-F']
# [2]
# ['non-F']
# [3]
# ['non-F']
# [3, 4]
# ['non-F' 'gem-CF2']
# [2, 5]
# ['non-F' 'gem-CF2']
# [6, 30]
# ['non-F']
# [6, 7, 30]
# ['non-F' 'CH2F']
# [6, 8, 30]
# ['non-F' 'CHF2']
# [6, 9, 30]
# ['non-F' 'CF3']
# [6, 10, 30]
# ['non-F' 'CF3']
# [6, 11, 30]
# ['non-F' 'CF3']
# [6, 12, 30]
# ['non-F' 'CHF2']
# [6, 13, 30]
# ['non-F' 'CHF2']
# [6, 14, 30]
# ['non-F' 'CH2F']
# [6, 15, 30]
# ['non-F' 'CH2F']
# [6, 18, 30]
# ['non-F' 'gem-CF2']
# [19, 31]
# ['gem-CF2' 'non-F']
# [20, 31]
# ['gem-CF2' 'non-F']
# [1, 21]
# ['non-F' 'gem-CF2']
# [23, 32]
# ['gem-CF2' 'non-F']
# [24, 32]
# ['gem-CF2' 'non-F']
# [25, 32]
# ['gem-CF2' 'non-F']
# [26, 33]
# ['gem-CF2' 'non-F']
# [28]
# ['CHF2']
# [29]
# ['non-F']
# [6, 30]
# ['non-F']
# [31]
# ['non-F']
# [32]
# ['non-F']
# [33]
# ['non-F']
# [37, 39]
# ['CF3' 'non-F']
# [39]
# ['non-F']
# [40]
# ['non-F']
# [6, 30, 41]
# ['non-F' 'CF3']
# [6, 30, 42]
# ['non-F' 'CHF2']
# [6, 30, 43]
# ['non-F' 'CH2F']
# [29, 44]
# ['non-F' 'CF3']
# [29, 45]
# ['non-F' 'CF3']
# [29, 46]
# ['non-F' 'CHF2']
# [29, 47]
# ['non-F' 'CHF2']
# [29, 48]
# ['non-F' 'CH2F']
# [52]
# ['non-F']
# [52, 53]
# ['non-F' 'gem-CF2']
# [52, 54]
# ['non-F' 'gem-CF2']
# [56, 59]
# ['gem-CF2' 'non-F']
# [57, 58, 155]
# ['gem-CF2' 'non-F']
# [58]
# ['non-F']
# [59]
# ['non-F']
# [60]
# ['non-F']
# [61, 63]
# ['CF3' 'non-F']
# [62, 64, 90, 116, 119]
# ['CF3' 'non-F']
# [63]
# ['non-F']
# [64, 90, 119]
# ['non-F']
# [65]
# ['non-F']
# [66, 69]
# ['CF3' 'non-F']
# [67, 71]
# ['CF3' 'non-F']
# [68, 72, 112, 115]
# ['CF3' 'non-F']
# [69]
# ['non-F']
# [70]
# ['non-F']
# [71]
# ['non-F']
# [72, 115]
# ['non-F']
# [73, 74]
# ['CF3' 'non-F']
# [74]
# ['non-F']
# [75]
# ['non-F']
# [76, 79]
# ['gem-CF2' 'non-F']
# [77, 79]
# ['gem-CF2' 'non-F']
# [78, 79]
# ['gem-CF2' 'non-F']
# [80, 81]
# ['gem-CF2' 'non-F']
# [81]
# ['non-F']
# [84, 85]
# ['gem-CF2' 'non-F']
# [85]
# ['non-F']
# [87, 123]
# ['non-F']
# [87, 88, 123]
# ['non-F' 'CHF']
# [64, 90, 119]
# ['non-F']
# [64, 90, 91, 119]
# ['non-F' 'CHF']
# [64, 90, 92, 119]
# ['non-F' 'gem-CF2']
# [64, 90, 93, 119]
# ['non-F' 'CHF']
# [64, 90, 94, 119]
# ['non-F' 'CHF']
# [72, 95, 115]
# ['non-F' 'CHF']
# [72, 96, 115]
# ['non-F' 'gem-CF2']
# [72, 97, 115]
# ['non-F' 'CHF']
# [72, 98, 115]
# ['non-F' 'CHF']
# [72, 100, 115]
# ['non-F' 'CHF']
# [72, 101, 115]
# ['non-F' 'CHF']
# [102, 105]
# ['CF3' 'non-F']
# [104, 105]
# ['CH2F' 'non-F']
# [106, 105]
# ['CF3' 'non-F']
# [107, 105]
# ['CF3' 'non-F']
# [108, 105]
# ['CHF2' 'non-F']
# [109, 105]
# ['CHF2' 'non-F']
# [110, 105]
# ['CH2F' 'non-F']
# [111, 105]
# ['CH2F' 'non-F']
# [68, 72, 112, 115]
# ['CF3' 'non-F']
# [72, 113, 115]
# ['non-F' 'CHF2']
# [72, 114, 115]
# ['non-F' 'CH2F']
# [72, 115]
# ['non-F']
# [62, 64, 90, 116, 119]
# ['CF3' 'non-F']
# [64, 90, 117, 119]
# ['non-F' 'CHF2']
# [64, 90, 118, 119]
# ['non-F' 'CH2F']
# [64, 90, 119]
# ['non-F']
# [87, 120, 123]
# ['non-F' 'CF3']
# [87, 121, 123]
# ['non-F' 'CHF2']
# [87, 122, 123]
# ['non-F' 'CH2F']
# [87, 123]
# ['non-F']
# [125]
# ['CHF2']
# [72, 115, 128]
# ['non-F' 'CF3']
# [72, 115, 129]
# ['non-F' 'CHF2']
# [72, 115, 130]
# ['non-F' 'CH2F']
# [64, 90, 119, 131]
# ['non-F' 'CF3']
# [64, 90, 119, 132]
# ['non-F' 'CHF2']
# [87, 123, 134]
# ['non-F' 'CF3']
# [87, 123, 135]
# ['non-F' 'CHF2']
# [87, 123, 136]
# ['non-F' 'CH2F']
# [138, 140]
# ['CHF2' 'non-F']
# [139, 140]
# ['CH2F' 'non-F']
# [140]
# ['non-F']
# [72, 115, 141]
# ['non-F' 'CF3']
# [72, 115, 143]
# ['non-F' 'CH2F']
# [144, 147]
# ['CH2F' 'non-F']
# [145, 147, 161]
# ['CHF2' 'non-F']
# [146, 147]
# ['CF3' 'non-F']
# [147]
# ['non-F']
# [150, 105]
# ['gem-CF2' 'non-F']
# [151, 163]
# ['gem-CF2' 'non-F']
# [58, 153]
# ['non-F' 'gem-CF2']
# [58, 154]
# ['non-F' 'gem-CF2']
# [57, 58, 155]
# ['gem-CF2' 'non-F']
# [156, 164]
# ['gem-CF2' 'non-F']
# [157, 164]
# ['gem-CF2' 'non-F']
# [158, 164]
# ['gem-CF2' 'non-F']
# [159, 165]
# ['gem-CF2' 'non-F']
# [160, 165]
# ['gem-CF2' 'non-F']
# [145, 147, 161]
# ['CHF2' 'non-F']
# [162]
# ['non-F']
# [163]
# ['non-F']
# [164]
# ['non-F']
# [165]
# ['non-F']
# [166]
# ['non-F']
# [166, 168]
# ['non-F' 'gem-CF2']
# [169, 105]
# ['CF3' 'non-F']
# [162, 172]
# ['non-F' 'CF3']
# [162, 173]
# ['non-F' 'CF3']
# [162, 174]
# ['non-F' 'CHF2']
# [162, 175]
# ['non-F' 'CHF2']
# [176]
# ['non-F']
# [177]
# ['non-F']
# [180]
# ['non-F']
# [180, 182]
# ['non-F' 'gem-CF2']
# [105]
# ['non-F']
# [29, 16]
# ['non-F' 'gem-CF2']
# [36, 34]
# ['gem-CF2' 'non-F']
# [72, 115, 99]
# ['non-F' 'CHF']
# [1, 0]
# ['non-F' 'gem-CF2']
# [105, 170]
# ['non-F' 'CHF2']
# [34]
# ['non-F']
# [79]
# ['non-F']
# [72, 115, 86]
# ['non-F' 'gem-CF2']
# [72, 115, 142]
# ['non-F' 'CHF2']
# [50]
# ['non-F']
# [140, 137]
# ['non-F' 'CF3']
# [39, 38]
# ['non-F' 'CHF2']
# [105, 149]
# ['non-F' 'gem-CF2']
# [64, 90, 119, 133]
# ['non-F' 'CH2F']
# [87, 123, 89]
# ['non-F' 'gem-CF2']
# [163, 152]
# ['non-F' 'gem-CF2']
# [105, 171]
# ['non-F' 'CH2F']
# [6, 30, 17]
# ['non-F' 'gem-CF2']
# [60, 55]
# ['non-F' 'gem-CF2']
# [126]
# ['CH2F']
# [105, 103]
# ['non-F' 'CHF2']
# [49]
# ['non-F']
# [1, 22]
# ['non-F' 'gem-CF2']
# [33, 27]
# ['non-F' 'gem-CF2']

# %%
df_for_train = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\logP_lipophilicity_data\gnn_cv\train_test_for_SMILES_per_model.csv', index_col=0)

# %%
df_for_train
# Out:
#      fold_id  logP                                        Smiles  F group  \
# 1        0.0  2.88                        O=C(Nc1ccccc1)C1CCCCC1    non-F
# 2        1.0  2.87        O=C(Nc1ccccc1)[C@H]1C[C@@H]2C[C@@H]2C1    non-F
# 3        1.0  2.92       O=C(Nc1ccccc1)[C@@H]1C[C@@H]2C[C@@H]2C1    non-F
# 4        0.0  2.37   O=C(Nc1ccccc1)[C@H]1C[C@@H]2[C@H](C1)C2(F)F  gem-CF2
# 5        0.0  2.88  O=C(Nc1ccccc1)[C@@H]1C[C@@H]2[C@H](C1)C2(F)F  gem-CF2
# ..       ...   ...                                           ...      ...
# 126      NaN  1.07                             O=C(NCCF)c1ccccc1     CH2F
# 103      NaN  2.48                   O=C(NC1(C(F)F)CCC1)c1ccccc1     CHF2
# 49       NaN  2.42                 C[C@@H]1C[C@H]1C(=O)Nc1ccccc1    non-F
# 22       NaN  2.72                  O=C(Nc1ccccc1)C1CCCC(F)(F)C1  gem-CF2
# 27       NaN  2.12                      CC(F)(F)CCC(=O)Nc1ccccc1  gem-CF2
#
#                                 non-F Smiles
# 1                     O=C(Nc1ccccc1)C1CCCCC1
# 2     O=C(Nc1ccccc1)[C@H]1C[C@@H]2C[C@@H]2C1
# 3    O=C(Nc1ccccc1)[C@@H]1C[C@@H]2C[C@@H]2C1
# 4    O=C(Nc1ccccc1)[C@@H]1C[C@@H]2C[C@@H]2C1
# 5     O=C(Nc1ccccc1)[C@H]1C[C@@H]2C[C@@H]2C1
# ..                                       ...
# 126                          CNC(=O)c1ccccc1
# 103                     O=C(NC1CCC1)c1ccccc1
# 49             C[C@@H]1C[C@H]1C(=O)Nc1ccccc1
# 22                    O=C(Nc1ccccc1)C1CCCCC1
# 27                        CCCCC(=O)Nc1ccccc1
#
# [172 rows x 5 columns]

# %%
df_for_train = main_df_for_train.copy().loc[index_to_remain]

for index, row in df_for_train.iterrows():
    SMILES = row['Smiles']
    SMILES_non_F = row['non-F Smiles']

    indexes_to_remove = []
    for index_train, row_train in df.iterrows():
        if row_train['Smiles'] == SMILES:
            indexes_to_remove.append(index_train)
        if row_train['Smiles'] == SMILES_non_F and SMILES_non_F != SMILES:
            indexes_to_remove.append(index_train)
    
    print(indexes_to_remove)
    df_train = df.drop(indexes_to_remove, axis=0, inplace=False)
    df_test = df.loc[indexes_to_remove]

    print(df_test['F group'].unique())

    # break
# Out:
# [1]
# ['non-F']
# [2]
# ['non-F']
# [3]
# ['non-F']
# [3, 4]
# ['non-F' 'gem-CF2']
# [2, 5]
# ['non-F' 'gem-CF2']
# [6, 30]
# ['non-F']
# [6, 7, 30]
# ['non-F' 'CH2F']
# [6, 8, 30]
# ['non-F' 'CHF2']
# [6, 9, 30]
# ['non-F' 'CF3']
# [6, 10, 30]
# ['non-F' 'CF3']
# [6, 11, 30]
# ['non-F' 'CF3']
# [6, 12, 30]
# ['non-F' 'CHF2']
# [6, 13, 30]
# ['non-F' 'CHF2']
# [6, 14, 30]
# ['non-F' 'CH2F']
# [6, 15, 30]
# ['non-F' 'CH2F']
# [6, 18, 30]
# ['non-F' 'gem-CF2']
# [19, 31]
# ['gem-CF2' 'non-F']
# [20, 31]
# ['gem-CF2' 'non-F']
# [1, 21]
# ['non-F' 'gem-CF2']
# [23, 32]
# ['gem-CF2' 'non-F']
# [24, 32]
# ['gem-CF2' 'non-F']
# [25, 32]
# ['gem-CF2' 'non-F']
# [26, 33]
# ['gem-CF2' 'non-F']
# [28]
# ['CHF2']
# [29]
# ['non-F']
# [6, 30]
# ['non-F']
# [31]
# ['non-F']
# [32]
# ['non-F']
# [33]
# ['non-F']
# [37, 39]
# ['CF3' 'non-F']
# [39]
# ['non-F']
# [40]
# ['non-F']
# [6, 30, 41]
# ['non-F' 'CF3']
# [6, 30, 42]
# ['non-F' 'CHF2']
# [6, 30, 43]
# ['non-F' 'CH2F']
# [29, 44]
# ['non-F' 'CF3']
# [29, 45]
# ['non-F' 'CF3']
# [29, 46]
# ['non-F' 'CHF2']
# [29, 47]
# ['non-F' 'CHF2']
# [29, 48]
# ['non-F' 'CH2F']
# [52]
# ['non-F']
# [52, 53]
# ['non-F' 'gem-CF2']
# [52, 54]
# ['non-F' 'gem-CF2']
# [56, 59]
# ['gem-CF2' 'non-F']
# [57, 58, 155]
# ['gem-CF2' 'non-F']
# [58]
# ['non-F']
# [59]
# ['non-F']
# [60]
# ['non-F']
# [61, 63]
# ['CF3' 'non-F']
# [62, 64, 90, 116, 119]
# ['CF3' 'non-F']
# [63]
# ['non-F']
# [64, 90, 119]
# ['non-F']
# [65]
# ['non-F']
# [66, 69]
# ['CF3' 'non-F']
# [67, 71]
# ['CF3' 'non-F']
# [68, 72, 112, 115]
# ['CF3' 'non-F']
# [69]
# ['non-F']
# [70]
# ['non-F']
# [71]
# ['non-F']
# [72, 115]
# ['non-F']
# [73, 74]
# ['CF3' 'non-F']
# [74]
# ['non-F']
# [75]
# ['non-F']
# [76, 79]
# ['gem-CF2' 'non-F']
# [77, 79]
# ['gem-CF2' 'non-F']
# [78, 79]
# ['gem-CF2' 'non-F']
# [80, 81]
# ['gem-CF2' 'non-F']
# [81]
# ['non-F']
# [84, 85]
# ['gem-CF2' 'non-F']
# [85]
# ['non-F']
# [87, 123]
# ['non-F']
# [87, 88, 123]
# ['non-F' 'CHF']
# [64, 90, 119]
# ['non-F']
# [64, 90, 91, 119]
# ['non-F' 'CHF']
# [64, 90, 92, 119]
# ['non-F' 'gem-CF2']
# [64, 90, 93, 119]
# ['non-F' 'CHF']
# [64, 90, 94, 119]
# ['non-F' 'CHF']
# [72, 95, 115]
# ['non-F' 'CHF']
# [72, 96, 115]
# ['non-F' 'gem-CF2']
# [72, 97, 115]
# ['non-F' 'CHF']
# [72, 98, 115]
# ['non-F' 'CHF']
# [72, 100, 115]
# ['non-F' 'CHF']
# [72, 101, 115]
# ['non-F' 'CHF']
# [102, 105]
# ['CF3' 'non-F']
# [104, 105]
# ['CH2F' 'non-F']
# [106, 105]
# ['CF3' 'non-F']
# [107, 105]
# ['CF3' 'non-F']
# [108, 105]
# ['CHF2' 'non-F']
# [109, 105]
# ['CHF2' 'non-F']
# [110, 105]
# ['CH2F' 'non-F']
# [111, 105]
# ['CH2F' 'non-F']
# [68, 72, 112, 115]
# ['CF3' 'non-F']
# [72, 113, 115]
# ['non-F' 'CHF2']
# [72, 114, 115]
# ['non-F' 'CH2F']
# [72, 115]
# ['non-F']
# [62, 64, 90, 116, 119]
# ['CF3' 'non-F']
# [64, 90, 117, 119]
# ['non-F' 'CHF2']
# [64, 90, 118, 119]
# ['non-F' 'CH2F']
# [64, 90, 119]
# ['non-F']
# [87, 120, 123]
# ['non-F' 'CF3']
# [87, 121, 123]
# ['non-F' 'CHF2']
# [87, 122, 123]
# ['non-F' 'CH2F']
# [87, 123]
# ['non-F']
# [125]
# ['CHF2']
# [72, 115, 128]
# ['non-F' 'CF3']
# [72, 115, 129]
# ['non-F' 'CHF2']
# [72, 115, 130]
# ['non-F' 'CH2F']
# [64, 90, 119, 131]
# ['non-F' 'CF3']
# [64, 90, 119, 132]
# ['non-F' 'CHF2']
# [87, 123, 134]
# ['non-F' 'CF3']
# [87, 123, 135]
# ['non-F' 'CHF2']
# [87, 123, 136]
# ['non-F' 'CH2F']
# [138, 140]
# ['CHF2' 'non-F']
# [139, 140]
# ['CH2F' 'non-F']
# [140]
# ['non-F']
# [72, 115, 141]
# ['non-F' 'CF3']
# [72, 115, 143]
# ['non-F' 'CH2F']
# [144, 147]
# ['CH2F' 'non-F']
# [145, 147, 161]
# ['CHF2' 'non-F']
# [146, 147]
# ['CF3' 'non-F']
# [147]
# ['non-F']
# [150, 105]
# ['gem-CF2' 'non-F']
# [151, 163]
# ['gem-CF2' 'non-F']
# [58, 153]
# ['non-F' 'gem-CF2']
# [58, 154]
# ['non-F' 'gem-CF2']
# [57, 58, 155]
# ['gem-CF2' 'non-F']
# [156, 164]
# ['gem-CF2' 'non-F']
# [157, 164]
# ['gem-CF2' 'non-F']
# [158, 164]
# ['gem-CF2' 'non-F']
# [159, 165]
# ['gem-CF2' 'non-F']
# [160, 165]
# ['gem-CF2' 'non-F']
# [145, 147, 161]
# ['CHF2' 'non-F']
# [162]
# ['non-F']
# [163]
# ['non-F']
# [164]
# ['non-F']
# [165]
# ['non-F']
# [166]
# ['non-F']
# [166, 168]
# ['non-F' 'gem-CF2']
# [169, 105]
# ['CF3' 'non-F']
# [162, 172]
# ['non-F' 'CF3']
# [162, 173]
# ['non-F' 'CF3']
# [162, 174]
# ['non-F' 'CHF2']
# [162, 175]
# ['non-F' 'CHF2']
# [176]
# ['non-F']
# [177]
# ['non-F']
# [180]
# ['non-F']
# [180, 182]
# ['non-F' 'gem-CF2']
# [105]
# ['non-F']
# [29, 16]
# ['non-F' 'gem-CF2']
# [36, 34]
# ['gem-CF2' 'non-F']
# [72, 115, 99]
# ['non-F' 'CHF']
# [1, 0]
# ['non-F' 'gem-CF2']
# [105, 170]
# ['non-F' 'CHF2']
# [34]
# ['non-F']
# [79]
# ['non-F']
# [72, 115, 86]
# ['non-F' 'gem-CF2']
# [72, 115, 142]
# ['non-F' 'CHF2']
# [50]
# ['non-F']
# [140, 137]
# ['non-F' 'CF3']
# [39, 38]
# ['non-F' 'CHF2']
# [105, 149]
# ['non-F' 'gem-CF2']
# [64, 90, 119, 133]
# ['non-F' 'CH2F']
# [87, 123, 89]
# ['non-F' 'gem-CF2']
# [163, 152]
# ['non-F' 'gem-CF2']
# [105, 171]
# ['non-F' 'CH2F']
# [6, 30, 17]
# ['non-F' 'gem-CF2']
# [60, 55]
# ['non-F' 'gem-CF2']
# [126]
# ['CH2F']
# [105, 103]
# ['non-F' 'CHF2']
# [49]
# ['non-F']
# [1, 22]
# ['non-F' 'gem-CF2']
# [33, 27]
# ['non-F' 'gem-CF2']

# %%
df = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\logP_lipophilicity_data\gnn_cv\train_test_for_SMILES_per_model.csv', index_col=0)

# %%
df
# Out:
#      fold_id  logP                                        Smiles  F group  \
# 4        0.0  2.37   O=C(Nc1ccccc1)[C@H]1C[C@@H]2[C@H](C1)C2(F)F  gem-CF2
# 5        0.0  2.88  O=C(Nc1ccccc1)[C@@H]1C[C@@H]2[C@H](C1)C2(F)F  gem-CF2
# 7        0.0  1.88                      O=C(Nc1ccccc1)C1(CF)CCC1     CH2F
# 8        0.0  2.19                   O=C(Nc1ccccc1)C1(C(F)F)CCC1     CHF2
# 9        0.0  2.51                O=C(Nc1ccccc1)C1(C(F)(F)F)CCC1      CF3
# ..       ...   ...                                           ...      ...
# 55       NaN  2.23  O=C(N[C@@H]1C[C@@H]2[C@H](C1)C2(F)F)c1ccccc1  gem-CF2
# 126      NaN  1.07                             O=C(NCCF)c1ccccc1     CH2F
# 103      NaN  2.48                   O=C(NC1(C(F)F)CCC1)c1ccccc1     CHF2
# 22       NaN  2.72                  O=C(Nc1ccccc1)C1CCCC(F)(F)C1  gem-CF2
# 27       NaN  2.12                      CC(F)(F)CCC(=O)Nc1ccccc1  gem-CF2
#
#                                 non-F Smiles
# 4    O=C(Nc1ccccc1)[C@@H]1C[C@@H]2C[C@@H]2C1
# 5     O=C(Nc1ccccc1)[C@H]1C[C@@H]2C[C@@H]2C1
# 7                       O=C(Nc1ccccc1)C1CCC1
# 8                       O=C(Nc1ccccc1)C1CCC1
# 9                       O=C(Nc1ccccc1)C1CCC1
# ..                                       ...
# 55    O=C(N[C@H]1C[C@@H]2C[C@@H]2C1)c1ccccc1
# 126                          CNC(=O)c1ccccc1
# 103                     O=C(NC1CCC1)c1ccccc1
# 22                    O=C(Nc1ccccc1)C1CCCCC1
# 27                        CCCCC(=O)Nc1ccccc1
#
# [126 rows x 5 columns]

# %% [markdown]
# -------

# %% [markdown]
# -------

# %% [markdown]
# -------

# %% [markdown]
# -------

# %% [markdown]
# -------

# %% [markdown]
# PKA

# %%
import pandas as pd

train_set_basic = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\pKa_basicity_data\gnn_cv_canon_smiles\train_basic.csv', index_col=0)
test_set_basic = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\pKa_basicity_data\gnn_cv_canon_smiles\test_basic.csv', index_col=0)

train_set_acid = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\pKa_basicity_data\gnn_cv_canon_smiles\train_acid.csv', index_col=0)
test_set_acid = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\pKa_basicity_data\gnn_cv_canon_smiles\test_acid.csv', index_col=0)

train_df = pd.concat([train_set_basic, train_set_acid], axis=0)
test_df = pd.concat([test_set_basic, test_set_acid], axis=0)

df = pd.concat([train_df, test_df], axis=0)
# df['Smiles'] = df['Smiles'].apply(convert_to_canon)

# %%
df_init = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\init_data\pKa_Prediction_Starting data_2024.05.07.csv', index_col=0)
# df_init['Smiles'] = df_init['Smiles'].apply(convert_to_canon)

# %%
functional_group_to_smiles = {
    "CF3": "C(F)(F)F", 
    "CH2F": "CF", 
    "gem-CF2": "F", 
    "CHF2": "C(F)(F)",
    "CHF": "F",
    "non-F": ""
}

# %%
SMILES_to_functional_group = {}

for index, row in df_init.iterrows():
    if pd.isnull(row['Smiles']):
        continue

    SMILES_to_functional_group[row['Smiles']] = row['F group']

# %%
from rdkit import Chem

def remove_functional_group_from_smiles(smiles, f_group):
    f_group_smiles = functional_group_to_smiles[f_group]

    mol = Chem.MolFromSmiles(smiles)
    mol_f_group = Chem.MolFromSmiles(f_group_smiles)

    if mol.HasSubstructMatch(mol_f_group):
        mol = Chem.DeleteSubstructs(mol, mol_f_group)

    smiles_without_group = Chem.MolToSmiles(mol)
    return smiles_without_group

canon_smiles = []
functional_groups = []
smiles_with_removed_flurine = []
for SMILES in df['Smiles']:
    functional_group = SMILES_to_functional_group[SMILES]
    functional_groups.append(functional_group)

    # canon_smile = Chem.CanonSmiles(SMILES)
    # canon_smiles.append(canon_smile)
    
    SMILES_without_fluorine_group = remove_functional_group_from_smiles(smiles=SMILES, f_group=functional_group)
    smiles_with_removed_flurine.append(SMILES_without_fluorine_group)

# df['Smiles'] = canon_smiles
df['F group'] = functional_groups
df['non-F Smiles'] = smiles_with_removed_flurine

# %%
for index, row in df.iterrows():
    print(row['Smiles'], row['non-F Smiles'])
# Out:
# N[C@@H]1C[C@@H]2[C@H](C1)C2(F)F N[C@H]1C[C@@H]2C[C@@H]2C1
# N[C@H]1C[C@@H]2[C@H](C1)C2(F)F N[C@@H]1C[C@@H]2C[C@@H]2C1
# NC1CCC(F)(F)CC1 NC1CCCCC1
# NC1CCCCC1 NC1CCCCC1
# N[C@@H]1C[C@@H]2C[C@@H]2C1 N[C@@H]1C[C@@H]2C[C@@H]2C1
# N[C@H]1C[C@@H]2C[C@@H]2C1 N[C@H]1C[C@@H]2C[C@@H]2C1
# FC(F)(F)C12CC(CN1)C2 C1NC2CC1C2
# C1NC2CC1C2 C1NC2CC1C2
# C1CCNC1 C1CCNC1
# CC12CC(CN1)C2 CC12CC(CN1)C2
# FC(F)(F)C12CCC(CC1)CN2 C1CC2CCC1CN2
# C1CC2CC1CN2 C1CC2CC1CN2
# C1CC2CCC1CN2 C1CC2CCC1CN2
# C1CCNCC1 C1CCNCC1
# FC(F)(F)C12CCCC(CN1)C2 C1CC2CNC(C1)C2
# C1CC2CNC(C1)C2 C1CC2CNC(C1)C2
# FC1(F)CC2CNCC(C2)C1 C1CC2CNCC(C1)C2
# FC1(F)CC2CNCC(C1)C2(F)F C1CC2CNCC(C1)C2
# FC1(F)C2CCCC1CNC2 C1CC2CNCC(C1)C2
# C1CC2CNCC(C1)C2 C1CC2CNCC(C1)C2
# FC1(F)C2CNCC1COC2 C1NCC2COCC1C2
# C1NCC2COCC1C2 C1NCC2COCC1C2
# C1CC2CNCC1C2 C1CC2CNCC1C2
# C1CNC1 C1CNC1
# FC1(F)CNC1 C1CNC1
# FC1CCNC1 C1CCNC1
# FC1(F)CCNC1 C1CCNC1
# F[C@@H]1CNC[C@@H]1F C1CCNC1
# F[C@@H]1CNC[C@H]1F C1CCNC1
# FC1CCCNC1 C1CCNCC1
# FC1(F)CCCNC1 C1CCNCC1
# F[C@@H]1CNC[C@H](F)C1 C1CCNCC1
# F[C@@H]1CNC[C@@H](F)C1 C1CCNCC1
# FC1CCNCC1 C1CCNCC1
# F[C@@H]1CCNC[C@@H]1F C1CCNCC1
# F[C@@H]1CCNC[C@H]1F C1CCNCC1
# NC1(C(F)(F)F)CCC1 NC1CCC1
# NC1(C(F)F)CCC1 NC1CCC1
# NC1(CF)CCC1 NC1CCC1
# NC1CCC1 NC1CCC1
# N[C@H]1C[C@H](C(F)(F)F)C1 NC1CCC1
# N[C@H]1C[C@@H](C(F)(F)F)C1 NC1CCC1
# N[C@H]1C[C@H](C(F)F)C1 NC1CCC1
# N[C@H]1C[C@@H](C(F)F)C1 NC1CCC1
# N[C@H]1C[C@H](CF)C1 NC1CCC1
# N[C@H]1C[C@@H](CF)C1 NC1CCC1
# FC(F)C1CCCCN1 C1CCNCC1
# FC(F)C1CCCN1 C1CCNC1
# FC(F)(F)C1CCN1 C1CNC1
# FC(F)C1CCN1 C1CNC1
# NCCF CN
# FC(F)(F)C1CCCNC1 C1CCNCC1
# FC(F)C1CCCNC1 C1CCNCC1
# FCC1CCCNC1 C1CCNCC1
# FC(F)C1CCNC1 C1CCNC1
# FCC1CCNC1 C1CCNC1
# FC(F)(F)C1CNC1 C1CNC1
# FC(F)C1CNC1 C1CNC1
# FCC1CNC1 C1CNC1
# NCCC(F)F CCN
# NCCCF CCN
# CCN CCN
# FC(F)C1CCNCC1 C1CCNCC1
# FCC1CCNCC1 C1CCNCC1
# NCCCCF CCCN
# NCCCC(F)F CCCN
# NCCCC(F)(F)F CCCN
# CCCN CCCN
# NC1CCC1(F)F NC1CCC1
# NC1CC(F)(F)C1 NC1CCC1
# NC1CCCCC1(F)F NC1CCCCC1
# NC1CCCC(F)(F)C1 NC1CCCCC1
# NC1CCCCCC1(F)F NC1CCCCCC1
# NC1CCCCC(F)(F)C1 NC1CCCCCC1
# NC1CCCC(F)(F)CC1 NC1CCCCCC1
# CCC(F)(F)CN CCCCN
# CC(F)(F)CCN CCCCN
# NC1CC1 NC1CC1
# NC1CCCC1 NC1CCCC1
# NC1CCCCCC1 NC1CCCCCC1
# NC1CC2(CCC2)C1 NC1CC2(CCC2)C1
# NC1CC2(C1)CC(F)(F)C2 NC1CC2(CCC2)C1
# N[C@@H]1CC[C@H]1C(F)(F)F N[C@@H]1CCC1
# N[C@@H]1CC[C@H]1CF N[C@@H]1CCC1
# N[C@@H]1C[C@H]1C(F)(F)F N[C@@H]1CC1
# N[C@H]1C[C@H]1C(F)(F)F N[C@@H]1CC1
# N[C@@H]1C[C@H]1C(F)F N[C@@H]1CC1
# N[C@H]1C[C@H]1C(F)F N[C@@H]1CC1
# C[C@@H]1C[C@H]1N C[C@@H]1C[C@H]1N
# NC1CC12CC2 NC1CC12CC2
# O=C(O)C1CCC(F)(F)CC1 O=C(O)C1CCCCC1
# O=C(O)C1CCCCC1 O=C(O)C1CCCCC1
# O=C(O)[C@H]1C[C@@H]2C[C@@H]2C1 O=C(O)[C@H]1C[C@@H]2C[C@@H]2C1
# O=C(O)[C@H]1C[C@@H]2[C@H](C1)C2(F)F O=C(O)[C@@H]1C[C@@H]2C[C@@H]2C1
# O=C(O)[C@@H]1C[C@@H]2[C@H](C1)C2(F)F O=C(O)[C@H]1C[C@@H]2C[C@@H]2C1
# O=C(O)C1CCC1 O=C(O)C1CCC1
# O=C(O)C1(CF)CCC1 O=C(O)C1CCC1
# O=C(O)C1(C(F)F)CCC1 O=C(O)C1CCC1
# O=C(O)C1(C(F)(F)F)CCC1 O=C(O)C1CCC1
# O=C(O)[C@H]1C[C@H](C(F)(F)F)C1 O=C(O)C1CCC1
# O=C(O)[C@H]1C[C@@H](C(F)(F)F)C1 O=C(O)C1CCC1
# O=C(O)[C@H]1C[C@H](C(F)F)C1 O=C(O)C1CCC1
# O=C(O)[C@H]1C[C@@H](C(F)F)C1 O=C(O)C1CCC1
# O=C(O)[C@H]1C[C@H](CF)C1 O=C(O)C1CCC1
# O=C(O)[C@H]1C[C@@H](CF)C1 O=C(O)C1CCC1
# O=C(O)C1CC1(F)F O=C(O)C1CC1
# O=C(O)C1CCC1(F)F O=C(O)C1CCC1
# O=C(O)C1CC(F)(F)C1 O=C(O)C1CCC1
# O=C(O)C1CCCC1(F)F O=C(O)C1CCCC1
# O=C(O)C1CCC(F)(F)C1 O=C(O)C1CCCC1
# O=C(O)C1CCCCC1(F)F O=C(O)C1CCCCC1
# O=C(O)C1CCCCCC1(F)F O=C(O)C1CCCCCC1
# O=C(O)C1CCCCC(F)(F)C1 O=C(O)C1CCCCCC1
# O=C(O)C1CCCC(F)(F)CC1 O=C(O)C1CCCCCC1
# CCC(F)(F)CC(=O)O CCCCC(=O)O
# CC(F)(F)CCC(=O)O CCCCC(=O)O
# O=C(O)C1CC1 O=C(O)C1CC1
# O=C(O)C1CCCC1 O=C(O)C1CCCC1
# O=C(O)C1CCCCCC1 O=C(O)C1CCCCCC1
# CCCCC(=O)O CCCCC(=O)O
# O=C(O)C1CC2(CCC2)C1 O=C(O)C1CC2(CCC2)C1
# O=C(O)C1CC2(C1)CC(F)(F)C2 O=C(O)C1CC2(CCC2)C1
# O=C(O)[C@@H]1CC[C@H]1C(F)(F)F O=C(O)[C@@H]1CCC1
# O=C(O)[C@@H]1CC[C@H]1C(F)F O=C(O)[C@@H]1CCC1
# O=C(O)[C@@H]1CC[C@H]1CF O=C(O)[C@@H]1CCC1
# O=C(O)[C@@H]1C[C@H]1C(F)(F)F O=C(O)[C@@H]1CC1
# O=C(O)[C@H]1C[C@H]1C(F)(F)F O=C(O)[C@@H]1CC1
# O=C(O)[C@@H]1C[C@H]1C(F)F O=C(O)[C@@H]1CC1
# O=C(O)[C@H]1C[C@H]1C(F)F O=C(O)[C@@H]1CC1
# O=C(O)[C@@H]1C[C@H]1CF O=C(O)[C@@H]1CC1
# C[C@@H]1C[C@H]1C(=O)O C[C@@H]1C[C@H]1C(=O)O
# C[C@@H]1C[C@@H]1C(=O)O C[C@@H]1C[C@@H]1C(=O)O
# O=C(O)C1C(F)(F)C12CC2 O=C(O)C1CC12CC2
# FC(F)(F)C12CCC(CN1)C2 C1CC2CC1CN2
# FC(F)(F)C1CCCN1 C1CCNC1
# FC(F)(F)C1CCCCN1 C1CCNCC1
# NC1CC12CC2(F)F NC1CC12CC2
# NC1CCCC1(F)F NC1CCCC1
# FC1(F)CCNCC1 C1CCNCC1
# FC1(F)C2CCC1CNC2 C1CC2CNCC1C2
# NC1CCC(F)(F)C1 NC1CCCC1
# FC1CNC1 C1CNC1
# N[C@@H]1CC[C@H]1C(F)F N[C@@H]1CCC1
# C[C@@H]1C[C@@H]1N C[C@@H]1C[C@@H]1N
# FCC1CCCCN1 C1CCNCC1
# FCC1CCCN1 C1CCNC1
# FCC1CCN1 C1CNC1
# NC1CC2(C1)CC(F)C2 NC1CC2(CCC2)C1
# FC(F)(F)C1CCNCC1 C1CCNCC1
# CCCCN CCCCN
# CC12CCC(CC1)CN2 CC12CCC(CC1)CN2
# CC12CCCC(CN1)C2 CC12CCCC(CN1)C2
# O=C(O)C1CC12CC2(F)F O=C(O)C1CC12CC2
# O=C(O)C12CC(CO1)C2 O=C(O)C12CC(CO1)C2
# O=C(O)C1CCCC(F)(F)C1 O=C(O)C1CCCCC1
# O=C(O)[C@@H]1C[C@@H]2C[C@@H]2C1 O=C(O)[C@@H]1C[C@@H]2C[C@@H]2C1
# O=C(O)C1CC2(CC(F)C2)C1 O=C(O)C1CC2(CCC2)C1
# O=C(O)C1CC12CC2 O=C(O)C1CC12CC2
# O=C(O)CCCC(F)F CCCC(=O)O

# %%
mol = Chem.MolFromSmiles(Chem.CanonSmiles('N[C@@H]1C[C@@H]2[C@H](C1)C2(F)F'))

mol_f_group = Chem.MolFromSmiles('F')

if mol.HasSubstructMatch(mol_f_group):
    mol = Chem.DeleteSubstructs(mol, mol_f_group)

Chem.MolToSmiles(mol)
# Out:
# 'N[C@H]1C[C@@H]2C[C@@H]2C1'

# %%
mol

# %%
main_df_for_train = df.copy()

index_to_remain = []
for index_non_F, row_non_F in main_df_for_train.iterrows():
    SMILES_to_find = row_non_F['non-F Smiles']
    is_on_train = False
     
    for index, row in main_df_for_train.iterrows():
        if row['Smiles'] == SMILES_to_find:
            is_on_train = True
    
    index_to_remain.append(index_non_F)
    if row_non_F['F group'] != 'non-F':
        print(row_non_F['Smiles'], SMILES_to_find, row_non_F['F group'], index_non_F, is_on_train)
# Out:
# N[C@@H]1C[C@@H]2[C@H](C1)C2(F)F N[C@H]1C[C@@H]2C[C@@H]2C1 gem-CF2 54 True
# N[C@H]1C[C@@H]2[C@H](C1)C2(F)F N[C@@H]1C[C@@H]2C[C@@H]2C1 gem-CF2 55 True
# NC1CCC(F)(F)CC1 NC1CCCCC1 gem-CF2 56 True
# FC(F)(F)C12CC(CN1)C2 C1NC2CC1C2 CF3 60 True
# FC(F)(F)C12CCC(CC1)CN2 C1CC2CCC1CN2 CF3 66 True
# FC(F)(F)C12CCCC(CN1)C2 C1CC2CNC(C1)C2 CF3 72 True
# FC1(F)CC2CNCC(C2)C1 C1CC2CNCC(C1)C2 gem-CF2 75 True
# FC1(F)CC2CNCC(C1)C2(F)F C1CC2CNCC(C1)C2 gem-CF2 76 True
# FC1(F)C2CCCC1CNC2 C1CC2CNCC(C1)C2 gem-CF2 77 True
# FC1(F)C2CNCC1COC2 C1NCC2COCC1C2 gem-CF2 79 True
# FC1(F)CNC1 C1CNC1 gem-CF2 88 True
# FC1CCNC1 C1CCNC1 CHF 89 True
# FC1(F)CCNC1 C1CCNC1 gem-CF2 90 True
# F[C@@H]1CNC[C@@H]1F C1CCNC1 CHF 91 True
# F[C@@H]1CNC[C@H]1F C1CCNC1 CHF 92 True
# FC1CCCNC1 C1CCNCC1 CHF 93 True
# FC1(F)CCCNC1 C1CCNCC1 gem-CF2 94 True
# F[C@@H]1CNC[C@H](F)C1 C1CCNCC1 CHF 95 True
# F[C@@H]1CNC[C@@H](F)C1 C1CCNCC1 CHF 96 True
# FC1CCNCC1 C1CCNCC1 CHF 97 True
# F[C@@H]1CCNC[C@@H]1F C1CCNCC1 CHF 98 True
# F[C@@H]1CCNC[C@H]1F C1CCNCC1 CHF 99 True
# NC1(C(F)(F)F)CCC1 NC1CCC1 CF3 100 True
# NC1(C(F)F)CCC1 NC1CCC1 CHF2 101 True
# NC1(CF)CCC1 NC1CCC1 CH2F 102 True
# N[C@H]1C[C@H](C(F)(F)F)C1 NC1CCC1 CF3 104 True
# N[C@H]1C[C@@H](C(F)(F)F)C1 NC1CCC1 CF3 105 True
# N[C@H]1C[C@H](C(F)F)C1 NC1CCC1 CHF2 106 True
# N[C@H]1C[C@@H](C(F)F)C1 NC1CCC1 CHF2 107 True
# N[C@H]1C[C@H](CF)C1 NC1CCC1 CH2F 108 True
# N[C@H]1C[C@@H](CF)C1 NC1CCC1 CH2F 109 True
# FC(F)C1CCCCN1 C1CCNCC1 CHF2 110 True
# FC(F)C1CCCN1 C1CCNC1 CHF2 112 True
# FC(F)(F)C1CCN1 C1CNC1 CF3 114 True
# FC(F)C1CCN1 C1CNC1 CHF2 115 True
# NCCF CN CH2F 119 False
# FC(F)(F)C1CCCNC1 C1CCNCC1 CF3 121 True
# FC(F)C1CCCNC1 C1CCNCC1 CHF2 122 True
# FCC1CCCNC1 C1CCNCC1 CH2F 123 True
# FC(F)C1CCNC1 C1CCNC1 CHF2 125 True
# FCC1CCNC1 C1CCNC1 CH2F 126 True
# FC(F)(F)C1CNC1 C1CNC1 CF3 127 True
# FC(F)C1CNC1 C1CNC1 CHF2 128 True
# FCC1CNC1 C1CNC1 CH2F 129 True
# NCCC(F)F CCN CHF2 131 True
# NCCCF CCN CH2F 132 True
# FC(F)C1CCNCC1 C1CCNCC1 CHF2 135 True
# FCC1CCNCC1 C1CCNCC1 CH2F 136 True
# NCCCCF CCCN CH2F 137 True
# NCCCC(F)F CCCN CHF2 138 True
# NCCCC(F)(F)F CCCN CF3 139 True
# NC1CCC1(F)F NC1CCC1 gem-CF2 142 True
# NC1CC(F)(F)C1 NC1CCC1 gem-CF2 143 True
# NC1CCCCC1(F)F NC1CCCCC1 gem-CF2 146 True
# NC1CCCC(F)(F)C1 NC1CCCCC1 gem-CF2 147 True
# NC1CCCCCC1(F)F NC1CCCCCC1 gem-CF2 148 True
# NC1CCCCC(F)(F)C1 NC1CCCCCC1 gem-CF2 149 True
# NC1CCCC(F)(F)CC1 NC1CCCCCC1 gem-CF2 150 True
# CCC(F)(F)CN CCCCN gem-CF2 151 True
# CC(F)(F)CCN CCCCN gem-CF2 152 True
# NC1CC2(C1)CC(F)(F)C2 NC1CC2(CCC2)C1 gem-CF2 159 True
# N[C@@H]1CC[C@H]1C(F)(F)F N[C@@H]1CCC1 CF3 160 False
# N[C@@H]1CC[C@H]1CF N[C@@H]1CCC1 CH2F 162 False
# N[C@@H]1C[C@H]1C(F)(F)F N[C@@H]1CC1 CF3 163 False
# N[C@H]1C[C@H]1C(F)(F)F N[C@@H]1CC1 CF3 164 False
# N[C@@H]1C[C@H]1C(F)F N[C@@H]1CC1 CHF2 165 False
# N[C@H]1C[C@H]1C(F)F N[C@@H]1CC1 CHF2 166 False
# O=C(O)C1CCC(F)(F)CC1 O=C(O)C1CCCCC1 gem-CF2 0 True
# O=C(O)[C@H]1C[C@@H]2[C@H](C1)C2(F)F O=C(O)[C@@H]1C[C@@H]2C[C@@H]2C1 gem-CF2 4 True
# O=C(O)[C@@H]1C[C@@H]2[C@H](C1)C2(F)F O=C(O)[C@H]1C[C@@H]2C[C@@H]2C1 gem-CF2 5 True
# O=C(O)C1(CF)CCC1 O=C(O)C1CCC1 CH2F 7 True
# O=C(O)C1(C(F)F)CCC1 O=C(O)C1CCC1 CHF2 8 True
# O=C(O)C1(C(F)(F)F)CCC1 O=C(O)C1CCC1 CF3 9 True
# O=C(O)[C@H]1C[C@H](C(F)(F)F)C1 O=C(O)C1CCC1 CF3 10 True
# O=C(O)[C@H]1C[C@@H](C(F)(F)F)C1 O=C(O)C1CCC1 CF3 11 True
# O=C(O)[C@H]1C[C@H](C(F)F)C1 O=C(O)C1CCC1 CHF2 12 True
# O=C(O)[C@H]1C[C@@H](C(F)F)C1 O=C(O)C1CCC1 CHF2 13 True
# O=C(O)[C@H]1C[C@H](CF)C1 O=C(O)C1CCC1 CH2F 14 True
# O=C(O)[C@H]1C[C@@H](CF)C1 O=C(O)C1CCC1 CH2F 15 True
# O=C(O)C1CC1(F)F O=C(O)C1CC1 gem-CF2 16 True
# O=C(O)C1CCC1(F)F O=C(O)C1CCC1 gem-CF2 17 True
# O=C(O)C1CC(F)(F)C1 O=C(O)C1CCC1 gem-CF2 18 True
# O=C(O)C1CCCC1(F)F O=C(O)C1CCCC1 gem-CF2 19 True
# O=C(O)C1CCC(F)(F)C1 O=C(O)C1CCCC1 gem-CF2 20 True
# O=C(O)C1CCCCC1(F)F O=C(O)C1CCCCC1 gem-CF2 21 True
# O=C(O)C1CCCCCC1(F)F O=C(O)C1CCCCCC1 gem-CF2 23 True
# O=C(O)C1CCCCC(F)(F)C1 O=C(O)C1CCCCCC1 gem-CF2 24 True
# O=C(O)C1CCCC(F)(F)CC1 O=C(O)C1CCCCCC1 gem-CF2 25 True
# CCC(F)(F)CC(=O)O CCCCC(=O)O gem-CF2 26 True
# CC(F)(F)CCC(=O)O CCCCC(=O)O gem-CF2 27 True
# O=C(O)C1CC2(C1)CC(F)(F)C2 O=C(O)C1CC2(CCC2)C1 gem-CF2 35 True
# O=C(O)[C@@H]1CC[C@H]1C(F)(F)F O=C(O)[C@@H]1CCC1 CF3 40 False
# O=C(O)[C@@H]1CC[C@H]1C(F)F O=C(O)[C@@H]1CCC1 CHF2 41 False
# O=C(O)[C@@H]1CC[C@H]1CF O=C(O)[C@@H]1CCC1 CH2F 42 False
# O=C(O)[C@@H]1C[C@H]1C(F)(F)F O=C(O)[C@@H]1CC1 CF3 43 False
# O=C(O)[C@H]1C[C@H]1C(F)(F)F O=C(O)[C@@H]1CC1 CF3 44 False
# O=C(O)[C@@H]1C[C@H]1C(F)F O=C(O)[C@@H]1CC1 CHF2 45 False
# O=C(O)[C@H]1C[C@H]1C(F)F O=C(O)[C@@H]1CC1 CHF2 46 False
# O=C(O)[C@@H]1C[C@H]1CF O=C(O)[C@@H]1CC1 CH2F 47 False
# O=C(O)C1C(F)(F)C12CC2 O=C(O)C1CC12CC2 gem-CF2 52 True
# FC(F)(F)C12CCC(CN1)C2 C1CC2CC1CN2 CF3 65 True
# FC(F)(F)C1CCCN1 C1CCNC1 CF3 61 True
# FC(F)(F)C1CCCCN1 C1CCNCC1 CF3 67 True
# NC1CC12CC2(F)F NC1CC12CC2 gem-CF2 173 True
# NC1CCCC1(F)F NC1CCCC1 gem-CF2 144 True
# FC1(F)CCNCC1 C1CCNCC1 gem-CF2 85 True
# FC1(F)C2CCC1CNC2 C1CC2CNCC1C2 gem-CF2 83 True
# NC1CCC(F)(F)C1 NC1CCCC1 gem-CF2 145 True
# FC1CNC1 C1CNC1 CHF 87 True
# N[C@@H]1CC[C@H]1C(F)F N[C@@H]1CCC1 CHF2 161 False
# FCC1CCCCN1 C1CCNCC1 CH2F 111 True
# FCC1CCCN1 C1CCNC1 CH2F 113 True
# FCC1CCN1 C1CNC1 CH2F 116 True
# NC1CC2(C1)CC(F)C2 NC1CC2(CCC2)C1 CHF 158 True
# FC(F)(F)C1CCNCC1 C1CCNCC1 CF3 134 True
# O=C(O)C1CC12CC2(F)F O=C(O)C1CC12CC2 gem-CF2 53 True
# O=C(O)C1CCCC(F)(F)C1 O=C(O)C1CCCCC1 gem-CF2 22 True
# O=C(O)C1CC2(CC(F)C2)C1 O=C(O)C1CC2(CCC2)C1 CHF 34 True
# O=C(O)CCCC(F)F CCCC(=O)O CHF2 28 False

# %%
df_for_train = main_df_for_train.copy().loc[index_to_remain]

for index, row in df_for_train.iterrows():
    SMILES = row['Smiles']
    SMILES_non_F = row['non-F Smiles']

    indexes_to_remove = []
    for index_train, row_train in df.iterrows():
        if row_train['Smiles'] == SMILES:
            indexes_to_remove.append(index_train)
        if row_train['Smiles'] == SMILES_non_F and SMILES_non_F != SMILES:
            indexes_to_remove.append(index_train)
    
    print(indexes_to_remove)
    df_train = df.drop(indexes_to_remove, axis=0, inplace=False)
    df_test = df.loc[indexes_to_remove]

    print(df_test['F group'].unique())

    # break
# Out:
# [54, 59]
# ['gem-CF2' 'non-F']
# [55, 58]
# ['gem-CF2' 'non-F']
# [56, 57]
# ['gem-CF2' 'non-F']
# [57]
# ['non-F']
# [58]
# ['non-F']
# [59]
# ['non-F']
# [60, 62]
# ['CF3' 'non-F']
# [62]
# ['non-F']
# [63]
# ['non-F']
# [64]
# ['non-F']
# [66, 70]
# ['CF3' 'non-F']
# [68]
# ['non-F']
# [70]
# ['non-F']
# [71]
# ['non-F']
# [72, 73]
# ['CF3' 'non-F']
# [73]
# ['non-F']
# [75, 78]
# ['gem-CF2' 'non-F']
# [76, 78]
# ['gem-CF2' 'non-F']
# [77, 78]
# ['gem-CF2' 'non-F']
# [78]
# ['non-F']
# [79, 80]
# ['gem-CF2' 'non-F']
# [80]
# ['non-F']
# [84]
# ['non-F']
# [86]
# ['non-F']
# [86, 88]
# ['non-F' 'gem-CF2']
# [63, 89]
# ['non-F' 'CHF']
# [63, 90]
# ['non-F' 'gem-CF2']
# [63, 91]
# ['non-F' 'CHF']
# [63, 92]
# ['non-F' 'CHF']
# [71, 93]
# ['non-F' 'CHF']
# [71, 94]
# ['non-F' 'gem-CF2']
# [71, 95]
# ['non-F' 'CHF']
# [71, 96]
# ['non-F' 'CHF']
# [71, 97]
# ['non-F' 'CHF']
# [71, 98]
# ['non-F' 'CHF']
# [71, 99]
# ['non-F' 'CHF']
# [100, 103]
# ['CF3' 'non-F']
# [101, 103]
# ['CHF2' 'non-F']
# [102, 103]
# ['CH2F' 'non-F']
# [103]
# ['non-F']
# [103, 104]
# ['non-F' 'CF3']
# [103, 105]
# ['non-F' 'CF3']
# [103, 106]
# ['non-F' 'CHF2']
# [103, 107]
# ['non-F' 'CHF2']
# [103, 108]
# ['non-F' 'CH2F']
# [103, 109]
# ['non-F' 'CH2F']
# [71, 110]
# ['non-F' 'CHF2']
# [63, 112]
# ['non-F' 'CHF2']
# [86, 114]
# ['non-F' 'CF3']
# [86, 115]
# ['non-F' 'CHF2']
# [119]
# ['CH2F']
# [71, 121]
# ['non-F' 'CF3']
# [71, 122]
# ['non-F' 'CHF2']
# [71, 123]
# ['non-F' 'CH2F']
# [63, 125]
# ['non-F' 'CHF2']
# [63, 126]
# ['non-F' 'CH2F']
# [86, 127]
# ['non-F' 'CF3']
# [86, 128]
# ['non-F' 'CHF2']
# [86, 129]
# ['non-F' 'CH2F']
# [131, 133]
# ['CHF2' 'non-F']
# [132, 133]
# ['CH2F' 'non-F']
# [133]
# ['non-F']
# [71, 135]
# ['non-F' 'CHF2']
# [71, 136]
# ['non-F' 'CH2F']
# [137, 140]
# ['CH2F' 'non-F']
# [138, 140]
# ['CHF2' 'non-F']
# [139, 140]
# ['CF3' 'non-F']
# [140]
# ['non-F']
# [103, 142]
# ['non-F' 'gem-CF2']
# [103, 143]
# ['non-F' 'gem-CF2']
# [57, 146]
# ['non-F' 'gem-CF2']
# [57, 147]
# ['non-F' 'gem-CF2']
# [148, 155]
# ['gem-CF2' 'non-F']
# [149, 155]
# ['gem-CF2' 'non-F']
# [150, 155]
# ['gem-CF2' 'non-F']
# [151, 156]
# ['gem-CF2' 'non-F']
# [152, 156]
# ['gem-CF2' 'non-F']
# [153]
# ['non-F']
# [154]
# ['non-F']
# [155]
# ['non-F']
# [157]
# ['non-F']
# [157, 159]
# ['non-F' 'gem-CF2']
# [160]
# ['CF3']
# [162]
# ['CH2F']
# [163]
# ['CF3']
# [164]
# ['CF3']
# [165]
# ['CHF2']
# [166]
# ['CHF2']
# [167]
# ['non-F']
# [171]
# ['non-F']
# [0, 1]
# ['gem-CF2' 'non-F']
# [1]
# ['non-F']
# [2]
# ['non-F']
# [4, 3]
# ['gem-CF2' 'non-F']
# [2, 5]
# ['non-F' 'gem-CF2']
# [6]
# ['non-F']
# [6, 7]
# ['non-F' 'CH2F']
# [6, 8]
# ['non-F' 'CHF2']
# [6, 9]
# ['non-F' 'CF3']
# [6, 10]
# ['non-F' 'CF3']
# [6, 11]
# ['non-F' 'CF3']
# [6, 12]
# ['non-F' 'CHF2']
# [6, 13]
# ['non-F' 'CHF2']
# [6, 14]
# ['non-F' 'CH2F']
# [6, 15]
# ['non-F' 'CH2F']
# [16, 29]
# ['gem-CF2' 'non-F']
# [6, 17]
# ['non-F' 'gem-CF2']
# [6, 18]
# ['non-F' 'gem-CF2']
# [19, 30]
# ['gem-CF2' 'non-F']
# [20, 30]
# ['gem-CF2' 'non-F']
# [1, 21]
# ['non-F' 'gem-CF2']
# [23, 31]
# ['gem-CF2' 'non-F']
# [24, 31]
# ['gem-CF2' 'non-F']
# [25, 31]
# ['gem-CF2' 'non-F']
# [26, 32]
# ['gem-CF2' 'non-F']
# [27, 32]
# ['gem-CF2' 'non-F']
# [29]
# ['non-F']
# [30]
# ['non-F']
# [31]
# ['non-F']
# [32]
# ['non-F']
# [33]
# ['non-F']
# [33, 35]
# ['non-F' 'gem-CF2']
# [40]
# ['CF3']
# [41]
# ['CHF2']
# [42]
# ['CH2F']
# [43]
# ['CF3']
# [44]
# ['CF3']
# [45]
# ['CHF2']
# [46]
# ['CHF2']
# [47]
# ['CH2F']
# [48]
# ['non-F']
# [49]
# ['non-F']
# [52, 51]
# ['gem-CF2' 'non-F']
# [68, 65]
# ['non-F' 'CF3']
# [63, 61]
# ['non-F' 'CF3']
# [71, 67]
# ['non-F' 'CF3']
# [171, 173]
# ['non-F' 'gem-CF2']
# [154, 144]
# ['non-F' 'gem-CF2']
# [71, 85]
# ['non-F' 'gem-CF2']
# [84, 83]
# ['non-F' 'gem-CF2']
# [154, 145]
# ['non-F' 'gem-CF2']
# [86, 87]
# ['non-F' 'CHF']
# [161]
# ['CHF2']
# [168]
# ['non-F']
# [71, 111]
# ['non-F' 'CH2F']
# [63, 113]
# ['non-F' 'CH2F']
# [86, 116]
# ['non-F' 'CH2F']
# [157, 158]
# ['non-F' 'CHF']
# [71, 134]
# ['non-F' 'CF3']
# [156]
# ['non-F']
# [69]
# ['non-F']
# [74]
# ['non-F']
# [53, 51]
# ['gem-CF2' 'non-F']
# [38]
# ['non-F']
# [1, 22]
# ['non-F' 'gem-CF2']
# [3]
# ['non-F']
# [33, 34]
# ['non-F' 'CHF']
# [51]
# ['non-F']
# [28]
# ['CHF2']

# %%
df_for_train.to_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\pKa_basicity_data\gnn_cv_canon_smiles\train_test_for_SMILES_per_model.csv')

# %%
df_for_train
# Out:
#     fold_id    pKa                           Smiles  F group  \
# 54      0.0   8.89  N[C@@H]1C[C@@H]2[C@H](C1)C2(F)F  gem-CF2
# 55      0.0   8.95   N[C@H]1C[C@@H]2[C@H](C1)C2(F)F  gem-CF2
# 56      1.0   9.45                  NC1CCC(F)(F)CC1  gem-CF2
# 57      1.0  10.58                        NC1CCCCC1    non-F
# 58      0.0   9.79       N[C@@H]1C[C@@H]2C[C@@H]2C1    non-F
# ..      ...    ...                              ...      ...
# 22      NaN   4.18             O=C(O)C1CCCC(F)(F)C1  gem-CF2
# 3       NaN   4.24  O=C(O)[C@@H]1C[C@@H]2C[C@@H]2C1    non-F
# 34      NaN   4.39           O=C(O)C1CC2(CC(F)C2)C1      CHF
# 51      NaN   4.61                  O=C(O)C1CC12CC2    non-F
# 28      NaN   4.38                   O=C(O)CCCC(F)F     CHF2
#
#                        non-F Smiles
# 54        N[C@H]1C[C@@H]2C[C@@H]2C1
# 55       N[C@@H]1C[C@@H]2C[C@@H]2C1
# 56                        NC1CCCCC1
# 57                        NC1CCCCC1
# 58       N[C@@H]1C[C@@H]2C[C@@H]2C1
# ..                              ...
# 22                   O=C(O)C1CCCCC1
# 3   O=C(O)[C@@H]1C[C@@H]2C[C@@H]2C1
# 34              O=C(O)C1CC2(CCC2)C1
# 51                  O=C(O)C1CC12CC2
# 28                        CCCC(=O)O
#
# [159 rows x 5 columns]

# %%
import pandas as pd

df_for_train = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\pKa_basicity_data\gnn_cv_canon_smiles\train_test_for_SMILES_per_model.csv', index_col=0)

# %%
for index, row in df_for_train.iterrows():
    ok = False
    for index_temp, row_temp in df_for_train.iterrows():
        if row['non-F Smiles'] == row_temp['Smiles']:
            ok = True
    
    print(ok, row['Smiles'], row['non-F Smiles'])
# Out:
# True N[C@@H]1C[C@@H]2[C@H](C1)C2(F)F N[C@H]1C[C@@H]2C[C@@H]2C1
# True N[C@H]1C[C@@H]2[C@H](C1)C2(F)F N[C@@H]1C[C@@H]2C[C@@H]2C1
# True NC1CCC(F)(F)CC1 NC1CCCCC1
# True NC1CCCCC1 NC1CCCCC1
# True N[C@@H]1C[C@@H]2C[C@@H]2C1 N[C@@H]1C[C@@H]2C[C@@H]2C1
# True N[C@H]1C[C@@H]2C[C@@H]2C1 N[C@H]1C[C@@H]2C[C@@H]2C1
# True FC(F)(F)C12CC(CN1)C2 C1NC2CC1C2
# True C1NC2CC1C2 C1NC2CC1C2
# True C1CCNC1 C1CCNC1
# True CC12CC(CN1)C2 CC12CC(CN1)C2
# True FC(F)(F)C12CCC(CC1)CN2 C1CC2CCC1CN2
# True C1CC2CC1CN2 C1CC2CC1CN2
# True C1CC2CCC1CN2 C1CC2CCC1CN2
# True C1CCNCC1 C1CCNCC1
# True FC(F)(F)C12CCCC(CN1)C2 C1CC2CNC(C1)C2
# True C1CC2CNC(C1)C2 C1CC2CNC(C1)C2
# True FC1(F)CC2CNCC(C2)C1 C1CC2CNCC(C1)C2
# True FC1(F)CC2CNCC(C1)C2(F)F C1CC2CNCC(C1)C2
# True FC1(F)C2CCCC1CNC2 C1CC2CNCC(C1)C2
# True C1CC2CNCC(C1)C2 C1CC2CNCC(C1)C2
# True FC1(F)C2CNCC1COC2 C1NCC2COCC1C2
# True C1NCC2COCC1C2 C1NCC2COCC1C2
# True C1CC2CNCC1C2 C1CC2CNCC1C2
# True C1CNC1 C1CNC1
# True FC1(F)CNC1 C1CNC1
# True FC1CCNC1 C1CCNC1
# True FC1(F)CCNC1 C1CCNC1
# True F[C@@H]1CNC[C@@H]1F C1CCNC1
# True F[C@@H]1CNC[C@H]1F C1CCNC1
# True FC1CCCNC1 C1CCNCC1
# True FC1(F)CCCNC1 C1CCNCC1
# True F[C@@H]1CNC[C@H](F)C1 C1CCNCC1
# True F[C@@H]1CNC[C@@H](F)C1 C1CCNCC1
# True FC1CCNCC1 C1CCNCC1
# True F[C@@H]1CCNC[C@@H]1F C1CCNCC1
# True F[C@@H]1CCNC[C@H]1F C1CCNCC1
# True NC1(C(F)(F)F)CCC1 NC1CCC1
# True NC1(C(F)F)CCC1 NC1CCC1
# True NC1(CF)CCC1 NC1CCC1
# True NC1CCC1 NC1CCC1
# True N[C@H]1C[C@H](C(F)(F)F)C1 NC1CCC1
# True N[C@H]1C[C@@H](C(F)(F)F)C1 NC1CCC1
# True N[C@H]1C[C@H](C(F)F)C1 NC1CCC1
# True N[C@H]1C[C@@H](C(F)F)C1 NC1CCC1
# True N[C@H]1C[C@H](CF)C1 NC1CCC1
# True N[C@H]1C[C@@H](CF)C1 NC1CCC1
# True FC(F)C1CCCCN1 C1CCNCC1
# True FC(F)C1CCCN1 C1CCNC1
# True FC(F)(F)C1CCN1 C1CNC1
# True FC(F)C1CCN1 C1CNC1
# False NCCF CN
# True FC(F)(F)C1CCCNC1 C1CCNCC1
# True FC(F)C1CCCNC1 C1CCNCC1
# True FCC1CCCNC1 C1CCNCC1
# True FC(F)C1CCNC1 C1CCNC1
# True FCC1CCNC1 C1CCNC1
# True FC(F)(F)C1CNC1 C1CNC1
# True FC(F)C1CNC1 C1CNC1
# True FCC1CNC1 C1CNC1
# True NCCC(F)F CCN
# True NCCCF CCN
# True CCN CCN
# True FC(F)C1CCNCC1 C1CCNCC1
# True FCC1CCNCC1 C1CCNCC1
# True NCCCCF CCCN
# True NCCCC(F)F CCCN
# True NCCCC(F)(F)F CCCN
# True CCCN CCCN
# True NC1CCC1(F)F NC1CCC1
# True NC1CC(F)(F)C1 NC1CCC1
# True NC1CCCCC1(F)F NC1CCCCC1
# True NC1CCCC(F)(F)C1 NC1CCCCC1
# True NC1CCCCCC1(F)F NC1CCCCCC1
# True NC1CCCCC(F)(F)C1 NC1CCCCCC1
# True NC1CCCC(F)(F)CC1 NC1CCCCCC1
# True CCC(F)(F)CN CCCCN
# True CC(F)(F)CCN CCCCN
# True NC1CC1 NC1CC1
# True NC1CCCC1 NC1CCCC1
# True NC1CCCCCC1 NC1CCCCCC1
# True NC1CC2(CCC2)C1 NC1CC2(CCC2)C1
# True NC1CC2(C1)CC(F)(F)C2 NC1CC2(CCC2)C1
# False N[C@@H]1CC[C@H]1C(F)(F)F N[C@@H]1CCC1
# False N[C@@H]1CC[C@H]1CF N[C@@H]1CCC1
# False N[C@@H]1C[C@H]1C(F)(F)F N[C@@H]1CC1
# False N[C@H]1C[C@H]1C(F)(F)F N[C@@H]1CC1
# False N[C@@H]1C[C@H]1C(F)F N[C@@H]1CC1
# False N[C@H]1C[C@H]1C(F)F N[C@@H]1CC1
# True C[C@@H]1C[C@H]1N C[C@@H]1C[C@H]1N
# True NC1CC12CC2 NC1CC12CC2
# True O=C(O)C1CCC(F)(F)CC1 O=C(O)C1CCCCC1
# True O=C(O)C1CCCCC1 O=C(O)C1CCCCC1
# True O=C(O)[C@H]1C[C@@H]2C[C@@H]2C1 O=C(O)[C@H]1C[C@@H]2C[C@@H]2C1
# True O=C(O)[C@H]1C[C@@H]2[C@H](C1)C2(F)F O=C(O)[C@@H]1C[C@@H]2C[C@@H]2C1
# True O=C(O)[C@@H]1C[C@@H]2[C@H](C1)C2(F)F O=C(O)[C@H]1C[C@@H]2C[C@@H]2C1
# True O=C(O)C1CCC1 O=C(O)C1CCC1
# True O=C(O)C1(CF)CCC1 O=C(O)C1CCC1
# True O=C(O)C1(C(F)F)CCC1 O=C(O)C1CCC1
# True O=C(O)C1(C(F)(F)F)CCC1 O=C(O)C1CCC1
# True O=C(O)[C@H]1C[C@H](C(F)(F)F)C1 O=C(O)C1CCC1
# True O=C(O)[C@H]1C[C@@H](C(F)(F)F)C1 O=C(O)C1CCC1
# True O=C(O)[C@H]1C[C@H](C(F)F)C1 O=C(O)C1CCC1
# True O=C(O)[C@H]1C[C@@H](C(F)F)C1 O=C(O)C1CCC1
# True O=C(O)[C@H]1C[C@H](CF)C1 O=C(O)C1CCC1
# True O=C(O)[C@H]1C[C@@H](CF)C1 O=C(O)C1CCC1
# True O=C(O)C1CC1(F)F O=C(O)C1CC1
# True O=C(O)C1CCC1(F)F O=C(O)C1CCC1
# True O=C(O)C1CC(F)(F)C1 O=C(O)C1CCC1
# True O=C(O)C1CCCC1(F)F O=C(O)C1CCCC1
# True O=C(O)C1CCC(F)(F)C1 O=C(O)C1CCCC1
# True O=C(O)C1CCCCC1(F)F O=C(O)C1CCCCC1
# True O=C(O)C1CCCCCC1(F)F O=C(O)C1CCCCCC1
# True O=C(O)C1CCCCC(F)(F)C1 O=C(O)C1CCCCCC1
# True O=C(O)C1CCCC(F)(F)CC1 O=C(O)C1CCCCCC1
# True CCC(F)(F)CC(=O)O CCCCC(=O)O
# True CC(F)(F)CCC(=O)O CCCCC(=O)O
# True O=C(O)C1CC1 O=C(O)C1CC1
# True O=C(O)C1CCCC1 O=C(O)C1CCCC1
# True O=C(O)C1CCCCCC1 O=C(O)C1CCCCCC1
# True CCCCC(=O)O CCCCC(=O)O
# True O=C(O)C1CC2(CCC2)C1 O=C(O)C1CC2(CCC2)C1
# True O=C(O)C1CC2(C1)CC(F)(F)C2 O=C(O)C1CC2(CCC2)C1
# False O=C(O)[C@@H]1CC[C@H]1C(F)(F)F O=C(O)[C@@H]1CCC1
# False O=C(O)[C@@H]1CC[C@H]1C(F)F O=C(O)[C@@H]1CCC1
# False O=C(O)[C@@H]1CC[C@H]1CF O=C(O)[C@@H]1CCC1
# False O=C(O)[C@@H]1C[C@H]1C(F)(F)F O=C(O)[C@@H]1CC1
# False O=C(O)[C@H]1C[C@H]1C(F)(F)F O=C(O)[C@@H]1CC1
# False O=C(O)[C@@H]1C[C@H]1C(F)F O=C(O)[C@@H]1CC1
# False O=C(O)[C@H]1C[C@H]1C(F)F O=C(O)[C@@H]1CC1
# False O=C(O)[C@@H]1C[C@H]1CF O=C(O)[C@@H]1CC1
# True C[C@@H]1C[C@H]1C(=O)O C[C@@H]1C[C@H]1C(=O)O
# True C[C@@H]1C[C@@H]1C(=O)O C[C@@H]1C[C@@H]1C(=O)O
# True O=C(O)C1C(F)(F)C12CC2 O=C(O)C1CC12CC2
# True FC(F)(F)C12CCC(CN1)C2 C1CC2CC1CN2
# True FC(F)(F)C1CCCN1 C1CCNC1
# True FC(F)(F)C1CCCCN1 C1CCNCC1
# True NC1CC12CC2(F)F NC1CC12CC2
# True NC1CCCC1(F)F NC1CCCC1
# True FC1(F)CCNCC1 C1CCNCC1
# True FC1(F)C2CCC1CNC2 C1CC2CNCC1C2
# True NC1CCC(F)(F)C1 NC1CCCC1
# True FC1CNC1 C1CNC1
# False N[C@@H]1CC[C@H]1C(F)F N[C@@H]1CCC1
# True C[C@@H]1C[C@@H]1N C[C@@H]1C[C@@H]1N
# True FCC1CCCCN1 C1CCNCC1
# True FCC1CCCN1 C1CCNC1
# True FCC1CCN1 C1CNC1
# True NC1CC2(C1)CC(F)C2 NC1CC2(CCC2)C1
# True FC(F)(F)C1CCNCC1 C1CCNCC1
# True CCCCN CCCCN
# True CC12CCC(CC1)CN2 CC12CCC(CC1)CN2
# True CC12CCCC(CN1)C2 CC12CCCC(CN1)C2
# True O=C(O)C1CC12CC2(F)F O=C(O)C1CC12CC2
# True O=C(O)C12CC(CO1)C2 O=C(O)C12CC(CO1)C2
# True O=C(O)C1CCCC(F)(F)C1 O=C(O)C1CCCCC1
# True O=C(O)[C@@H]1C[C@@H]2C[C@@H]2C1 O=C(O)[C@@H]1C[C@@H]2C[C@@H]2C1
# True O=C(O)C1CC2(CC(F)C2)C1 O=C(O)C1CC2(CCC2)C1
# True O=C(O)C1CC12CC2 O=C(O)C1CC12CC2
# False O=C(O)CCCC(F)F CCCC(=O)O

# %% [markdown]
# OUT OF SCOPE

# %%
import pandas as pd

pKa_df = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\pKa_basicity_data\gnn_cv_canon_smiles\train_test_for_SMILES_per_model.csv', index_col=0)

decreased_df = pKa_df.loc[[134, 100]]

# %%
decreased_df.to_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\pKa_basicity_data\gnn_cv_canon_smiles\train_test_for_SMILES_per_model_CF3_2_mols.csv')
