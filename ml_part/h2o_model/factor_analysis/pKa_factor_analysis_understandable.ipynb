# %%
import pandas as pd
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

train_df = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\csv_for_rulefit\train_pKa_v3.csv', index_col=0)
test_df = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\csv_for_rulefit\test_pKa_v3.csv', index_col=0)

merged_dataframe = pd.concat([train_df, test_df], axis=0)

merged_dataframe.rename(columns={"amine_type": "identificator"}, inplace=True)
merged_dataframe.drop(['molecule_type'], axis=1, inplace=True)

features_to_analyse = []
for feature_name in merged_dataframe.columns:
    if len(merged_dataframe[feature_name].unique()) > 1:
        features_to_analyse.append(feature_name)

features_to_drop = ['nFARing', 'nFAHRing', 'nFHRing', 'nAHRing', 'fold_id']

for feature_to_drop in features_to_drop:
    features_to_analyse.remove(feature_to_drop)

fa = FactorAnalyzer(rotation=None)

df_features = merged_dataframe[features_to_analyse]
df_features_darray = StandardScaler().fit_transform(df_features)
fa.fit(df_features_darray)

ev, _ = fa.get_eigenvalues()
for index, en_value in enumerate(ev):
    if en_value < 1:
        break
index += 1


plt.scatter(range(1, index + 1), ev[:index])
plt.plot(range(1, index + 1), ev[:index])
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.axhline(y = 1, color='r')
plt.grid()
plt.show()

# %%
from factor_analyzer.factor_analyzer import calculate_kmo

kmo_all, kmo_model = calculate_kmo(df_features)
kmo_model
# Out:
# c:\work\DrugDiscovery\drug-discovery-venv\Lib\site-packages\factor_analyzer\utils.py:244: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn(
# 0.6264509573214989

# %%
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity

chi_square_value, p_value = calculate_bartlett_sphericity(df_features_darray)
print(f"statistics: {chi_square_value}, p-value: {p_value}")
# Out:
# statistics: 20104.39738872372, p-value: 0.0

# %%
from sklearn.preprocessing import StandardScaler

n_factors = 10

fa = FactorAnalyzer(n_factors=n_factors, rotation="varimax")

fa.fit(df_features)

fa_load = pd.DataFrame(fa.loadings_,index=df_features.columns)
fa_load.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_0cc3f_row0_col0, #T_0cc3f_row16_col3 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_0cc3f_row0_col1, #T_0cc3f_row26_col8 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_0cc3f_row0_col2, #T_0cc3f_row5_col4, #T_0cc3f_row6_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_0cc3f_row0_col3, #T_0cc3f_row28_col8 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_0cc3f_row0_col4 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_0cc3f_row0_col5, #T_0cc3f_row3_col4, #T_0cc3f_row14_col9, #T_0cc3f_row18_col7 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_0cc3f_row0_col6, #T_0cc3f_row2_col6, #T_0cc3f_row6_col5, #T_0cc3f_row7_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_0cc3f_row0_col7, #T_0cc3f_row4_col2, #T_0cc3f_row5_col9, #T_0cc3f_row6_col0, #T_0cc3f_row7_col1, #T_0cc3f_row10_col0, #T_0cc3f_row12_col5, #T_0cc3f_row13_col8, #T_0cc3f_row17_col2, #T_0cc3f_row18_col3, #T_0cc3f_row23_col4, #T_0cc3f_row27_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0cc3f_row0_col8, #T_0cc3f_row11_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_0cc3f_row0_col9, #T_0cc3f_row2_col1, #T_0cc3f_row11_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_0cc3f_row1_col0, #T_0cc3f_row3_col8, #T_0cc3f_row12_col8, #T_0cc3f_row22_col9, #T_0cc3f_row24_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_0cc3f_row1_col1, #T_0cc3f_row23_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_0cc3f_row1_col2, #T_0cc3f_row4_col6, #T_0cc3f_row17_col6 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_0cc3f_row1_col3, #T_0cc3f_row7_col8, #T_0cc3f_row11_col8 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_0cc3f_row1_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_0cc3f_row1_col5 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_0cc3f_row1_col6, #T_0cc3f_row2_col2, #T_0cc3f_row26_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_0cc3f_row1_col7, #T_0cc3f_row8_col4, #T_0cc3f_row19_col4, #T_0cc3f_row25_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_0cc3f_row1_col8, #T_0cc3f_row12_col0, #T_0cc3f_row12_col3, #T_0cc3f_row23_col8 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_0cc3f_row1_col9, #T_0cc3f_row3_col7, #T_0cc3f_row5_col1, #T_0cc3f_row18_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_0cc3f_row2_col0, #T_0cc3f_row6_col7, #T_0cc3f_row8_col7 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_0cc3f_row2_col3 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_0cc3f_row2_col4, #T_0cc3f_row4_col7, #T_0cc3f_row6_col8, #T_0cc3f_row17_col7 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_0cc3f_row2_col5, #T_0cc3f_row11_col7 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_0cc3f_row2_col7, #T_0cc3f_row3_col9, #T_0cc3f_row5_col0, #T_0cc3f_row16_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_0cc3f_row2_col8, #T_0cc3f_row21_col4 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_0cc3f_row2_col9 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_0cc3f_row3_col0, #T_0cc3f_row19_col9 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_0cc3f_row3_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_0cc3f_row3_col2, #T_0cc3f_row22_col4, #T_0cc3f_row24_col0, #T_0cc3f_row24_col3 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_0cc3f_row3_col3, #T_0cc3f_row28_col4 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_0cc3f_row3_col5, #T_0cc3f_row28_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_0cc3f_row3_col6, #T_0cc3f_row5_col5, #T_0cc3f_row24_col9 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_0cc3f_row4_col0, #T_0cc3f_row11_col6, #T_0cc3f_row15_col8, #T_0cc3f_row17_col0, #T_0cc3f_row20_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_0cc3f_row4_col1, #T_0cc3f_row17_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_0cc3f_row4_col3, #T_0cc3f_row17_col3 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_0cc3f_row4_col4, #T_0cc3f_row17_col4, #T_0cc3f_row21_col5 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_0cc3f_row4_col5, #T_0cc3f_row17_col5, #T_0cc3f_row20_col5, #T_0cc3f_row29_col9 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_0cc3f_row4_col8, #T_0cc3f_row17_col8, #T_0cc3f_row21_col6, #T_0cc3f_row27_col8 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_0cc3f_row4_col9, #T_0cc3f_row17_col9 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_0cc3f_row5_col2, #T_0cc3f_row13_col6 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_0cc3f_row5_col3 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_0cc3f_row5_col6, #T_0cc3f_row11_col3, #T_0cc3f_row15_col7, #T_0cc3f_row16_col9, #T_0cc3f_row19_col8, #T_0cc3f_row20_col1, #T_0cc3f_row24_col2, #T_0cc3f_row24_col4, #T_0cc3f_row24_col6, #T_0cc3f_row25_col0, #T_0cc3f_row27_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0cc3f_row5_col7 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_0cc3f_row5_col8 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_0cc3f_row6_col1, #T_0cc3f_row21_col7, #T_0cc3f_row24_col8, #T_0cc3f_row26_col1 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_0cc3f_row6_col2, #T_0cc3f_row10_col2, #T_0cc3f_row15_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_0cc3f_row6_col3, #T_0cc3f_row21_col3, #T_0cc3f_row22_col3 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_0cc3f_row6_col6, #T_0cc3f_row24_col7, #T_0cc3f_row27_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_0cc3f_row6_col9 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_0cc3f_row7_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_0cc3f_row7_col2, #T_0cc3f_row23_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_0cc3f_row7_col3, #T_0cc3f_row10_col1, #T_0cc3f_row27_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_0cc3f_row7_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_0cc3f_row7_col5, #T_0cc3f_row10_col4, #T_0cc3f_row12_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_0cc3f_row7_col7, #T_0cc3f_row14_col7, #T_0cc3f_row26_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_0cc3f_row7_col9, #T_0cc3f_row12_col7, #T_0cc3f_row13_col4, #T_0cc3f_row13_col7, #T_0cc3f_row20_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_0cc3f_row8_col0, #T_0cc3f_row14_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_0cc3f_row8_col1, #T_0cc3f_row10_col3 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_0cc3f_row8_col2, #T_0cc3f_row11_col9, #T_0cc3f_row20_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_0cc3f_row8_col3 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_0cc3f_row8_col5, #T_0cc3f_row19_col7, #T_0cc3f_row25_col3, #T_0cc3f_row26_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_0cc3f_row8_col6, #T_0cc3f_row9_col9, #T_0cc3f_row14_col4, #T_0cc3f_row29_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_0cc3f_row8_col8 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_0cc3f_row8_col9, #T_0cc3f_row9_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_0cc3f_row9_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_0cc3f_row9_col2 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_0cc3f_row9_col3, #T_0cc3f_row14_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_0cc3f_row9_col4 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_0cc3f_row9_col5, #T_0cc3f_row21_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_0cc3f_row9_col6, #T_0cc3f_row14_col2, #T_0cc3f_row24_col1, #T_0cc3f_row27_col9 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_0cc3f_row9_col7 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_0cc3f_row9_col8, #T_0cc3f_row16_col8 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_0cc3f_row10_col5, #T_0cc3f_row18_col4, #T_0cc3f_row18_col6, #T_0cc3f_row19_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_0cc3f_row10_col6, #T_0cc3f_row10_col9, #T_0cc3f_row25_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }

# %%
explained_variance = fa.get_factor_variance()

variance_per_factor = explained_variance[0]

proportional_variance = explained_variance[1]

cumulative_variance = explained_variance[2]

print("Variance Per Factor:", variance_per_factor)
print("Propartional Variance:", proportional_variance)
print("Cumulative Variance:", cumulative_variance)
# Out:
# Variance Per Factor: [6.55952436 6.24207152 3.73846477 2.84847886 1.75763571 1.69282464
#  1.05694895 0.91185669 0.66093824 0.57223457]
# Propartional Variance: [0.21865081 0.20806905 0.12461549 0.0949493  0.05858786 0.05642749
#  0.03523163 0.03039522 0.02203127 0.01907449]
# Cumulative Variance: [0.21865081 0.42671986 0.55133536 0.64628465 0.70487251 0.7613
#  0.79653163 0.82692685 0.84895812 0.86803261]

# %% [markdown]
# -------------------------------------------

# %% [markdown]
# **ONLY AMINES**

# %%
import os
import sys
sys.path.insert(0, os.path.dirname('C:\work\DrugDiscovery\main_git\XAI_Chem\ml_part'))

import pandas as pd

from ml_part.random_forest.data_prep.preparation import DataPreparation
from ml_part.random_forest.train import RFTrain

CSV_PATH = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\remained_features_pKa_01.02_v2.csv'
smiles_filepath = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\smiles_to_index.pkl'

dataPreparation = DataPreparation(CSV_PATH)

unimportant_features_to_drop = ['logP']
X, y = dataPreparation.prepare_data_for_RF(is_pKa=True,
                                           molecule_type="amine",
                                           use_mandatory_features=True,
                                           is_remove_outliers=True,
                                           is_remove_nan=False,
                                           outliers_features_to_skip=unimportant_features_to_drop,)

correlated_features = ['f_atom_fraction', 'naHRing', 'nFaRing', 'nFaHRing', 'tpsa+f']
features_to_drop = []
for feature_name in X.columns:
    if feature_name in correlated_features:
        features_to_drop.append(feature_name)

X = X.drop(features_to_drop, axis=1)

rf_train = RFTrain(X=X, 
                   y=y,
                   smiles_filepath=smiles_filepath,
                   is_pKa=True,
                   k_folds=2)

y_train = rf_train.y_train
X_train = rf_train.X_train

y_test = rf_train.y_test
X_test = rf_train.X_test

train_df = pd.concat([X_train, y_train], axis=1)
test_df = pd.concat([X_test, y_test], axis=1)

print(len(train_df), len(test_df))
# Out:
# True
# 128
# ['avg_atoms_in_cycle', 'nFaHRing', 'chirality', 'PPSA5', 'tpsa+f', 'RPCS', 'mol_num_cycles', 'GeomShapeIndex', 'angle_R2X2R1', 'nN', 'distance_between_atoms_in_f_group_centers', 'nC', 'nFARing', 'angle_R1X1R2', 'f_freedom', 'naHRing', 'nFAHRing', 'cis/trans', 'dipole_moment', 'f_to_fg', 'identificator', 'f_atom_fraction', 'nFRing', 'nFaRing', 'naRing', 'nFHRing', 'PBF', 'nARing', 'nF', 'dihedral_angle', 'nAHRing', 'nO', 'TASA', 'angle_X2X1R1', 'mol_volume', 'FPSA3', 'PNSA5', 'angle_X1X2R2', 'nHRing', 'pKa', 'logP']
# dipole_moment outliers indexes: [27]
# f_atom_fraction outliers indexes: [69]
# mol_volume outliers indexes: [72]
# Remains rows:121, amount of features: 41
# 102 19

# %%
from factor_analyzer import FactorAnalyzer
from sklearn.preprocessing import StandardScaler
import pandas as pd
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns

merged_dataframe = pd.concat([train_df, test_df], axis=0)

features_to_analyse = []
for feature_name in merged_dataframe.columns:
    if len(merged_dataframe[feature_name].unique()) != 1:
        features_to_analyse.append(feature_name)
features_to_analyse.remove('fold_id')

fa = FactorAnalyzer(rotation=None)

df_features = merged_dataframe[features_to_analyse]
df_features_darray = StandardScaler().fit_transform(df_features)
fa.fit(df_features_darray)

ev, _ = fa.get_eigenvalues()
for index, en_value in enumerate(ev):
    if en_value < 1:
        break
index += 1


plt.scatter(range(1, index + 1), ev[:index])
plt.plot(range(1, index + 1), ev[:index])
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.axhline(y = 1, color='r')
plt.grid()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

n_factors = 10

fa = FactorAnalyzer(n_factors=n_factors, rotation="varimax")

fa.fit(df_features)

fa_load = pd.DataFrame(fa.loadings_,index=df_features.columns)
fa_load.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_46206_row0_col0, #T_46206_row12_col1, #T_46206_row18_col1, #T_46206_row30_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_46206_row0_col1, #T_46206_row22_col6, #T_46206_row26_col2, #T_46206_row27_col6 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_46206_row0_col2, #T_46206_row13_col1 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_46206_row0_col3, #T_46206_row1_col4, #T_46206_row14_col4, #T_46206_row24_col4 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_46206_row0_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_46206_row0_col5, #T_46206_row5_col5, #T_46206_row16_col7, #T_46206_row22_col3, #T_46206_row25_col7 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_46206_row0_col6, #T_46206_row1_col5, #T_46206_row4_col9, #T_46206_row6_col1, #T_46206_row9_col0, #T_46206_row11_col8, #T_46206_row16_col3, #T_46206_row17_col0, #T_46206_row20_col9, #T_46206_row21_col2, #T_46206_row24_col7, #T_46206_row25_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_46206_row0_col7 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_46206_row0_col8, #T_46206_row0_col9 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_46206_row1_col0, #T_46206_row9_col8, #T_46206_row10_col9, #T_46206_row15_col0, #T_46206_row17_col8, #T_46206_row29_col3, #T_46206_row30_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_46206_row1_col1, #T_46206_row7_col9, #T_46206_row24_col1, #T_46206_row25_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_46206_row1_col2, #T_46206_row7_col6 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_46206_row1_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_46206_row1_col6, #T_46206_row29_col4, #T_46206_row30_col6 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_46206_row1_col7, #T_46206_row27_col3, #T_46206_row32_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_46206_row1_col8, #T_46206_row7_col3, #T_46206_row10_col8, #T_46206_row12_col8, #T_46206_row18_col8, #T_46206_row24_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_46206_row1_col9, #T_46206_row15_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_46206_row2_col0, #T_46206_row3_col9 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_46206_row2_col1, #T_46206_row5_col4, #T_46206_row5_col8 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_46206_row2_col2 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_46206_row2_col3, #T_46206_row22_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_46206_row2_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_46206_row2_col5 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_46206_row2_col6, #T_46206_row16_col4 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_46206_row2_col7, #T_46206_row22_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_46206_row2_col8 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_46206_row2_col9 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_46206_row3_col0, #T_46206_row6_col3, #T_46206_row13_col0, #T_46206_row16_col9, #T_46206_row19_col7, #T_46206_row26_col0, #T_46206_row26_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_46206_row3_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_46206_row3_col2, #T_46206_row5_col3, #T_46206_row5_col6, #T_46206_row12_col9, #T_46206_row18_col9, #T_46206_row22_col8, #T_46206_row28_col0, #T_46206_row28_col4, #T_46206_row29_col1, #T_46206_row29_col2, #T_46206_row29_col7, #T_46206_row32_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_46206_row3_col3 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_46206_row3_col4, #T_46206_row4_col3, #T_46206_row20_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_46206_row3_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_46206_row3_col6 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_46206_row3_col7, #T_46206_row4_col5, #T_46206_row10_col0, #T_46206_row11_col4, #T_46206_row20_col5, #T_46206_row27_col9 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_46206_row3_col8 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_46206_row4_col0, #T_46206_row20_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_46206_row4_col1, #T_46206_row20_col1, #T_46206_row29_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_46206_row4_col2, #T_46206_row13_col4, #T_46206_row20_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_46206_row4_col4, #T_46206_row20_col4, #T_46206_row25_col6 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_46206_row4_col6, #T_46206_row11_col6, #T_46206_row20_col6 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_46206_row4_col7, #T_46206_row9_col9, #T_46206_row17_col9, #T_46206_row19_col3, #T_46206_row19_col5, #T_46206_row20_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_46206_row4_col8, #T_46206_row19_col1, #T_46206_row20_col8 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_46206_row5_col0, #T_46206_row10_col7, #T_46206_row21_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_46206_row5_col1, #T_46206_row24_col9, #T_46206_row32_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_46206_row5_col2, #T_46206_row26_col6 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_46206_row5_col7, #T_46206_row14_col5, #T_46206_row28_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_46206_row5_col9, #T_46206_row23_col8, #T_46206_row23_col9, #T_46206_row31_col8, #T_46206_row31_col9 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_46206_row6_col0, #T_46206_row9_col5, #T_46206_row17_col5, #T_46206_row30_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_46206_row6_col2 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_46206_row6_col4, #T_46206_row7_col8, #T_46206_row16_col8, #T_46206_row22_col4, #T_46206_row26_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_46206_row6_col5, #T_46206_row8_col7, #T_46206_row21_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_46206_row6_col6 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_46206_row6_col7 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_46206_row6_col8, #T_46206_row26_col3, #T_46206_row32_col8 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_46206_row6_col9, #T_46206_row23_col1, #T_46206_row31_col1 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_46206_row7_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_46206_row7_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_46206_row7_col2 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_46206_row7_col4, #T_46206_row21_col4, #T_46206_row24_col2, #T_46206_row26_col8, #T_46206_row27_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_46206_row7_col5, #T_46206_row9_col1, #T_46206_row17_col1, #T_46206_row32_col9 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_46206_row7_col7 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_46206_row8_col0 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_46206_row8_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_46206_row8_col2, #T_46206_row13_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_46206_row8_col3, #T_46206_row28_col1 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_46206_row8_col4 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_46206_row8_col5, #T_46206_row11_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_46206_row8_col6 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_46206_row8_col8, #T_46206_row12_col0, #T_46206_row18_col0 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_46206_row8_col9, #T_46206_row19_col9, #T_46206_row24_col8, #T_46206_row26_col9 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_46206_row9_col2, #T_46206_row16_col1, #T_46206_row17_col2 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_46206_row9_col3, #T_46206_row17_col3, #T_46206_row25_col8 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_46206_row9_col4, #T_46206_row12_col2, #T_46206_row14

# %% [markdown]
# -------------------------------------------

# %% [markdown]
# ONLY ACIDS

# %%
import os
import sys
sys.path.insert(0, os.path.dirname('C:\work\DrugDiscovery\main_git\XAI_Chem\ml_part'))

import pandas as pd

from ml_part.random_forest.data_prep.preparation import DataPreparation
from ml_part.random_forest.train import RFTrain

CSV_PATH = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\remained_features_pKa_01.02_v2.csv'
smiles_filepath = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\smiles_to_index.pkl'

dataPreparation = DataPreparation(CSV_PATH)

unimportant_features_to_drop = ['logP', 'RPCS']
X, y = dataPreparation.prepare_data_for_RF(is_pKa=True,
                                           molecule_type="acid",
                                           use_mandatory_features=True,
                                           is_remove_outliers=True,
                                           is_remove_nan=False,
                                           outliers_features_to_skip=unimportant_features_to_drop,)

correlated_features = ['f_atom_fraction', 'naHRing', 'nFaRing', 'nFaHRing', 'tpsa+f']
features_to_drop = []
for feature_name in X.columns:
    if feature_name in correlated_features:
        features_to_drop.append(feature_name)

X = X.drop(features_to_drop, axis=1)

rf_train = RFTrain(X=X, 
                   y=y,
                   smiles_filepath=smiles_filepath,
                   is_pKa=True,
                   k_folds=2)

y_train = rf_train.y_train
X_train = rf_train.X_train

y_test = rf_train.y_test
X_test = rf_train.X_test

train_df = pd.concat([X_train, y_train], axis=1)
test_df = pd.concat([X_test, y_test], axis=1)

print(len(train_df), len(test_df))
# Out:
# True
# 55
# ['avg_atoms_in_cycle', 'nFaHRing', 'chirality', 'PPSA5', 'tpsa+f', 'RPCS', 'mol_num_cycles', 'GeomShapeIndex', 'angle_R2X2R1', 'nN', 'distance_between_atoms_in_f_group_centers', 'nC', 'nFARing', 'angle_R1X1R2', 'f_freedom', 'naHRing', 'nFAHRing', 'cis/trans', 'dipole_moment', 'f_to_fg', 'identificator', 'f_atom_fraction', 'nFRing', 'nFaRing', 'naRing', 'nFHRing', 'PBF', 'nARing', 'nF', 'dihedral_angle', 'nAHRing', 'nO', 'TASA', 'angle_X2X1R1', 'mol_volume', 'FPSA3', 'PNSA5', 'angle_X1X2R2', 'nHRing', 'pKa', 'logP']
# PPSA5 outliers indexes: [39, 40]
# GeomShapeIndex outliers indexes: [50]
# distance_between_atoms_in_f_group_centers outliers indexes: [35]
# PBF outliers indexes: [40]
# FPSA3 outliers indexes: [40]
# Remains rows:50, amount of features: 41
# 43 7

# %%
from factor_analyzer import FactorAnalyzer
from sklearn.preprocessing import StandardScaler
import pandas as pd
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns

merged_dataframe = pd.concat([train_df, test_df], axis=0)

features_to_analyse = []
features_to_drop = []
for feature_name in merged_dataframe.columns:
    if len(merged_dataframe[feature_name].unique()) > 1:
        features_to_analyse.append(feature_name)
    if len(merged_dataframe[feature_name].unique()) == 2: 
        features_to_drop.append(feature_name)

features_to_drop = ['nFARing', 'nFAHRing', 'nFHRing', 'nAHRing', 'fold_id']

for feature_to_drop in features_to_drop:
    features_to_analyse.remove(feature_to_drop)

fa = FactorAnalyzer(rotation=None)

df_features = merged_dataframe[features_to_analyse]
df_features_to_drop = merged_dataframe[features_to_drop]
# df_features_darray = StandardScaler().fit_transform(df_features)
fa.fit(df_features)

ev, _ = fa.get_eigenvalues()
for index, en_value in enumerate(ev):
    if en_value < 1:
        break
index += 1


plt.scatter(range(1, index + 1), ev[:index])
plt.plot(range(1, index + 1), ev[:index])
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.axhline(y = 1, color='r')
plt.grid()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

n_factors = 7

fa = FactorAnalyzer(n_factors=n_factors, rotation="varimax")

fa.fit(df_features)

fa_load = pd.DataFrame(fa.loadings_,index=df_features.columns)
fa_load.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_151d1_row0_col0, #T_151d1_row27_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_151d1_row0_col1, #T_151d1_row18_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_151d1_row0_col2, #T_151d1_row18_col0 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_151d1_row0_col3 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_151d1_row0_col4, #T_151d1_row3_col4, #T_151d1_row18_col3 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_151d1_row0_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_151d1_row0_col6, #T_151d1_row5_col5, #T_151d1_row20_col5 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_151d1_row1_col0, #T_151d1_row2_col3, #T_151d1_row8_col6 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_151d1_row1_col1, #T_151d1_row20_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_151d1_row1_col2, #T_151d1_row18_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_151d1_row1_col3, #T_151d1_row5_col3, #T_151d1_row7_col6 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_151d1_row1_col4, #T_151d1_row4_col5, #T_151d1_row16_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_151d1_row1_col5, #T_151d1_row3_col3, #T_151d1_row6_col0, #T_151d1_row8_col2, #T_151d1_row10_col4, #T_151d1_row15_col6, #T_151d1_row19_col1, #T_151d1_row26_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_151d1_row1_col6, #T_151d1_row15_col5, #T_151d1_row24_col6, #T_151d1_row25_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_151d1_row2_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_151d1_row2_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_151d1_row2_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_151d1_row2_col4, #T_151d1_row11_col1, #T_151d1_row17_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_151d1_row2_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_151d1_row2_col6 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_151d1_row3_col0, #T_151d1_row4_col6, #T_151d1_row16_col6, #T_151d1_row22_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_151d1_row3_col1, #T_151d1_row9_col6 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_151d1_row3_col2, #T_151d1_row7_col1, #T_151d1_row25_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_151d1_row3_col5, #T_151d1_row10_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_151d1_row3_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_151d1_row4_col0, #T_151d1_row16_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_151d1_row4_col1, #T_151d1_row16_col1 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_151d1_row4_col2, #T_151d1_row16_col2 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_151d1_row4_col3, #T_151d1_row16_col3, #T_151d1_row27_col2 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_151d1_row4_col4, #T_151d1_row6_col1, #T_151d1_row16_col4, #T_151d1_row18_col2 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_151d1_row5_col0, #T_151d1_row13_col3 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_151d1_row5_col1, #T_151d1_row14_col3 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_151d1_row5_col2 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_151d1_row5_col4, #T_151d1_row14_col0, #T_151d1_row14_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_151d1_row5_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_151d1_row6_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_151d1_row6_col3, #T_151d1_row9_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_151d1_row6_col4, #T_151d1_row10_col6, #T_151d1_row17_col1, #T_151d1_row21_col6, #T_151d1_row27_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_151d1_row6_col5, #T_151d1_row12_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_151d1_row6_col6, #T_151d1_row12_col2, #T_151d1_row23_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_151d1_row7_col0 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_151d1_row7_col2, #T_151d1_row25_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_151d1_row7_col3, #T_151d1_row25_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_151d1_row7_col4, #T_151d1_row9_col5 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_151d1_row7_col5, #T_151d1_row21_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_151d1_row8_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_151d1_row8_col1, #T_151d1_row17_col6 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_151d1_row8_col3, #T_151d1_row14_col2, #T_151d1_row15_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_151d1_row8_col4 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_151d1_row8_col5, #T_151d1_row13_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_151d1_row9_col0 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_151d1_row9_col1, #T_151d1_row18_col4, #T_151d1_row19_col4, #T_151d1_row26_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_151d1_row9_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_151d1_row9_col4, #T_151d1_row15_col0 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_151d1_row10_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_151d1_row10_col1, #T_151d1_row21_col4, #T_151d1_row23_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_151d1_row10_col3 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_151d1_row10_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_151d1_row11_col0 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_151d1_row11_col2 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_151d1_row11_col3, #T_151d1_row21_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_151d1_row11_col4 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_151d1_row11_col5 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_151d1_row11_col6 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_151d1_row12_col0 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_151d1_row12_col3, #T_151d1_row22_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_151d1_row12_col4, #T_151d1_row19_col5, #T_151d1_row20_col3, #T_151d1_row23_col2, #T_151d1_row24_col0, #T_151d1_row26_col5, #T_151d1_row27_col1, #T_151d1_row27_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_151d1_row12_col5, #T_151d1_row19_col2, #T_151d1_row20_col0, #T_151d1_row25_col5, #T_151d1_row26_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_151d1_row12_col6 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_151d1_row13_col0 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_151d1_row13_col1, #T_151d1_row15_col4, #T_151d1_row18_col5, #T_151d1_row19_col3, #T_151d1_row26_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_151d1_row13_col2 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_151d1_row13_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_151d1_row13_col6 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_151d1_row14_col1 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_151d1_row14_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_151d1_row14_col5 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_151d1_row15_col1, #T_151d1_row19_col6, #T_151d1_row26_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_151d1_row15_col2, #T_151d1_row25_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_151d1_row17_col0, #T_151d1_row22_col2 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_151d1_row17_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_151d1_row17_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_151d1_row17_col5 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_151d1_row19_col0, #T_151d1_row26_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_151d1_row20_col2 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_151d1_row20_col4, #T_151d1_row21_col1, #T_151d1_row24_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_151d1
