# %%
import pandas as pd
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import numpy as np
from statistics import median

train_df = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\csv_for_rulefit\train_pKa_v3.csv', index_col=0)
test_df = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\csv_for_rulefit\test_pKa_v3.csv', index_col=0)

merged_dataframe = pd.concat([train_df, test_df], axis=0)

merged_dataframe.rename(columns={"amine_type": "identificator"}, inplace=True)
merged_dataframe.drop(['molecule_type'], axis=1, inplace=True)

features_to_analyse = []
for feature_name in merged_dataframe.columns:
    if len(merged_dataframe[feature_name].unique()) > 1:
        features_to_analyse.append(feature_name)

features_to_drop = ['nFARing', 'nFAHRing', 'nFHRing', 'nAHRing', 'fold_id']

for feature_to_drop in features_to_drop:
    features_to_analyse.remove(feature_to_drop)

fa = FactorAnalyzer(rotation=None)

df_features = merged_dataframe[features_to_analyse]
df_features_darray = StandardScaler().fit_transform(df_features)
fa.fit(df_features_darray)

ev, _ = fa.get_eigenvalues()
for index, en_value in enumerate(ev):
    if en_value < 1:
        break
index += 1

n_factors = 6

fa = FactorAnalyzer(n_factors=n_factors, rotation="varimax")

fa.fit(df_features)

fa_load = pd.DataFrame(fa.loadings_,index=df_features.columns)
fa_load.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_f2d2f_row0_col0, #T_f2d2f_row23_col3 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_f2d2f_row0_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_f2d2f_row0_col2, #T_f2d2f_row22_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_f2d2f_row0_col3, #T_f2d2f_row10_col5, #T_f2d2f_row20_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_f2d2f_row0_col4 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_f2d2f_row0_col5, #T_f2d2f_row21_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_f2d2f_row1_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_f2d2f_row1_col1, #T_f2d2f_row12_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_f2d2f_row1_col2, #T_f2d2f_row22_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_f2d2f_row1_col3 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_f2d2f_row1_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_f2d2f_row1_col5 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_f2d2f_row2_col0, #T_f2d2f_row4_col0, #T_f2d2f_row4_col4, #T_f2d2f_row17_col0, #T_f2d2f_row17_col4, #T_f2d2f_row28_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_f2d2f_row2_col1, #T_f2d2f_row27_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_f2d2f_row2_col2, #T_f2d2f_row10_col2, #T_f2d2f_row14_col2 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_f2d2f_row2_col3 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_f2d2f_row2_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_f2d2f_row2_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_f2d2f_row3_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_f2d2f_row3_col1 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_f2d2f_row3_col2, #T_f2d2f_row13_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_f2d2f_row3_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_f2d2f_row3_col4, #T_f2d2f_row12_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_f2d2f_row3_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_f2d2f_row4_col1, #T_f2d2f_row17_col1, #T_f2d2f_row21_col3 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_f2d2f_row4_col2, #T_f2d2f_row7_col1, #T_f2d2f_row9_col4, #T_f2d2f_row10_col0, #T_f2d2f_row12_col5, #T_f2d2f_row17_col2, #T_f2d2f_row18_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f2d2f_row4_col3, #T_f2d2f_row13_col1, #T_f2d2f_row17_col3 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_f2d2f_row4_col5, #T_f2d2f_row17_col5, #T_f2d2f_row25_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_f2d2f_row5_col0, #T_f2d2f_row22_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_f2d2f_row5_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_f2d2f_row5_col2 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_f2d2f_row5_col3 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_f2d2f_row5_col4, #T_f2d2f_row18_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_f2d2f_row5_col5, #T_f2d2f_row19_col4 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_f2d2f_row6_col0, #T_f2d2f_row22_col0 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_f2d2f_row6_col1 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_f2d2f_row6_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_f2d2f_row6_col3, #T_f2d2f_row15_col1 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_f2d2f_row6_col4, #T_f2d2f_row18_col5 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_f2d2f_row6_col5 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_f2d2f_row7_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_f2d2f_row7_col2, #T_f2d2f_row19_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_f2d2f_row7_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_f2d2f_row7_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_f2d2f_row7_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_f2d2f_row8_col0, #T_f2d2f_row21_col1 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_f2d2f_row8_col1, #T_f2d2f_row8_col3, #T_f2d2f_row22_col3 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_f2d2f_row8_col2, #T_f2d2f_row13_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_f2d2f_row8_col4, #T_f2d2f_row26_col5 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_f2d2f_row8_col5 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_f2d2f_row9_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_f2d2f_row9_col1, #T_f2d2f_row24_col5 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_f2d2f_row9_col2, #T_f2d2f_row14_col3 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_f2d2f_row9_col3, #T_f2d2f_row15_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_f2d2f_row9_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_f2d2f_row10_col1, #T_f2d2f_row16_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_f2d2f_row10_col3, #T_f2d2f_row16_col3 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_f2d2f_row10_col4, #T_f2d2f_row23_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_f2d2f_row11_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_f2d2f_row11_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_f2d2f_row11_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_f2d2f_row11_col3, #T_f2d2f_row20_col1, #T_f2d2f_row24_col2, #T_f2d2f_row24_col4, #T_f2d2f_row25_col0, #T_f2d2f_row27_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f2d2f_row11_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_f2d2f_row11_col5 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_f2d2f_row12_col1 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_f2d2f_row12_col3, #T_f2d2f_row27_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_f2d2f_row12_col4, #T_f2d2f_row20_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_f2d2f_row13_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_f2d2f_row13_col2 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_f2d2f_row13_col3 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_f2d2f_row14_col0 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_f2d2f_row14_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_f2d2f_row14_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_f2d2f_row14_col5, #T_f2d2f_row23_col1 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_f2d2f_row15_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_f2d2f_row15_col2 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_f2d2f_row15_col4, #T_f2d2f_row20_col2, #T_f2d2f_row21_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_f2d2f_row15_col5, #T_f2d2f_row27_col3 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_f2d2f_row16_col0, #T_f2d2f_row29_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_f2d2f_row16_col2 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_f2d2f_row16_col4 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_f2d2f_row16_col5 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_f2d2f_row18_col0 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_f2d2f_row18_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_f2d2f_row18_col2 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_f2d2f_row19_col0 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_f2d2f_row19_col1 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_f2d2f_row19_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_f2d2f_row19_col5 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_f2d2f_row20_col3 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_f2d2f_row20_col5, #T_f2d2f_row29_col3 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_f2d2f_row21_col2, #T_f2d2f_row23_col0, #T_f2d2f_row28_col0 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_f2d2f_row21_col4 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_f2d2f_row22_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_f2d2f_row23_col2 {
#   background-color: #e4d9d2;
#   color:

# %%
medians_for_features = {}
for feature_name in df_features.columns:
    medians_for_features[feature_name] = median(df_features[feature_name])

medians_for_features
# Out:
# {'avg_atoms_in_cycle': 4.0,
#  'chirality': 0,
#  'PPSA5': 11.306940529954163,
#  'RPCS': 16.5901927054261,
#  'mol_num_cycles': 1,
#  'GeomShapeIndex': 0.6422838373782467,
#  'angle_R2X2R1': 103.44173207136691,
#  'nN': 1,
#  'distance_between_atoms_in_f_group_centers': 1.498352188301075,
#  'nC': 5,
#  'angle_R1X1R2': 99.26138155009872,
#  'f_freedom': 1,
#  'cis/trans': 0,
#  'dipole_moment': 0.3913210742586738,
#  'f_to_fg': 2.0,
#  'nFRing': 0,
#  'PBF': 0.670246346273359,
#  'nARing': 1,
#  'nF': 2,
#  'dihedral_angle': 2.6122304011075688,
#  'nO': 0,
#  'TASA': 191.30629717730744,
#  'angle_X2X1R1': 111.73009521109194,
#  'mol_volume': 110.85,
#  'FPSA3': 0.0373397997635106,
#  'PNSA5': -16.940435357676453,
#  'angle_X1X2R2': 116.07898596286806,
#  'nHRing': 0,
#  'identificator': 1,
#  'pKa': 7.78}

# %%
features_names = df_features.columns
fa_loadings = fa.loadings_

for factor_index in range(n_factors):
    important_features_in_factor = []
    is_inverted = []
    for feature_index in range(len(fa_loadings[:,factor_index])):
        if abs(fa_loadings[feature_index][factor_index]) > 0.7 and features_names[feature_index] != 'pKa':
            important_features_in_factor.append(features_names[feature_index])
            if fa_loadings[feature_index][factor_index] > 0: is_inverted.append(False)
            else: is_inverted.append(True)
    
    print(important_features_in_factor)
    print(is_inverted)
    
    
    lower_pKa = set()
    higher_pKa = set()
    for important_feature_in_factor_index in range(len(important_features_in_factor)):
        feature_name = important_features_in_factor[important_feature_in_factor_index]
        for index, row in df_features.iterrows():
            if row[feature_name] > medians_for_features[feature_name] and is_inverted[important_feature_in_factor_index] == False or \
                row[feature_name] < medians_for_features[feature_name] and is_inverted[important_feature_in_factor_index] == True:        
                higher_pKa.add(row['pKa'])
            if row[feature_name] >= medians_for_features[feature_name] and is_inverted[important_feature_in_factor_index] == True or \
                row[feature_name] <= medians_for_features[feature_name] and is_inverted[important_feature_in_factor_index] == False:        
                lower_pKa.add(row['pKa'])
    
    print(f"higher_pKa: {sum(higher_pKa) / len(higher_pKa)}")
    print(f"lower_pKa: {sum(lower_pKa) / len(lower_pKa)}")

    print("-"*20)
# Out:
# ['angle_R2X2R1', 'distance_between_atoms_in_f_group_centers', 'angle_R1X1R2', 'f_to_fg', 'angle_X2X1R1', 'angle_X1X2R2']
# [False, False, False, False, False, False]
# higher_pKa: 7.096304347826084
# lower_pKa: 7.5412056737588635
# --------------------
# ['PPSA5', 'nN', 'nO', 'FPSA3', 'PNSA5', 'identificator']
# [True, False, True, True, False, False]
# higher_pKa: 8.449729729729727
# lower_pKa: 7.517945205479451
# --------------------
# ['mol_num_cycles', 'nFRing', 'nARing']
# [False, False, False]
# higher_pKa: 7.788857142857145
# lower_pKa: 7.369999999999997
# --------------------
# ['f_freedom', 'nF']
# [True, False]
# higher_pKa: 6.5356250000000005
# lower_pKa: 7.655163934426227
# --------------------
# ['nC', 'mol_volume']
# [False, False]
# higher_pKa: 6.955949367088609
# lower_pKa: 7.956111111111108
# --------------------
# ['chirality', 'cis/trans']
# [False, False]
# higher_pKa: 6.671463414634147
# lower_pKa: 7.598347107438013
# --------------------

# %% [markdown]
# Only for amine molecules

# %%
import os
import sys
sys.path.insert(0, os.path.dirname('C:\work\DrugDiscovery\main_git\XAI_Chem\ml_part'))

import pandas as pd

from ml_part.random_forest.data_prep.preparation import DataPreparation
from ml_part.random_forest.train import RFTrain

CSV_PATH = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\remained_features_pKa_01.02_v2.csv'
smiles_filepath = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\smiles_to_index.pkl'

dataPreparation = DataPreparation(CSV_PATH)

unimportant_features_to_drop = ['logP']
X, y = dataPreparation.prepare_data_for_RF(is_pKa=True,
                                           molecule_type="amine",
                                           use_mandatory_features=True,
                                           is_remove_outliers=True,
                                           is_remove_nan=False,
                                           outliers_features_to_skip=unimportant_features_to_drop,)

correlated_features = ['f_atom_fraction', 'naHRing', 'nFaRing', 'nFaHRing', 'tpsa+f']
features_to_drop = []
for feature_name in X.columns:
    if feature_name in correlated_features:
        features_to_drop.append(feature_name)

X = X.drop(features_to_drop, axis=1)

rf_train = RFTrain(X=X, 
                   y=y,
                   smiles_filepath=smiles_filepath,
                   is_pKa=True,
                   k_folds=2)

y_train = rf_train.y_train
X_train = rf_train.X_train

y_test = rf_train.y_test
X_test = rf_train.X_test

train_df = pd.concat([X_train, y_train], axis=1)
test_df = pd.concat([X_test, y_test], axis=1)

print(len(train_df), len(test_df))
# Out:
# True
# 128
# ['avg_atoms_in_cycle', 'nFaHRing', 'chirality', 'PPSA5', 'tpsa+f', 'RPCS', 'mol_num_cycles', 'GeomShapeIndex', 'angle_R2X2R1', 'nN', 'distance_between_atoms_in_f_group_centers', 'nC', 'nFARing', 'angle_R1X1R2', 'f_freedom', 'naHRing', 'nFAHRing', 'cis/trans', 'dipole_moment', 'f_to_fg', 'identificator', 'f_atom_fraction', 'nFRing', 'nFaRing', 'naRing', 'nFHRing', 'PBF', 'nARing', 'nF', 'dihedral_angle', 'nAHRing', 'nO', 'TASA', 'angle_X2X1R1', 'mol_volume', 'FPSA3', 'PNSA5', 'angle_X1X2R2', 'nHRing', 'pKa', 'logP']
# dipole_moment outliers indexes: [27]
# f_atom_fraction outliers indexes: [69]
# mol_volume outliers indexes: [72]
# Remains rows:121, amount of features: 41
# 102 19

# %%
from factor_analyzer import FactorAnalyzer
from sklearn.preprocessing import StandardScaler
import pandas as pd
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns

merged_dataframe = pd.concat([train_df, test_df], axis=0)

# merged_dataframe.rename(columns={"amine_type": "identificator"}, inplace=True)

# indexes_to_drop = []
# for index, row in merged_dataframe.iterrows():
#     if row['distance_between_atoms_in_f_group_centers'] == 0:
#         indexes_to_drop.append(index)
# merged_dataframe.drop(indexes_to_drop, axis=0, inplace=True)

features_to_analyse = []
for feature_name in merged_dataframe.columns:
    if len(merged_dataframe[feature_name].unique()) > 1:
        features_to_analyse.append(feature_name)

features_to_drop = ['nFARing', 'nFAHRing', 'nFHRing', 'nAHRing', 'fold_id']

for feature_to_drop in features_to_drop:
    features_to_analyse.remove(feature_to_drop)

fa = FactorAnalyzer(rotation=None)


df_features = merged_dataframe[features_to_analyse]
df_features_darray = StandardScaler().fit_transform(df_features)
fa.fit(df_features_darray)

ev, _ = fa.get_eigenvalues()
for index, en_value in enumerate(ev):
    if en_value < 1:
        break
index += 1

n_factors = 7

fa = FactorAnalyzer(n_factors=n_factors, rotation="varimax")
fa.fit(df_features)

fa_load = pd.DataFrame(fa.loadings_,index=df_features.columns)
fa_load.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_1d8e8_row0_col0 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_1d8e8_row0_col1, #T_1d8e8_row7_col6, #T_1d8e8_row10_col4 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_1d8e8_row0_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_1d8e8_row0_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_1d8e8_row0_col4, #T_1d8e8_row27_col5 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_1d8e8_row0_col5 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_1d8e8_row0_col6, #T_1d8e8_row9_col4, #T_1d8e8_row14_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_1d8e8_row1_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_1d8e8_row1_col1, #T_1d8e8_row11_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_1d8e8_row1_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_1d8e8_row1_col3, #T_1d8e8_row11_col5, #T_1d8e8_row12_col4, #T_1d8e8_row19_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_1d8e8_row1_col4, #T_1d8e8_row4_col2, #T_1d8e8_row6_col0, #T_1d8e8_row14_col3, #T_1d8e8_row17_col2, #T_1d8e8_row18_col1, #T_1d8e8_row23_col5, #T_1d8e8_row24_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1d8e8_row1_col5 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_1d8e8_row1_col6, #T_1d8e8_row9_col6, #T_1d8e8_row14_col2, #T_1d8e8_row16_col6, #T_1d8e8_row22_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_1d8e8_row2_col0, #T_1d8e8_row11_col0, #T_1d8e8_row22_col6 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_1d8e8_row2_col1 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_1d8e8_row2_col2, #T_1d8e8_row25_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_1d8e8_row2_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_1d8e8_row2_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_1d8e8_row2_col5, #T_1d8e8_row3_col6, #T_1d8e8_row25_col5 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_1d8e8_row2_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_1d8e8_row3_col0, #T_1d8e8_row10_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_1d8e8_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_1d8e8_row3_col2, #T_1d8e8_row6_col3, #T_1d8e8_row10_col5 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_1d8e8_row3_col3, #T_1d8e8_row14_col6 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_1d8e8_row3_col4, #T_1d8e8_row26_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_1d8e8_row3_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_1d8e8_row4_col0, #T_1d8e8_row7_col3, #T_1d8e8_row17_col0, #T_1d8e8_row23_col6 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_1d8e8_row4_col1, #T_1d8e8_row17_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_1d8e8_row4_col3, #T_1d8e8_row11_col6, #T_1d8e8_row17_col3 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_1d8e8_row4_col4, #T_1d8e8_row17_col4, #T_1d8e8_row18_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_1d8e8_row4_col5, #T_1d8e8_row17_col5, #T_1d8e8_row19_col5, #T_1d8e8_row28_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_1d8e8_row4_col6, #T_1d8e8_row17_col6, #T_1d8e8_row22_col2 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_1d8e8_row5_col0, #T_1d8e8_row12_col3, #T_1d8e8_row19_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_1d8e8_row5_col1, #T_1d8e8_row7_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_1d8e8_row5_col2, #T_1d8e8_row18_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_1d8e8_row5_col3, #T_1d8e8_row5_col5, #T_1d8e8_row21_col6, #T_1d8e8_row24_col2, #T_1d8e8_row25_col0, #T_1d8e8_row25_col1, #T_1d8e8_row27_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1d8e8_row5_col4, #T_1d8e8_row15_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_1d8e8_row5_col6, #T_1d8e8_row26_col6 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_1d8e8_row6_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_1d8e8_row6_col2, #T_1d8e8_row8_col6, #T_1d8e8_row20_col0, #T_1d8e8_row26_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_1d8e8_row6_col4, #T_1d8e8_row26_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_1d8e8_row6_col5, #T_1d8e8_row11_col2, #T_1d8e8_row18_col6, #T_1d8e8_row28_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_1d8e8_row6_col6, #T_1d8e8_row10_col3 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_1d8e8_row7_col0 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_1d8e8_row7_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_1d8e8_row7_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_1d8e8_row7_col5, #T_1d8e8_row12_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_1d8e8_row8_col0, #T_1d8e8_row25_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_1d8e8_row8_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_1d8e8_row8_col2 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_1d8e8_row8_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_1d8e8_row8_col4 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_1d8e8_row8_col5 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_1d8e8_row9_col0 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_1d8e8_row9_col1 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_1d8e8_row9_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_1d8e8_row9_col3 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_1d8e8_row9_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_1d8e8_row10_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_1d8e8_row10_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_1d8e8_row10_col6 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_1d8e8_row11_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_1d8e8_row11_col4 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_1d8e8_row12_col0, #T_1d8e8_row13_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_1d8e8_row12_col1 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_1d8e8_row12_col5, #T_1d8e8_row16_col5 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_1d8e8_row12_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_1d8e8_row13_col0 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_1d8e8_row13_col1 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_1d8e8_row13_col2, #T_1d8e8_row16_col0, #T_1d8e8_row28_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_1d8e8_row13_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_1d8e8_row13_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_1d8e8_row13_col5 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_1d8e8_row14_col0, #T_1d8e8_row28_col6 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_1d8e8_row14_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_1d8e8_row14_col4 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_1d8e8_row15_col1, #T_1d8e8_row21_col1, #T_1d8e8_row27_col6 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_1d8e8_row15_col2 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_1d8e8_row15_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_1d8e8_row15_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_1d8e8_row15_col5 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_1d8e8_row15_col6 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_1d8e8_row16_col1 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_1d8e8_row16_col2 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_1d8e8_row16_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_1d8e8_row16_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_1d8e8_row18_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_1d8e8_row18_col3, #T_1d8e8_row20_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_1d8e8_row18_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_1d8e8_row19_col0 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_1d8e8_row19_col1 {
#   background-color: #e5d8d1;

# %%
medians_for_features = {}
for feature_name in df_features.columns:
    medians_for_features[feature_name] = median(df_features[feature_name])

medians_for_features
# Out:
# {'avg_atoms_in_cycle': 4.0,
#  'chirality': 0,
#  'PPSA5': 10.452837258190042,
#  'RPCS': 7.150318535820773,
#  'mol_num_cycles': 1,
#  'GeomShapeIndex': 0.5851234407622666,
#  'angle_R2X2R1': 100.17253184454503,
#  'distance_between_atoms_in_f_group_centers': 1.5285813872197025,
#  'nC': 5,
#  'angle_R1X1R2': 99.6408048541743,
#  'f_freedom': 1,
#  'cis/trans': 0,
#  'dipole_moment': 0.3931144784664414,
#  'f_to_fg': 2.0,
#  'identificator': 2,
#  'nFRing': 0,
#  'PBF': 0.6589667081744836,
#  'nARing': 1,
#  'nF': 2,
#  'dihedral_angle': 2.996612139414393,
#  'nO': 0,
#  'TASA': 211.36519837472065,
#  'angle_X2X1R1': 115.17801686108022,
#  'mol_volume': 106.57,
#  'FPSA3': 0.034808443256566,
#  'PNSA5': -14.710723928759617,
#  'angle_X1X2R2': 115.92053903765051,
#  'nHRing': 1,
#  'pKa': 9.05}

# %%
features_names = df_features.columns
fa_loadings = fa.loadings_

for factor_index in range(n_factors):
    important_features_in_factor = []
    is_inverted = []
    for feature_index in range(len(fa_loadings[:,factor_index])):
        if abs(fa_loadings[feature_index][factor_index]) > 0.5 and features_names[feature_index] != 'pKa':
            important_features_in_factor.append(features_names[feature_index])
            if fa_loadings[feature_index][factor_index] > 0: is_inverted.append(False)
            else: is_inverted.append(True)
    
    print(f"Factor number: {factor_index}")
    print(important_features_in_factor)
    print(is_inverted)
    
    
    lower_pKa = set()
    higher_pKa = set()
    for important_feature_in_factor_index in range(len(important_features_in_factor)):
        feature_name = important_features_in_factor[important_feature_in_factor_index]
        for index, row in df_features.iterrows():
            if row[feature_name] > medians_for_features[feature_name] and is_inverted[important_feature_in_factor_index] == False or \
                row[feature_name] < medians_for_features[feature_name] and is_inverted[important_feature_in_factor_index] == True:        
                higher_pKa.add(row['pKa'])
            if row[feature_name] >= medians_for_features[feature_name] and is_inverted[important_feature_in_factor_index] == True or \
                row[feature_name] <= medians_for_features[feature_name] and is_inverted[important_feature_in_factor_index] == False:        
                lower_pKa.add(row['pKa'])
    
    print(f"higher_pKa: {sum(higher_pKa) / len(higher_pKa)}")
    print(f"lower_pKa: {sum(lower_pKa) / len(lower_pKa)}")

    print("-"*20)
# Out:
# Factor number: 0
# ['avg_atoms_in_cycle', 'angle_R2X2R1', 'distance_between_atoms_in_f_group_centers', 'angle_R1X1R2', 'f_to_fg', 'dihedral_angle', 'angle_X2X1R1', 'angle_X1X2R2']
# [False, False, False, False, False, False, False, False]
# higher_pKa: 8.480126582278478
# lower_pKa: 8.892621359223297
# --------------------
# Factor number: 1
# ['PPSA5', 'RPCS', 'f_freedom', 'dipole_moment', 'f_to_fg', 'nF', 'PNSA5']
# [False, True, True, False, False, False, True]
# higher_pKa: 8.10756756756757
# lower_pKa: 8.844339622641504
# --------------------
# Factor number: 2
# ['mol_num_cycles', 'nC', 'nFRing', 'PBF', 'nARing', 'mol_volume']
# [False, False, False, False, False, False]
# higher_pKa: 8.688533333333336
# lower_pKa: 8.869230769230766
# --------------------
# Factor number: 3
# ['identificator', 'nHRing']
# [False, False]
# higher_pKa: 9.052222222222222
# lower_pKa: 8.798611111111109
# --------------------
# Factor number: 4
# ['chirality', 'cis/trans']
# [False, False]
# higher_pKa: 8.2816
# lower_pKa: 8.964269662921344
# --------------------
# Factor number: 5
# ['nC', 'mol_volume']
# [False, False]
# higher_pKa: 8.75311475409836
# lower_pKa: 8.767702702702708
# --------------------
# Factor number: 6
# ['TASA', 'FPSA3']
# [True, False]
# higher_pKa: 8.856760563380284
# lower_pKa: 8.839726027397262
# --------------------

# %% [markdown]
# compare chirality/cis-trans

# %%
important_features_in_factor = ['chirality', 'cis/trans']
is_inverted = [False, False]

lower_pKa = []
higher_pKa = []
for index, row in df_features.iterrows():
    if row['cis/trans'] == 0 and row['chirality'] == 0:
        higher_pKa.append(row['pKa'])
    if row['cis/trans'] == 1 and row['chirality'] != 0:
        lower_pKa.append(row['pKa'])
    # if row['chirality'] == 0:
    #     print(row['chirality'], row['pKa'])
    #     higher_pKa.append(row['pKa'])
    # if row['chirality'] > 0:
    #     lower_pKa.append(row['pKa'])
    #     print(row['chirality'], row['pKa'])

print(len(higher_pKa))
print(len(lower_pKa))

if len(higher_pKa) > 0: print(f"higher_pKa: {sum(higher_pKa) / len(higher_pKa)}")
if len(lower_pKa) > 0: print(f"lower_pKa: {sum(lower_pKa) / len(lower_pKa)}")
# Out:
# 96
# 8
# higher_pKa: 8.988020833333339
# lower_pKa: 7.84875

# %%
median_angle_value = median(df_features[df_features['angle_X1X2R2'] > 0]['angle_X1X2R2'])
median_angle_value
# Out:
# 136.66370418803444

# %% [markdown]
# Angles investigation

# %% [markdown]
# top angle in features: R1X1R2

# %%
important_features_in_factor = ['chirality', 'cis/trans']
is_inverted = [False, False]

lower_pKa = []
higher_pKa = []
for index, row in df_features.iterrows():
    if row['angle_X1X2R2'] == 0: continue
    if row['angle_X1X2R2'] > median_angle_value:
        higher_pKa.append(row['pKa'])
    if row['angle_X1X2R2'] < median_angle_value:
        lower_pKa.append(row['pKa'])
    # print(row['angle_R1X1R2'], row['pKa'])

print(len(higher_pKa))
print(len(lower_pKa))

print(f"higher_pKa: {sum(higher_pKa) / len(higher_pKa)}")
print(f"lower_pKa: {sum(lower_pKa) / len(lower_pKa)}")
# Out:
# 38
# 38
# higher_pKa: 8.487894736842106
# lower_pKa: 7.895526315789475

# %% [markdown]
# is functional groups in one side:

# %%
lower_pKa = []
higher_pKa = []
for index, row in df_features.iterrows():
    if row['angle_R1X1R2'] == 0 or row['angle_X2X1R1'] == 0: continue
    if row['angle_R1X1R2'] > row['angle_X2X1R1']: # different sides
        # print("trans", row['cis/trans'])
        higher_pKa.append(row['pKa'])
    if row['angle_R1X1R2'] < row['angle_X2X1R1']: # same sides
        # print("cis", row['cis/trans'])
        lower_pKa.append(row['pKa'])
    # print(row['angle_R1X1R2'], row['pKa'])

print(len(higher_pKa))
print(len(lower_pKa))

print(f"higher_pKa: {sum(higher_pKa) / len(higher_pKa)}")
print(f"lower_pKa: {sum(lower_pKa) / len(lower_pKa)}")
# Out:
# 32
# 44
# higher_pKa: 8.4140625
# lower_pKa: 8.030000000000003

# %% [markdown]
# short and long distances

# %%
median_distance_value = median(df_features[df_features['distance_between_atoms_in_f_group_centers'] > 0]['distance_between_atoms_in_f_group_centers'])
print("median:", median_distance_value)

lower_pKa = []
higher_pKa = []
for index, row in df_features.iterrows():
    if row['distance_between_atoms_in_f_group_centers'] == 0: continue
    if row['distance_between_atoms_in_f_group_centers'] > median_distance_value + 1: # different sides
        # print("trans", row['cis/trans'])
        higher_pKa.append(row['pKa'])
    if row['distance_between_atoms_in_f_group_centers'] < median_distance_value - 1: # same sides
        # print("cis", row['cis/trans'])
        lower_pKa.append(row['pKa'])
    # print(row['angle_R1X1R2'], row['pKa'])

print(len(higher_pKa))
print(len(lower_pKa))

print(f"higher_pKa: {sum(higher_pKa) / len(higher_pKa)}")
print(f"lower_pKa: {sum(lower_pKa) / len(lower_pKa)}")
# Out:
# median: 2.944062277480133
# 20
# 21
# higher_pKa: 8.796000000000001
# lower_pKa: 8.345238095238095

# %% [markdown]
# identificator check

# %%
lower_pKa = []
higher_pKa = []
for index, row in df_features.iterrows():
    if row['identificator'] == 1: # different sides
        # print("trans", row['cis/trans'])
        higher_pKa.append(row['pKa'])
    if row['identificator'] == 2: # same sides
        # print("cis", row['cis/trans'])
        lower_pKa.append(row['pKa'])
    # print(row['angle_R1X1R2'], row['pKa'])

print(f"higher_pKa: {sum(higher_pKa) / len(higher_pKa)}")
print(f"lower_pKa: {sum(lower_pKa) / len(lower_pKa)}")
# Out:
# higher_pKa: 8.58655172413793
# lower_pKa: 7.948085106382981

# %% [markdown]
# dipole_moment

# %%
median_value = median(df_features['PPSA5'])
print("median:", median_value)

lower_pKa = []
higher_pKa = []
for index, row in df_features.iterrows():
    if row['PPSA5'] == 0: continue
    if row['PPSA5'] > median_value: # different sides
        # print("trans", row['cis/trans'])
        higher_pKa.append(row['pKa'])
    if row['PPSA5'] < median_value: # same sides
        # print("cis", row['cis/trans'])
        lower_pKa.append(row['pKa'])
    # print(row['angle_R1X1R2'], row['pKa'])

print(len(higher_pKa))
print(len(lower_pKa))

print(f"higher_pKa: {sum(higher_pKa) / len(higher_pKa)}")
print(f"lower_pKa: {sum(lower_pKa) / len(lower_pKa)}")
# Out:
# median: 10.452837258190042
# 60
# 60
# higher_pKa: 7.977000000000003
# lower_pKa: 9.697000000000001
