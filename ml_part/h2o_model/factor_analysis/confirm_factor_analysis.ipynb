# %%
import os
import sys
sys.path.insert(0, os.path.dirname('C:\work\DrugDiscovery\main_git\XAI_Chem\ml_part'))

import pandas as pd

from ml_part.random_forest.data_prep.preparation import DataPreparation
from ml_part.random_forest.train import RFTrain

CSV_PATH = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\remained_features_pKa_01.02_v2.csv'
smiles_filepath = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\smiles_to_index.pkl'

dataPreparation = DataPreparation(CSV_PATH)

unimportant_features_to_drop = ['logP']
X, y = dataPreparation.prepare_data_for_RF(is_pKa=True,
                                           molecule_type="amine",
                                           use_mandatory_features=True,
                                           is_remove_outliers=True,
                                           is_remove_nan=False,
                                           outliers_features_to_skip=unimportant_features_to_drop,)

correlated_features = ['f_atom_fraction', 'naHRing', 'nFaRing', 'nFaHRing', 'tpsa+f']
features_to_drop = []
for feature_name in X.columns:
    if feature_name in correlated_features:
        features_to_drop.append(feature_name)

X = X.drop(features_to_drop, axis=1)

rf_train = RFTrain(X=X, 
                   y=y,
                   smiles_filepath=smiles_filepath,
                   is_pKa=True,
                   k_folds=2)

y_train = rf_train.y_train
X_train = rf_train.X_train

y_test = rf_train.y_test
X_test = rf_train.X_test

train_df = pd.concat([X_train, y_train], axis=1)
test_df = pd.concat([X_test, y_test], axis=1)

print(len(train_df), len(test_df))
# Out:
# True
# 128
# ['avg_atoms_in_cycle', 'nFaHRing', 'chirality', 'PPSA5', 'tpsa+f', 'RPCS', 'mol_num_cycles', 'GeomShapeIndex', 'angle_R2X2R1', 'nN', 'distance_between_atoms_in_f_group_centers', 'nC', 'nFARing', 'angle_R1X1R2', 'f_freedom', 'naHRing', 'nFAHRing', 'cis/trans', 'dipole_moment', 'f_to_fg', 'identificator', 'f_atom_fraction', 'nFRing', 'nFaRing', 'naRing', 'nFHRing', 'PBF', 'nARing', 'nF', 'dihedral_angle', 'nAHRing', 'nO', 'TASA', 'angle_X2X1R1', 'mol_volume', 'FPSA3', 'PNSA5', 'angle_X1X2R2', 'nHRing', 'pKa', 'logP']
# dipole_moment outliers indexes: [27]
# f_atom_fraction outliers indexes: [69]
# mol_volume outliers indexes: [72]
# Remains rows:121, amount of features: 41
# 102 19

# %%
from factor_analyzer import FactorAnalyzer
from sklearn.preprocessing import StandardScaler
import pandas as pd
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns

merged_dataframe = pd.concat([train_df, test_df], axis=0)

# merged_dataframe.rename(columns={"amine_type": "identificator"}, inplace=True)

features_to_analyse = []
for feature_name in merged_dataframe.columns:
    if len(merged_dataframe[feature_name].unique()) > 1:
        features_to_analyse.append(feature_name)

features_to_drop = ['nFARing', 'nFAHRing', 'nFHRing', 'nAHRing', 'fold_id']

for feature_to_drop in features_to_drop:
    features_to_analyse.remove(feature_to_drop)

fa = FactorAnalyzer(rotation=None)


df_features = merged_dataframe[features_to_analyse]
df_features_darray = StandardScaler().fit_transform(df_features)
fa.fit(df_features_darray)

ev, _ = fa.get_eigenvalues()
for index, en_value in enumerate(ev):
    if en_value < 1:
        break
index += 1

n_factors = 7

fa = FactorAnalyzer(n_factors=n_factors, rotation="varimax")
fa.fit(df_features)

fa_load = pd.DataFrame(fa.loadings_,index=df_features.columns)
fa_load.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_afbde_row0_col0 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_afbde_row0_col1, #T_afbde_row7_col6, #T_afbde_row10_col4 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_afbde_row0_col2 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_afbde_row0_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_afbde_row0_col4, #T_afbde_row27_col5 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_afbde_row0_col5 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_afbde_row0_col6, #T_afbde_row9_col4, #T_afbde_row14_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_afbde_row1_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_afbde_row1_col1, #T_afbde_row11_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_afbde_row1_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_afbde_row1_col3, #T_afbde_row11_col5, #T_afbde_row12_col4, #T_afbde_row19_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_afbde_row1_col4, #T_afbde_row4_col2, #T_afbde_row6_col0, #T_afbde_row14_col3, #T_afbde_row17_col2, #T_afbde_row18_col1, #T_afbde_row23_col5, #T_afbde_row24_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_afbde_row1_col5 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_afbde_row1_col6, #T_afbde_row9_col6, #T_afbde_row14_col2, #T_afbde_row16_col6, #T_afbde_row22_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_afbde_row2_col0, #T_afbde_row11_col0, #T_afbde_row22_col6 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_afbde_row2_col1 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_afbde_row2_col2, #T_afbde_row25_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_afbde_row2_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_afbde_row2_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_afbde_row2_col5, #T_afbde_row3_col6, #T_afbde_row25_col5 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_afbde_row2_col6 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_afbde_row3_col0, #T_afbde_row10_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_afbde_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_afbde_row3_col2, #T_afbde_row6_col3, #T_afbde_row10_col5 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_afbde_row3_col3, #T_afbde_row14_col6 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_afbde_row3_col4, #T_afbde_row26_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_afbde_row3_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_afbde_row4_col0, #T_afbde_row7_col3, #T_afbde_row17_col0, #T_afbde_row23_col6 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_afbde_row4_col1, #T_afbde_row17_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_afbde_row4_col3, #T_afbde_row11_col6, #T_afbde_row17_col3 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_afbde_row4_col4, #T_afbde_row17_col4, #T_afbde_row18_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_afbde_row4_col5, #T_afbde_row17_col5, #T_afbde_row19_col5, #T_afbde_row28_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_afbde_row4_col6, #T_afbde_row17_col6, #T_afbde_row22_col2 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_afbde_row5_col0, #T_afbde_row12_col3, #T_afbde_row19_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_afbde_row5_col1, #T_afbde_row7_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_afbde_row5_col2, #T_afbde_row18_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_afbde_row5_col3, #T_afbde_row5_col5, #T_afbde_row21_col6, #T_afbde_row24_col2, #T_afbde_row25_col0, #T_afbde_row25_col1, #T_afbde_row27_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_afbde_row5_col4, #T_afbde_row15_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_afbde_row5_col6, #T_afbde_row26_col6 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_afbde_row6_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_afbde_row6_col2, #T_afbde_row8_col6, #T_afbde_row20_col0, #T_afbde_row26_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_afbde_row6_col4, #T_afbde_row26_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_afbde_row6_col5, #T_afbde_row11_col2, #T_afbde_row18_col6, #T_afbde_row28_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_afbde_row6_col6, #T_afbde_row10_col3 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_afbde_row7_col0 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_afbde_row7_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_afbde_row7_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_afbde_row7_col5, #T_afbde_row12_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_afbde_row8_col0, #T_afbde_row25_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_afbde_row8_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_afbde_row8_col2 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_afbde_row8_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_afbde_row8_col4 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_afbde_row8_col5 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_afbde_row9_col0 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_afbde_row9_col1 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_afbde_row9_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_afbde_row9_col3 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_afbde_row9_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_afbde_row10_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_afbde_row10_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_afbde_row10_col6 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_afbde_row11_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_afbde_row11_col4 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_afbde_row12_col0, #T_afbde_row13_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_afbde_row12_col1 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_afbde_row12_col5, #T_afbde_row16_col5 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_afbde_row12_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_afbde_row13_col0 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_afbde_row13_col1 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_afbde_row13_col2, #T_afbde_row16_col0, #T_afbde_row28_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_afbde_row13_col3 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_afbde_row13_col4 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_afbde_row13_col5 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_afbde_row14_col0, #T_afbde_row28_col6 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_afbde_row14_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_afbde_row14_col4 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_afbde_row15_col1, #T_afbde_row21_col1, #T_afbde_row27_col6 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_afbde_row15_col2 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_afbde_row15_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_afbde_row15_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_afbde_row15_col5 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_afbde_row15_col6 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_afbde_row16_col1 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_afbde_row16_col2 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_afbde_row16_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_afbde_row16_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_afbde_row18_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_afbde_row18_col3, #T_afbde_row20_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_afbde_row18_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_afbde_row19_col0 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_afbde_row19_col1 {
#   background-color: #e5d8d1;

# %%
import pandas as pd
from factor_analyzer import ConfirmatoryFactorAnalyzer, ModelSpecificationParser

features = ["angle_R2X2R1", "angle_R1X1R2", "angle_X2X1R1", "angle_X1X2R2", "cis/trans", "chirality", "pKa"]

model_dict = {
    "F1": ["angle_R2X2R1", "angle_R1X1R2", "angle_X2X1R1", "angle_X1X2R2", "pKa"],
    "F2": ["cis/trans", "chirality", "pKa"]
}

df_features_temp = df_features[features]

model_spec = ModelSpecificationParser.parse_model_specification_from_dict(df_features_temp, model_dict)

cfa = ConfirmatoryFactorAnalyzer(model_spec, disp=False)

cfa.fit(df_features_temp)

print(cfa.loadings_)
# Out:
# [[ 2.83008973e+02  0.00000000e+00]
#  [ 2.69448315e+02  0.00000000e+00]
#  [ 2.94899535e+02  0.00000000e+00]
#  [ 2.83366194e+02  0.00000000e+00]
#  [ 3.81433366e-01 -1.67051589e+02]
#  [ 0.00000000e+00 -2.74041755e+03]
#  [ 0.00000000e+00 -2.41265654e+03]]
# c:\work\DrugDiscovery\drug-discovery-venv\Lib\site-packages\factor_analyzer\confirmatory_factor_analyzer.py:753: UserWarning: The optimization routine failed to converge: ABNORMAL_TERMINATION_IN_LNSRCH
#   warnings.warn(
