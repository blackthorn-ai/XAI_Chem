# %%
import pandas as pd
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

train_df = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\csv_for_rulefit\train_logP_v3.csv', index_col=0)
test_df = pd.read_csv(r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\updated_features\csv_for_rulefit\test_logP_v3.csv', index_col=0)

merged_dataframe = pd.concat([train_df, test_df], axis=0)

features_to_analyse = []
for feature_name in merged_dataframe.columns:
    if len(merged_dataframe[feature_name].unique()) != 1:
        features_to_analyse.append(feature_name)
features_to_analyse.remove('fold_id')

fa = FactorAnalyzer(rotation=None)

df_features = merged_dataframe[features_to_analyse]
# df_features = StandardScaler().fit_transform(df_features)
fa.fit(df_features)

ev, _ = fa.get_eigenvalues()
for index, en_value in enumerate(ev):
    if en_value < 1:
        break
index += 1

plt.scatter(range(1, index + 1), ev[:index])
plt.plot(range(1, index + 1), ev[:index])
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.axhline(y = 1, color='r')
plt.grid()
plt.show()

# %%
from factor_analyzer.factor_analyzer import calculate_kmo

kmo_all, kmo_model = calculate_kmo(df_features)
kmo_model
# Out:
# c:\work\DrugDiscovery\drug-discovery-venv\Lib\site-packages\factor_analyzer\utils.py:244: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn(
# 0.49089938013343887

# %%
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity

df_for_bartlett_sphericity = StandardScaler().fit_transform(df_features)
chi_square_value, p_value = calculate_bartlett_sphericity(df_for_bartlett_sphericity)
print(f"statistics: {chi_square_value}, p-value: {p_value}")
# Out:
# statistics: 33195.52628459009, p-value: 0.0

# %%
from sklearn.preprocessing import StandardScaler

n_factors = 10

fa = FactorAnalyzer(n_factors=n_factors, rotation="varimax")

fa.fit(df_features)

fa_load = pd.DataFrame(fa.loadings_,index=df_features.columns)
fa_load.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_0e9aa_row0_col0, #T_0e9aa_row6_col8, #T_0e9aa_row8_col8, #T_0e9aa_row31_col5 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_0e9aa_row0_col1 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_0e9aa_row0_col2, #T_0e9aa_row2_col1, #T_0e9aa_row5_col0, #T_0e9aa_row10_col6, #T_0e9aa_row11_col8, #T_0e9aa_row15_col4, #T_0e9aa_row19_col7, #T_0e9aa_row20_col0, #T_0e9aa_row21_col9, #T_0e9aa_row26_col8, #T_0e9aa_row28_col1, #T_0e9aa_row32_col5, #T_0e9aa_row34_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0e9aa_row0_col3, #T_0e9aa_row1_col7, #T_0e9aa_row3_col1, #T_0e9aa_row17_col6, #T_0e9aa_row21_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_0e9aa_row0_col4 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_0e9aa_row0_col5, #T_0e9aa_row2_col6, #T_0e9aa_row5_col3, #T_0e9aa_row7_col8, #T_0e9aa_row13_col1, #T_0e9aa_row28_col6, #T_0e9aa_row30_col1, #T_0e9aa_row34_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_0e9aa_row0_col6, #T_0e9aa_row29_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_0e9aa_row0_col7, #T_0e9aa_row7_col7, #T_0e9aa_row16_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_0e9aa_row0_col8 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_0e9aa_row0_col9, #T_0e9aa_row5_col4, #T_0e9aa_row7_col4 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_0e9aa_row1_col0, #T_0e9aa_row20_col8 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_0e9aa_row1_col1, #T_0e9aa_row17_col2, #T_0e9aa_row24_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_0e9aa_row1_col2, #T_0e9aa_row1_col4, #T_0e9aa_row16_col0, #T_0e9aa_row16_col5, #T_0e9aa_row24_col1, #T_0e9aa_row24_col6, #T_0e9aa_row24_col7, #T_0e9aa_row27_col9, #T_0e9aa_row36_col3, #T_0e9aa_row36_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0e9aa_row1_col3 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_0e9aa_row1_col5, #T_0e9aa_row21_col8, #T_0e9aa_row27_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T
{
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_0e9aa_row6_col4, #T_0e9aa_row8_col4, #T_0e9aa_row24_col4 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_0e9aa_row6_col5, #T_0e9aa_row8_col5, #T_0e9aa_row20_col3, #T_0e9aa_row34_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_0e9aa_row6_col6, #T_0e9aa_row8_col6, #T_0e9aa_row33_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_0e9aa_row6_col9, #T_0e9aa_row8_col9, #T_0e9aa_row35_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_0e9aa_row7_col0 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_0e9aa_row7_col2, #T_0e9aa_row15_col9, #T_0e9aa_row36_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_0e9aa_row7_col6, #T_0e9aa_row18_col8, #T_0e9aa_row20_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_0e9aa_row7_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_0e9aa_row9_col1, #T_0e9aa_row10_col9, #T_0e9aa_row12_col1, #T_0e9aa_row18_col3, #T_0e9aa_row35_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_0e9aa_row9_col2, #T_0e9aa_row18_col7 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_0e9aa_row9_col4 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_0e9aa_row9_col5, #T_0e9aa_row30_col6, #T_0e9aa_row31_col1, #T_0e9aa_row31_col2 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_0e9aa_row9_col6 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_0e9aa_row9_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_0e9aa_row10_col0, #T_0e9aa_row14_col7, #T_0e9aa_row17_col7, #T_0e9aa_row30_col8 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_0e9aa_row10_col2, #T_0e9aa_row12_col3, #T_0e9aa_row18_col9, #T_0e9aa_row35_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_0e9aa_row10_col3, #T_0e9aa_row14_col2, #T_0e9aa_row32_co

# %% [markdown]
# No rotation

# %%
from sklearn.preprocessing import StandardScaler

n_factors = 8

fa = FactorAnalyzer(n_factors=n_factors, rotation=None)

fa.fit(df_features)

fa_load = pd.DataFrame(fa.loadings_,index=df_features.columns)
fa_load.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_7cdaf_row0_col0 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_7cdaf_row0_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_7cdaf_row0_col2, #T_7cdaf_row9_col7, #T_7cdaf_row22_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_7cdaf_row0_col3, #T_7cdaf_row23_col2 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_7cdaf_row0_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_7cdaf_row0_col5, #T_7cdaf_row24_col4 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_7cdaf_row0_col6, #T_7cdaf_row2_col0, #T_7cdaf_row6_col5, #T_7cdaf_row8_col5, #T_7cdaf_row28_col0 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_7cdaf_row0_col7, #T_7cdaf_row6_col0, #T_7cdaf_row8_col0, #T_7cdaf_row11_col5, #T_7cdaf_row26_col5 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_7cdaf_row1_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_7cdaf_row1_col1, #T_7cdaf_row2_col5, #T_7cdaf_row28_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_7cdaf_row1_col2 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_7cdaf_row1_col3 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_7cdaf_row1_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_7cdaf_row1_col5, #T_7cdaf_row6_col1, #T_7cdaf_row8_col1, #T_7cdaf_row10_col3, #T_7cdaf_row13_col0, #T_7cdaf_row16_col4, #T_7cdaf_row20_col0, #T_7cdaf_row34_col6, #T_7cdaf_row34_col7, #T_7cdaf_row35_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7cdaf_row1_col6 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_7cdaf_row1_col7, #T_7cdaf_row4_col1, #T_7cdaf_row11_col3, #T_7cdaf_row26_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_7cdaf_row2_col1, #T_7cdaf_row28_col1 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_7cdaf_row2_col2, #T_7cdaf_row28_col2, #T_7cdaf_row33_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_7cdaf_row2_col3, #T_7cdaf_row20_col4, #T_7cdaf_row28_col3 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_7cdaf_row2_col4, #T_7cdaf_row22_col7, #T_7cdaf_row25_col5, #T_7cdaf_row28_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_7cdaf_row2_col6, #T_7cdaf_row28_col6, #T_7cdaf_row34_col4 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_7cdaf_row2_col7, #T_7cdaf_row28_col7 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_7cdaf_row3_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_7cdaf_row3_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_7cdaf_row3_col2, #T_7cdaf_row17_col2 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_7cdaf_row3_col3 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_7cdaf_row3_col4 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_7cdaf_row3_col5, #T_7cdaf_row29_col0 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T