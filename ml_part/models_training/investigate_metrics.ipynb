# ...

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

def calculate_metrics(true_values, pred_values):
    mse = round(mean_squared_error(true_values, pred_values),3)
    mae = round(mean_absolute_error(true_values, pred_values),3)
    r_score = round(r2_score(true_values, pred_values),3)

    return {"mse": mse,
            "mae": mae,
            "r_score": r_score,}

train_pka_true = Train_pka_basic_true + Train_pka_acid_true
train_pKa_pred = Train_pka_basic_pred + Train_pka_acid_pred

test_pka_true = Test_pKa_basic_true + Test_pKa_acid_true
test_pKa_pred = Test_pKa_basic_pred + Test_pKa_acid_pred

print(f"Train metrics: {calculate_metrics(train_pka_true, train_pKa_pred)}" )
print(f"OOS metrics: {calculate_metrics(test_pka_true, test_pKa_pred)}" )
# Out:
# Train metrics: {'mse': 0.047, 'mae': 0.155, 'r_score': 0.993}
# OOS metrics: {'mse': 0.198, 'mae': 0.309, 'r_score': 0.967}

# %% [markdown]
# CV metrics

# %%
import pandas as pd

pKa_basic_csv_cv = r'C:\work\DrugDiscovery\main_git\XAI_Chem\ml_part\models_training\saved_cv_csv\pKa_basic_cv.csv'
pKa_acid_csv_cv = r'C:\work\DrugDiscovery\main_git\XAI_Chem\ml_part\models_training\saved_cv_csv\pKa_acid_cv.csv'

df_cv_basic = pd.read_csv(pKa_basic_csv_cv, index_col=0)
df_cv_acid = pd.read_csv(pKa_acid_csv_cv, index_col=0)

# %%
from ast import literal_eval

# basic
df_cv_basic.cv_0_true_values = df_cv_basic.cv_0_true_values.apply(literal_eval)
df_cv_basic.cv_0_pred_values = df_cv_basic.cv_0_pred_values.apply(literal_eval)

df_cv_basic.cv_0_train_true_values = df_cv_basic.cv_0_train_true_values.apply(literal_eval)
df_cv_basic.cv_0_train_pred_values = df_cv_basic.cv_0_train_pred_values.apply(literal_eval)


df_cv_basic.cv_1_true_values = df_cv_basic.cv_1_true_values.apply(literal_eval)
df_cv_basic.cv_1_pred_values = df_cv_basic.cv_1_pred_values.apply(literal_eval)

df_cv_basic.cv_1_train_true_values = df_cv_basic.cv_1_train_true_values.apply(literal_eval)
df_cv_basic.cv_1_train_pred_values = df_cv_basic.cv_1_train_pred_values.apply(literal_eval)

# acid
df_cv_acid.cv_0_true_values = df_cv_acid.cv_0_true_values.apply(literal_eval)
df_cv_acid.cv_0_pred_values = df_cv_acid.cv_0_pred_values.apply(literal_eval)

df_cv_acid.cv_0_train_true_values = df_cv_acid.cv_0_train_true_values.apply(literal_eval)
df_cv_acid.cv_0_train_pred_values = df_cv_acid.cv_0_train_pred_values.apply(literal_eval)


df_cv_acid.cv_1_true_values = df_cv_acid.cv_1_true_values.apply(literal_eval)
df_cv_acid.cv_1_pred_values = df_cv_acid.cv_1_pred_values.apply(literal_eval)

df_cv_acid.cv_1_train_true_values = df_cv_acid.cv_1_train_true_values.apply(literal_eval)
df_cv_acid.cv_1_train_pred_values = df_cv_acid.cv_1_train_pred_values.apply(literal_eval)

# %% [markdown]
# BASIC

# %%
best_index, best_r_2 = -1, -1
for index, row in df_cv_basic.iterrows():
    r_score = (row['cv_0_r^2'] + row['cv_1_r^2']) / 2
    if r_score > best_r_2:
        best_r_2 = r_score
        best_index = index

        true_basic_train = row['cv_0_train_true_values'] + row['cv_1_train_true_values']
        pred_basic_train = row['cv_0_train_pred_values'] + row['cv_1_train_pred_values']
        best_crossval_train_metrics = calculate_metrics(true_values=true_basic_train,
                                                        pred_values=pred_basic_train)
        
        true_basic_oss = row['cv_0_true_values'] + row['cv_1_true_values']
        pred_basic_oss = row['cv_0_pred_values'] + row['cv_1_pred_values']
        best_crossval_oss_metrics = calculate_metrics(true_values=true_basic_oss,
                                                      pred_values=pred_basic_oss)

print(best_crossval_train_metrics)
print(best_crossval_oss_metrics)
# Out:
# {'mse': 0.023, 'mae': 0.104, 'r_score': 0.991}
# {'mse': 0.201, 'mae': 0.313, 'r_score': 0.919}

# %% [markdown]
# ACID

# %%
best_index, best_r_2 = -1, -1
for index, row in df_cv_acid.iterrows():
    r_score = (row['cv_0_r^2'] + row['cv_1_r^2']) / 2
    if r_score > best_r_2:
        best_r_2 = r_score
        best_index = index

        true_acid_train = row['cv_0_train_true_values'] + row['cv_1_train_true_values']
        pred_acid_train = row['cv_0_train_pred_values'] + row['cv_1_train_pred_values']
        best_crossval_train_metrics = calculate_metrics(true_values=true_acid_train,
                                                        pred_values=pred_acid_train)
        
        true_acid_oss = row['cv_0_true_values'] + row['cv_1_true_values']
        pred_acid_oss = row['cv_0_pred_values'] + row['cv_1_pred_values']
        best_crossval_oss_metrics = calculate_metrics(true_values=true_acid_oss,
                                                      pred_values=pred_acid_oss)

print(best_crossval_train_metrics)
print(best_crossval_oss_metrics)
# Out:
# {'mse': 0.008, 'mae': 0.061, 'r_score': 0.962}
# {'mse': 0.017, 'mae': 0.106, 'r_score': 0.919}

# %%
train_true_values = true_basic_train + true_acid_train
train_pred_values = pred_basic_train + pred_acid_train
best_crossval_train_metrics = calculate_metrics(true_values=train_true_values,
                                                pred_values=train_pred_values)
print(f"Train cv: {best_crossval_train_metrics}")

cv_oss_true_values = true_basic_oss + true_acid_oss
cv_oss_pred_values = pred_basic_oss + pred_acid_oss
best_crossval_oss_metrics = calculate_metrics(true_values=cv_oss_true_values,
                                              pred_values=cv_oss_pred_values)
print(f"OOS cv: {best_crossval_oss_metrics}")
# Out:
# Train cv: {'mse': 0.019, 'mae': 0.091, 'r_score': 0.997}
# OOS cv: {'mse': 0.145, 'mae': 0.25, 'r_score': 0.978}

# %% [markdown]
# logP

# %%
Test_logP_pred = [1.9125679731369019, 1.9658740758895874, 2.74017071723938, 1.293167233467102, 2.6329548358917236, 1.960464358329773, 2.923034906387329, 2.399850845336914, 1.4777108430862427, 1.6542996168136597, 2.1267197132110596, 1.789663314819336, 1.8735551834106445, 1.802904486656189, 1.2532297372817993, 1.0336089134216309, 2.01554799079895, 1.7066318988800049, 2.211064577102661, 2.2293567657470703, 1.103033423423767, 2.277944326400757, 2.1267197132110596, 2.711442232131958, 2.119683027267456]

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

def calculate_metrics(true_values, pred_values):
    mse = round(mean_squared_error(true_values, pred_values),3)
    mae = round(mean_absolute_error(true_values, pred_values),3)
    r_score = round(r2_score(true_values, pred_values),3)

    return {"mse": mse,
            "mae": mae,
            "r_score": r_score,}

print(f"Train metrics: {calculate_metrics(Train_logP_true, Train_logP_pred)}" )
print(f"OOS metrics: {calculate_metrics(Test_logP_true, Test_logP_pred)}" )
# Out:
# Train metrics: {'mse': 0.035, 'mae': 0.142, 'r_score': 0.889}
# OOS metrics: {'mse': 0.021, 'mae': 0.104, 'r_score': 0.919}

# %% [markdown]
# CV metrics

# %%
import pandas as pd

logP_csv_cv = r'C:\work\DrugDiscovery\main_git\XAI_Chem\ml_part\models_training\saved_cv_csv\logP_cv.csv'

df_cv_logP = pd.read_csv(logP_csv_cv, index_col=0)

# %%
from ast import literal_eval

# logP
df_cv_logP.cv_0_true_values = df_cv_logP.cv_0_true_values.apply(literal_eval)
df_cv_logP.cv_0_pred_values = df_cv_logP.cv_0_pred_values.apply(literal_eval)

df_cv_logP.cv_0_train_true_values = df_cv_logP.cv_0_train_true_values.apply(literal_eval)
df_cv_logP.cv_0_train_pred_values = df_cv_logP.cv_0_train_pred_values.apply(literal_eval)


df_cv_logP.cv_1_true_values = df_cv_logP.cv_1_true_values.apply(literal_eval)
df_cv_logP.cv_1_pred_values = df_cv_logP.cv_1_pred_values.apply(literal_eval)

df_cv_logP.cv_1_train_true_values = df_cv_logP.cv_1_train_true_values.apply(literal_eval)
df_cv_logP.cv_1_train_pred_values = df_cv_logP.cv_1_train_pred_values.apply(literal_eval)

# %%
best_index, best_r_2 = -1, -1
for index, row in df_cv_logP.iterrows():
    r_score = (row['cv_0_r^2'] + row['cv_1_r^2']) / 2
    if r_score > best_r_2:
        best_r_2 = r_score
        best_index = index

        true_basic_train = row['cv_0_train_true_values'] + row['cv_1_train_true_values']
        pred_basic_train = row['cv_0_train_pred_values'] + row['cv_1_train_pred_values']
        best_crossval_train_metrics = calculate_metrics(true_values=true_basic_train,
                                                        pred_values=pred_basic_train)
        
        true_basic_oss = row['cv_0_true_values'] + row['cv_1_true_values']
        pred_basic_oss = row['cv_0_pred_values'] + row['cv_1_pred_values']
        best_crossval_oss_metrics = calculate_metrics(true_values=true_basic_oss,
                                                      pred_values=pred_basic_oss)

print("CV train:", best_crossval_train_metrics)
print("OOS train:", best_crossval_oss_metrics)
# Out:
# CV train: {'mse': 0.018, 'mae': 0.099, 'r_score': 0.943}
# OOS train: {'mse': 0.05, 'mae': 0.172, 'r_score': 0.842}
