# %%
import pandas as pd

train_path = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\from papers\scaffold_train_three_all_new_norm.csv'
test_path = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\from papers\scaffold_test_three_all_new_norm.csv'
valid_path = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\from papers\scaffold_valid_three_all_new_norm.csv'

df_train = pd.read_csv(train_path)
df_test = pd.read_csv(test_path)
df_valid = pd.read_csv(valid_path)

# %%
df = pd.concat([df_train, df_test, df_valid], axis=0)[['smiles', 'logp']].dropna()

# %%
df
# Out:
#                                                  smiles  logp
# 0                          CCN(CCO)C(=O)COC(=O)c1ccccc1  0.93
# 2                                            Brc1ccccc1  2.99
# 5                                COc1cc(C=CC(=O)O)ccc1O  1.51
# 8                                 C#CCN(C)C(C)Cc1ccccc1  2.90
# 14    O=[N+]([O-])c1cc([N+](=O)[O-])c(O)c([N+](=O)[O...  1.33
# ...                                                 ...   ...
# 3316      COc1ccc2sc(C(=O)N=c3nn[nH][nH]3)c(OC(C)C)c2c1  1.78
# 3317            CCCCOc1ccnc(C=CC2=CC([N+](=O)[O-])O2)n1  2.04
# 3318               O=C(CO)CN=c1[nH]cc[nH]c1=[N+]([O-])O -0.49
# 3319  COc1ccc2c(C=Nc3c(C)n(C)n(-c4ccccc4)c3=O)c(=O)n...  4.66
# 3320                               Cc1nnc(SCc2ccccc2)s1  2.35
#
# [13688 rows x 2 columns]

# %%
fluor_df = df[df['smiles'].str.contains('F')]

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import rdForceFieldHelpers

def calculate_matches(smiles):
    
    mol = Chem.MolFromSmiles(smiles)
    mol = Chem.AddHs(mol)
    rdForceFieldHelpers.MMFFSanitizeMolecule(mol)

    AllChem.EmbedMolecule(mol, randomSeed=42)

    carboxile_submol = Chem.MolFromSmiles('CC=O')
    nitro_amine_submol = Chem.MolFromSmiles('CN')

    carboxile_matches = mol.GetSubstructMatches(carboxile_submol)
    nitro_amine_matches = mol.GetSubstructMatches(nitro_amine_submol)

    return carboxile_matches, nitro_amine_matches

# %%
fluor_df
# Out:
#                                                  smiles  logp
# 204         CC(C)C(=O)Nc1ccc([N+](=O)[O-])c(C(F)(F)F)c1  3.35
# 208                              NC(Cc1ccc(F)cc1)C(=O)O -1.89
# 900                   O=C(O)c1ccccc1Nc1cccc(C(F)(F)F)c1  5.25
# 925                       O=C(O)Cc1ccccc1Nc1c(F)cccc1Cl  3.80
# 926                        O=C(O)Cc1ccccc1Nc1c(F)cccc1F  3.57
# ...                                                 ...   ...
# 3307       CCn1cc(C(=O)O)c(=O)c2cc(F)c(N3CCN(C)CC3)cc21  0.27
# 3308    CCn1cc(C(=O)O)c(=O)c2cc(F)c(N3CCNC(C)C3)c(F)c21 -0.30
# 3309       CCn1cc(C(=O)O)c(=O)c2cc(F)c(N3CCNC(C)C3)cc21  0.34
# 3310       CCn1cc(C(=O)O)c(=O)c2cc(F)c(N3CCNCC3)c(F)c21 -0.57
# 3312  CC1(C)CN=C(NN=C(C=Cc2ccc(C(F)(F)F)cc2)C=Cc2ccc...  2.31
#
# [1193 rows x 2 columns]

# %%
all_smiles = []

for _, row in fluor_df.iterrows():
    SMILES = row['smiles']

    all_smiles.append(SMILES.lower())
    carboxile_matches, nitro_amine_matches = calculate_matches(smiles=SMILES)

    if len(carboxile_matches) + len(nitro_amine_matches) == 1:
        print(f"SMILES: {SMILES}, carboxic matches: {len(carboxile_matches)}, nitro matches: {len(nitro_amine_matches)}")
# Out:
# SMILES: C=C(C)C(=O)OCC(F)(F)F, carboxic matches: 1, nitro matches: 0
# SMILES: COC(=O)C(F)(F)F, carboxic matches: 1, nitro matches: 0
# SMILES: NCC(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: CCOC(=O)C(F)(F)C(F)(F)F, carboxic matches: 1, nitro matches: 0
# SMILES: CCOC(=O)C(F)(F)F, carboxic matches: 1, nitro matches: 0
# SMILES: CCOC(=O)C(F)F, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O[Na])C(F)(F)C(F)F, carboxic matches: 1, nitro matches: 0
# SMILES: Cc1c(F)c(F)c(C(=O)O)c(F)c1F, carboxic matches: 1, nitro matches: 0
# SMILES: Cc1ccc(NS(=O)(=O)C(F)(F)F)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: CC(=O)Oc1cccc(C(F)(F)F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: CC(=O)Oc1cccc(F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: CC(=O)Oc1ccccc1C(F)(F)F, carboxic matches: 1, nitro matches: 0
# SMILES: CC(=O)Oc1ccccc1F, carboxic matches: 1, nitro matches: 0
# SMILES: CC(C)(C)S(=O)(=O)C(C#N)C=Nc1ccc(OC(F)(F)F)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: CC(C)(C)[N+]([O-])=Cc1ccc(F)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: N#CC(C#N)=NNc1ccc(OC(F)(F)F)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: N#CC(C#N)=NNc1ccccc1C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: NS(=O)(=O)c1ccc([N+](=O)[O-])c(C(F)(F)F)c1, carboxic matches: 0, nitro matches: 1
# SMILES: Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1, carboxic matches: 0, nitro matches: 1
# SMILES: Nc1cc(C(F)(F)F)ccc1Cl, carboxic matches: 0, nitro matches: 1
# SMILES: Nc1ccc(C(F)(F)F)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: Nc1ccc(F)c(Cl)c1, carboxic matches: 0, nitro matches: 1
# SMILES: Nc1ccc(F)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: Nc1ccc(F)cc1F, carboxic matches: 0, nitro matches: 1
# SMILES: Nc1cccc(F)c1, carboxic matches: 0, nitro matches: 1
# SMILES: Nc1ccccc1C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: Nc1ccccc1F, carboxic matches: 0, nitro matches: 1
# SMILES: O=C(O)COc1cc(F)cc(Cl)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)COc1cc(F)cc(I)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)COc1ccc(F)cc1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)COc1ccc(S(=O)(=O)F)cc1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)COc1cccc(C(F)(F)F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)COc1cccc(F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)COc1cccc(OC(F)(F)F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)COc1cccc(S(=O)(=O)C(F)(F)F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)COc1cccc(S(F)(F)(F)(F)F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)COc1cccc(SC(F)(F)F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)COc1ccccc1F, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)Cc1ccc(C(F)(F)F)cc1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)Cc1ccc(F)cc1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)Cc1ccc(S(=O)(=O)F)cc1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)Cc1cccc(C(F)(F)F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)Cc1cccc(F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)Cc1ccccc1F, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)c1c(F)cccc1Cl, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)c1c(F)cccc1F, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)c1ccc(C(F)(F)F)cc1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)c1ccc(F)cc1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)c1cccc(C(F)(F)F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)c1cccc(F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)c1ccccc1F, carboxic matches: 1, nitro matches: 0
# SMILES: O=Cc1ccc(F)cc1, carboxic matches: 1, nitro matches: 0
# SMILES: O=Cc1cccc(C(F)(F)F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=S(=O)(CF)Nc1ccc(Cl)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(CF)Nc1ccccc1, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(NCc1ccccc1)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1ccc(C(F)(F)F)cc1)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1ccc(Cl)cc1)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1ccc(Cl)cc1)C(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1ccc(Cl)cc1Cl)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1ccc(F)cc1)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1ccc(F)cc1F)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1ccc(I)cc1)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1cccc(Br)c1)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1cccc(C(F)(F)F)c1)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1cccc(Cl)c1)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1cccc(F)c1)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1cccc(O)c1)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1ccccc1)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=S(=O)(Nc1ccccc1)C(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=[N+]([O-])c1cc(C(F)(F)F)ccc1O, carboxic matches: 0, nitro matches: 1
# SMILES: O=[N+]([O-])c1cc(F)cc(F)c1, carboxic matches: 0, nitro matches: 1
# SMILES: O=[N+]([O-])c1cc(F)ccc1F, carboxic matches: 0, nitro matches: 1
# SMILES: O=[N+]([O-])c1ccc(C(F)(F)F)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: O=[N+]([O-])c1ccc(Cl)cc1C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=[N+]([O-])c1ccc(F)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: O=[N+]([O-])c1ccc(F)cc1O, carboxic matches: 0, nitro matches: 1
# SMILES: O=[N+]([O-])c1cccc(C(F)(F)F)c1, carboxic matches: 0, nitro matches: 1
# SMILES: O=[N+]([O-])c1cccc(F)c1, carboxic matches: 0, nitro matches: 1
# SMILES: O=[N+]([O-])c1ccccc1C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: O=[N+]([O-])c1ccccc1F, carboxic matches: 0, nitro matches: 1
# SMILES: COC(=O)c1c(F)cccc1Cl, carboxic matches: 1, nitro matches: 0
# SMILES: COC(=O)c1c(F)cccc1F, carboxic matches: 1, nitro matches: 0
# SMILES: COC(=O)c1ccc(F)cc1, carboxic matches: 1, nitro matches: 0
# SMILES: COC(=O)c1ccccc1F, carboxic matches: 1, nitro matches: 0
# SMILES: COc1ccc(NS(=O)(=O)C(F)(F)F)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: COc1cccc(NS(=O)(=O)C(F)(F)F)c1, carboxic matches: 0, nitro matches: 1
# SMILES: CS(=O)(=O)c1ccc(NS(=O)(=O)C(F)(F)F)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: CS(=O)(=O)c1cccc(NS(=O)(=O)C(F)(F)F)c1, carboxic matches: 0, nitro matches: 1
# SMILES: CSc1ccc(NS(=O)(=O)C(F)(F)F)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: Nc1cccc(C(F)(F)F)c1, carboxic matches: 0, nitro matches: 1
# SMILES: Cc1c(F)c(F)c(COC(=O)C2C(C=C(Cl)C(F)(F)F)C2(C)C)c(F)c1F, carboxic matches: 1, nitro matches: 0
# SMILES: CC1(C)C(C=C(Cl)Cl)C1C(=O)OCc1c(F)c(F)cc(F)c1F, carboxic matches: 1, nitro matches: 0
# SMILES: COc1cc(C=O)ccc1OS(=O)(=O)c1ccc(F)c(F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: CC1CC(OC(=O)COc2ccc(F)cc2)CC(C)(C)C1, carboxic matches: 1, nitro matches: 0
# SMILES: Fc1ccc(Oc2ccnc3cc(Cl)cc(Cl)c23)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: C#CCC(O)(c1ccc(F)cc1)c1cccnc1, carboxic matches: 0, nitro matches: 1
# SMILES: COc1cc([C@H]2c3c(C)n[nH]c3OC(=N)C2C#N)ccc1OCc1cccc(F)c1, carboxic matches: 0, nitro matches: 1
# SMILES: COc1ccc(C=O)cc1COc1c(F)c(F)cc(F)c1F, carboxic matches: 1, nitro matches: 0
# SMILES: Nc1ccc(S(=O)(=O)c2ccc(F)cc2)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: FN(F)C(c1ccccc1)(c1ccccc1)c1ccccc1, carboxic matches: 0, nitro matches: 1
# SMILES: FC(F)(F)c1ccc2cccnc2c1, carboxic matches: 0, nitro matches: 1
# SMILES: FC(F)(F)c1cccc2cccnc12, carboxic matches: 0, nitro matches: 1
# SMILES: Fc1cccc2cccnc12, carboxic matches: 0, nitro matches: 1
# SMILES: Oc1ccc(F)c2cccnc12, carboxic matches: 0, nitro matches: 1
# SMILES: O=C(O)C(c1ccc(-c2ccccc2)cc1)C(O)c1cccc(F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)C(c1ccc(-c2ccccc2)cc1)C(O)c1ccccc1F, carboxic matches: 1, nitro matches: 0
# SMILES: NC1CC2CC1c1cc(C(F)(F)F)ccc12, carboxic matches: 0, nitro matches: 1
# SMILES: NC1CC2CC1c1ccc(C(F)(F)F)cc12, carboxic matches: 0, nitro matches: 1
# SMILES: Fc1cccc(F)n1, carboxic matches: 0, nitro matches: 1
# SMILES: Fc1ccccn1, carboxic matches: 0, nitro matches: 1
# SMILES: Fc1cccnc1, carboxic matches: 0, nitro matches: 1
# SMILES: CCOP(=S)(OCC)Oc1cccc(F)n1, carboxic matches: 0, nitro matches: 1
# SMILES: O=[N+]([O-])c1ccc(Oc2ccc(C(F)(F)F)cc2Cl)cc1Oc1ccoc1, carboxic matches: 0, nitro matches: 1
# SMILES: CC(C)C(C(=O)OC(C#N)c1cccc(Oc2ccccc2)c1)c1ccc(OC(F)F)cc1, carboxic matches: 1, nitro matches: 0
# SMILES: CCOc1ccc(C2(C(=O)OC)CC(F)(F)C2(F)F)cc1, carboxic matches: 1, nitro matches: 0
# SMILES: CC1=C(CC(=O)O)c2cc(F)ccc2C1=Cc1ccc(S(C)=O)cc1, carboxic matches: 1, nitro matches: 0
# SMILES: O=[N+]([O-])c1ccc(Oc2ccc(C(F)(F)F)cc2Cl)cc1, carboxic matches: 0, nitro matches: 1
# SMILES: CCOc1cc(Oc2ccc(C(F)(F)F)cc2Cl)ccc1[N+](=O)[O-], carboxic matches: 0, nitro matches: 1
# SMILES: COC(=O)c1cc(Oc2ccc(C(F)(F)F)cc2Cl)ccc1Cl, carboxic matches: 1, nitro matches: 0
# SMILES: CC1(C)C(C=C(Cl)C(F)(F)F)C1C(=O)OC(C#N)c1cccc(Oc2ccccc2)c1, carboxic matches: 1, nitro matches: 0
# SMILES: CC1(C)C(C=C(Cl)Cl)C1C(=O)OC(C#N)c1ccc(F)c(Oc2ccccc2)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=S(=O)(Nc1ccc(-c2ccccc2)cc1)C(F)(F)F, carboxic matches: 0, nitro matches: 1
# SMILES: CC(C(=O)O)c1ccc(-c2ccccc2)c(F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: O=C(O)c1cc(-c2ccc(F)cc2F)ccc1O, carboxic matches: 1, nitro matches: 0
# SMILES: Cc1cc2c(c(=O)o1)[C@@H](c1cccc(F)c1F)C(C#N)C(=N)O2, carboxic matches: 1, nitro matches: 0
# SMILES: N#C[C@@H](Cc1cccs1)c1ncc(C(F)(F)F)cc1Cl, carboxic matches: 0, nitro matches: 1
# SMILES: COc1cc(C#N)ccc1OC(=O)/C=C/c1cccc(F)c1, carboxic matches: 1, nitro matches: 0
# SMILES: NC1C2CCC1c1cc(C(F)(F)F)ccc1C2, carboxic matches: 0, nitro matches: 1
# SMILES: NC1C2CCC1c1ccc(C(F)(F)F)cc1C2, carboxic matches: 0, nitro matches: 1
# SMILES: NC1C2CCC1c1cccc(C(F)(F)F)c1C2, carboxic matches: 0, nitro matches: 1

# %%
our_dataset = r'C:\work\DrugDiscovery\main_git\XAI_Chem\data\init_data\pKa_Prediction_Starting data_2024.01.25.csv'

our_df = pd.read_csv(our_dataset)

our_smiles = our_df['Smiles'].to_list()[1:]

# %%
all_smiles
# Out:
# ['cc(c)c(=o)nc1ccc([n+](=o)[o-])c(c(f)(f)f)c1',
#  'nc(cc1ccc(f)cc1)c(=o)o',
#  'o=c(o)c1ccccc1nc1cccc(c(f)(f)f)c1',
#  'o=c(o)cc1ccccc1nc1c(f)cccc1cl',
#  'o=c(o)cc1ccccc1nc1c(f)cccc1f',
#  'fc(f)(f)c1nc2ccccc2[nh]1',
#  'cnccc(oc1ccc(c(f)(f)f)cc1)c1ccccc1',
#  'cc1cn(c2cc3c(cc2f)c(=o)c(c(=o)o)cn3-c2ccc(f)cc2f)ccn1',
#  'coc1ccc(oc)c(cn(c(c)=o)c2cc(f)ccc2oc2ccccc2)c1',
#  'coc1ccc(occf)c(cn(c(c)=o)c2cc(f)ccc2oc2ccccc2)c1',
#  'coc1ccc(oci)c(cn(c(c)=o)c2cc(f)ccc2oc2ccccc2)c1',
#  'coc1ccc(ocf)c(cn(c(c)=o)c2cc(f)ccc2oc2ccccc2)c1',
#  'ccoc(=o)c1ncn2c1cn(c)c(=o)c1cc(f)ccc1-2',
#  'cc(c)c(nc(=o)cn1c(-c2ccccc2)ccc(n)c1=o)c(=o)c(f)(f)f',
#  'occn1ccn(cccn2c3ccccc3sc3ccc(c(f)(f)f)cc32)cc1',
#  'cn1ccn(cccn2c3ccccc3sc3ccc(c(f)(f)f)cc32)cc1',
#  'cn1c(=o)cn=c(c2ccccc2f)c2cc([n+](=o)[o-])ccc21',
#  'cn(c)cccn1c2ccccc2sc2ccc(c(f)(f)f)cc21',
#  'o=c(o)c1cn(c2cc2)c2cc(n3ccncc3)c(f)cc2c1=o',
#  'o=c1[nh]c2c(o)ccc(ccncccs(=o)(=o)nccoccc3cccc(c(f)(f)f)c3)c2s1',
#  'o=c1[nh]c2c(o)ccc(ccncccs(=o)(=o)nccoccc3ccc(f)cc3)c2s1',
#  'ccn1cc(c(=o)o)c(=o)c2cc(f)c(n3ccncc3)nc21',
#  'cc1coc2c(n3ccn(c)cc3)c(f)cc3c(=o)c(c(=o)o)cn1c23',
#  'cccc(=nc(=o)c(cc1ccc(oc)cc1)ns(=o)(=o)n1ccocc1)c(=o)nc(cc1ccccc1)c(=o)c(f)(f)c(=o)nccn1ccocc1',
#  'cccc(=nc(=o)c(cc1ccccc1)ns(=o)(=o)n1ccocc1)c(=o)nc(cc1ccccc1)c(=o)c(f)(f)c(=o)nccn1ccocc1',
#  'nc1c2cn(c3nc4c(cc3f)c(=o)c(c(=o)o)cn4-c3ccc(f)cc3f)cc12',
#  'cccc(=nc(=o)c(cc1ccccc1)ns(=o)(=o)n1ccn(c)cc1)c(=o)nc(cc1ccccc1)c(=o)c(f)(f)c(=o)nccn1ccocc1',
#  'cc(cco)c(f)(f)f',
#  'cc(cco)cc(f)(f)f',
#  'o=nn(ccf)c(=o)ncccl',
#  'cc(co)cc(f)(f)f',
#  'cc(o)c(f)(f)f',
#  'cc(o)cc(f)(f)f',
#  'nc(=o)c(f)(f)f',
#  'cc(op(c)(=o)f)c(c)(c)c',
#  'cnc(=s)ncc(f)(f)c(f)(f)c(f)(f)f',
#  'ccn(cc)cc(f)(f)f',
#  'nc(=o)cf',
#  'cncc(f)(f)f',
#  'c=c(c)c(=o)occ(f)(f)f',
#  'coc(=o)c(f)(f)f',
#  'occcf',
#  'ccncc(f)(f)f',
#  'ncc(f)(f)f',
#  'ccoc(=o)c(f)(f)c(f)(f)f',
#  'ccoc(=o)c(f)(f)f',
#  'ccoc(=o)c(f)f',
#  'cc(=o)c(f)(f)f',
#  'coc(f)(f)c(cl)cl',
#  'cc(=o)cf',
#  'oc(c(f)(f)f)c(f)(f)f',
#  'oc(cf)cf',
#  'occc(f)(f)f',
#  'occcc(f)(f)f',
#  'occccc(f)(f)f',
#  'occcccc(f)(f)f',
#  'ccc(o)ccc(f)(f)f',
#  'o=c(c(f)(f)f)c(f)(f)f',
#  'cc[c@h](c)nc(=o)nc(c(f)(f)f)c(f)(f)f',
#  'cn(c)c(=s)s[fe](sc(=s)n(c)c)sc(=s)n(c)c',
#  'cccccf',
#  'cn(c)cc(f)(f)f',
#  'cc(c)(o)c(f)(f)f',
#  'fc(cl)(cl)cl',
#  'ccccf',
#  'fc(f)(cl)c(f)(cl)cl',
#  'fc(f)(cl)c(f)(f)cl',
#  'fc(f)(cl)cl',
#  'fc(f)(f)br',
#  'fc(f)(f)c(cl)br',
#  'fc(f)(f)c(f)(f)c(f)(f)c(f)(f)c(f)(f)f',
#  'fc(f)(f)c(f)(f)f',
#  'fc(f)(f)cl',
#  'fc(f)(f)f',
#  'fc(f)oc(cl)c(f)(f)f',
#  'fc(f)oc(f)(f)c(f)cl',
#  'fs(f)(f)(f)(f)f',
#  'o=c(o[na])c(f)(f)c(f)f',
#  'cs(=o)(=o)f',
#  'cccn(c)cc(f)(f)f',
#  'cccn(cc)cc(f)(f)f',
#  'cc(c)op(=o)(f)oc(c)c',
#  'cc(c)op(c)(=o)f',
#  'occ(f)(f)c(f)(f)c(f)(f)f',
#  'cnc(=o)cf',
#  'occ(f)(f)c(f)(f)f',
#  'occ(f)(f)f',
#  'o=nn(cc(f)(f)f)cc(f)(f)f',
#  'cc1c(f)c(f)c(c(=o)o)c(f)c1f',
#  'c#ccn(c)c(c)cc1ccc(f)cc1',
#  'c#ccon=cnc1cc(f)c(occ#c)c(occ#c)c1',
#  'c#ccoc1cc(n=cnoc)cc(f)c1occ#c',
#  'c#ccoc1cc(n=cnocc)cc(f)c1occ#c',
#  'c#ccoc1cc(n=cnococ)cc(f)c1occ#c',
#  'cc1cc(nc(n)=o)ccc1f',
#  'c=c(c)cn(cc)c1c([n+](=o)[o-])cc(c(f)(f)f)cc1[n+](=o)[o-]',
#  'cc1ccc(f)cc1',
#  'c=ccoc1cc(nc(c)=o)c(f)cc1cl',
#  'cc1ccc(n(sc(f)(cl)cl)s(=o)(=o)n(c)c)cc1',
#  'cc1ccc(ns(=o)(=o)c(f)(f)f)cc1',
#  'cc1ccc(s(=o)(=o)f)cc1',
#  'cc(=o)c(=cc1ccc(f)cc1)c(c)=o',
#  'cc(=o)c(c#n)=nnc1cc(c(f)(f)f)ccc1cl',
#  'cc(=o)c(c#n)=nnc1ccc(sc(f)(f)f)cc1',
#  'cc(=o)c=cc1ccc(c(f)(f)f)cc1',
#  'cc(=o)c=cc1ccc(f)cc1',
#  'cc(=o)c=cc1cccc(c(f)(f)f)c1',
#  'cc(=o)c=cc1cccc(f)c1',
#  'cc(=o)c=cc1ccccc1c(f)(f)f',
#  'cc(=o)c=cc1ccccc1f',
#  'cc(=o)n(c)n=nc1ccc(f)cc1',
#  'cc1cccc(f)c1',
#  'cc(=o)nnc(=o)nc1ccc(f)cc1',
#  'cc(=o)nnc(=o)nc1cccc(c(f)(f)f)c1',
#  'cc(=o)nnc(=o)nc1cccc(f)c1',
#  'cc(=o)nc1c(f)c(f)c(f)c(f)c1f',
#  'cc(=o)nc1c(f)ccc(c(f)(f)f)c1br',
#  'cc(=o)nc1c(f)cccc1f',
#  'cc(=o)nc1cc(br)cc(c(f)(f)f)c1cl',
#  'cc(=o)nc1cc(c(f)(f)f)c(br)cc1f',
#  'cc(=o)nc1cc(c(f)(f)f)c(cl)cc1cl',
#  'cc(=o)nc1cc(c(f)(f)f)c(cl)cc1f',
#  'cc(=o)nc1cc(c(f)(f)f)c(f)cc1f',
#  'cc(=o)nc1cc(c(f)(f)f)cc(c(f)(f)f)c1',
#  'cc(=o)nc1cc(c(f)(f)f)cc(c(f)(f)f)c1br',
#  'cc(=o)nc1cc(c(f)(f)f)cc(cl)c1cl',
#  'cc(=o)nc1cc(c(f)(f)f)ccc1cl',
#  'cc(=o)nc1cc(c(f)(f)f)ccc1f',
#  'cc(=o)nc1cc(cl)c(f)c(cl)c1f',
#  'cc(=o)nc1cc(cl)cc(c(f)(f)f)c1br',
#  'cc(=o)nc1cc(cl)cc(c(f)(f)f)c1cl',
#  'cc(=o)nc1cc(cl)cc(c(f)(f)f)c1f',
#  'cc(=o)nc1cc(f)cc(c(f)(f)f)c1cl',
#  'cc(=o)nc1cc(ns(=o)(=o)c(f)(f)f)c(c)cc1c',
#  'cc(=o)nc1cc(oc(f)(f)f)c(cl)cc1cl',
#  'cc(=o)nc1cc([n+](=o)[o-])c(br)cc1f',
#  'cc(=o)nc1ccc(br)c(cl)c1f',
#  'cc(=o)nc1ccc(c(f)(f)f)cc1',
#  'cc(=o)nc1ccc(cl)c(c(f)(f)f)c1',
#  'cc(=o)nc1ccc(cl)cc1c(f)(f)f',
#  'cc(=o)nc1ccc(cl)cc1f',
#  'cc(=o)nc1ccc(f)cc1',
#  'cc(=o)nc1ccc(oc(f)(f)f)cc1',
#  'cc(=o)nc1ccc(s(=o)(=o)f)cc1',
#  'cc(=o)nc1cccc(c(f)(f)f)c1',
#  'cc(=o)nc1cccc(cl)c1f',
#  'cc(=o)nc1cccc(f)c1',
#  'cc(=o)nc1ccccc1c(f)(f)f',
#  'cc(=o)nc1ccccc1f',
#  'cc(=o)oc1cccc(c(f)(f)f)c1',
#  'cc(=o)oc1cccc(f)c1',
#  'cc(=o)oc1ccccc1c(f)(f)f',
#  'cc(=o)oc1ccccc1f',
#  'cc(=o)c1ccc(f)cc1',
#  'cc(=o)c1ccc(ns(=o)(=o)c(f)(f)f)cc1',
#  'cc(=o)c1cccc(f)c1',
#  'cc(=o)c1cccc(ns(=o)(=o)c(f)(f)f)c1',
#  'cc(c(=o)nc1ccc([n+](=o)[o-])c(c(f)(f)f)c1)c(f)(f)f',
#  'cc(c)(c)c(=o)c(c#n)=nnc1cc(c(f)(f)f)cc(c(f)(f)f)c1',
#  'cc(c)(c)c(=o)c(c#n)=nnc1cc(c(f)(f)f)ccc1cl',
#  'cc(c)(c)c(=o)c(c#n)=nnc1ccc(cl)cc1c(f)(f)f',
#  'cc(c)(c)nc(=s)nc1ccc(f)cc1',
#  'cc(c)(c)s(=o)(=o)c(c#n)c=nc1ccc(oc(f)(f)f)cc1',
#  'cc(c)(c)[n+]([o-])=cc1ccc(f)cc1',
#  'cc(c)(o)c(=o)nc1ccc([n+](=o)[o-])c(c(f)(f)f)c1',
#  'cc(c)c(=o)ns(=o)(=o)c1ccc(c(f)(f)f)cc1n',
#  'cc(c)c(=o)ns(=o)(=o)c1ccc(c(f)(f)f)cc1[n+](=o)[o-]',
#  'cc(c)c(=o)nc1cc(c(f)(f)f)ccc1s(n)(=o)=o',
#  'fc(f)(f)c(f)(f)c1ccccc1',
#  'fc(f)(f)ccc1ccccc1',
#  'fc(f)(f)cn(cc(f)(f)f)c1ccc(br)cc1',
#  'fc(f)(f)cn(cc(f)(f)f)c1ccccc1',
#  'fc(f)(f)oc1ccccc1',
#  'fc(f)(f)sc1ccccc1',
#  'fc(f)(f)c1ccc(c(f)(f)f)cc1',
#  'fc(f)(f)c1cccc(c(f)(f)f)c1',
#  'fc(f)(f)c1ccccc1',
#  'fc(f)(f)c1ccccc1cl',
#  'fc(f)oc1ccccc1',
#  'fcccc1ccccc1',
#  'fs(f)(f)(f)(f)c1ccccc1',
#  'fc1c(f)c(f)c(f)c(f)c1f',
#  'fc1cc(f)c(f)c(f)c1f',
#  'fc1ccc(br)cc1',
#  'fc1ccc(ccl)cc1',
#  'fc1ccc(cl)cc1',
#  'fc1ccc(f)c(f)c1',
#  'fc1ccc(f)cc1',
#  'fc1cccc(br)c1',
#  'fc1cccc(ccl)c1',
#  'fc1cccc(cl)c1',
#  'fc1cccc(f)c1',
#  'fc1ccccc1',
#  'fc1ccccc1ccl',
#  'fc1ccccc1f',
#  'n#cc(c#n)=nnc1ccc(oc(f)(f)f)cc1',
#  'n#cc(c#n)=nnc1ccccc1c(f)(f)f',
#  'n#cn=[n+]([o-])c1ccc(c(f)(f)f)cc1',
#  'n#cn=[n+]([o-])c1ccc(f)cc1',
#  'n#cn=[n+]([o-])c1cccc(c(f)(f)f)c1',
#  'n#cn=[n+]([o-])c1cccc(f)c1',
#  'n#cc1ccc(c=cc(=o)c(f)(f)f)cc1',
#  'n#cc1cccc(c=cc(=o)c(f)(f)f)c1',
#  'n#cc1cccc(f)c1',
#  'cc(o)(c(=o)nc1ccc([n+](=o)[o-])c(c(f)(f)f)c1)c(f)(f)f',
#  'nc(=o)c(=cc1cccc(f)c1)c(n)=o',
#  'cc(oc(=o)c1cccc(c(f)(f)f)c1)c(n)=o',
#  'nc(=o)nc1ccc(f)cc1',
#  'nc(=o)nc1cccc(c(f)(f)f)c1',
#  'nc(=o)nc1cccc(f)c1',
#  'nc(=o)nc1ccccc1f',
#  'nc(=o)c1c(f)cccc1br',
#  'nc(=o)c1c(f)cccc1cl',
#  'nc(=o)c1c(f)cccc1f',
#  'nc(=o)c1ccc(c(f)(f)f)cc1',
#  'nc(=o)c1ccc(f)cc1',
#  'nc(=o)c1cccc(f)c1',
#  'nc(=o)c1ccccc1c(f)(f)f',
#  'nc(=o)c1ccccc1f',
#  'ncc(cc(=o)o)c1ccc(f)cc1',
#  'ns(=o)(=o)c1ccc(s(=o)(=o)cccco)c(f)c1',
#  'ns(=o)(=o)c1ccc(s(=o)(=o)ccco)c(f)c1',
#  'ns(=o)(=o)c1ccc(s(=o)(=o)cco)c(f)c1',
#  'ns(=o)(=o)c1ccc(scccco)c(f)c1',
#  'ns(=o)(=o)c1ccc(sccco)c(f)c1',
#  'ns(=o)(=o)c1ccc(scco)c(f)c1',
#  'ns(=o)(=o)c1ccc([n+](=o)[o-])c(c(f)(f)f)c1',
#  'nc1c([n+](=o)[o-])cc(c(f)(f)f)cc1[n+](=o)[o-]',
#  'nc1cc(c(f)(f)f)cc(c(f)(f)f)c1',
#  'nc1cc(c(f)(f)f)ccc1cl',
#  'nc1ccc(c(=o)o)c(f)c1',
#  'nc1ccc(c(=o)o)cc1f',
#  'nc1ccc(c(f)(f)f)cc1',
#  'nc1ccc(f)c(cl)c1',
#  'nc1ccc(f)cc1',
#  'nc1ccc(f)cc1f',
#  'ccc(c)nc(=o)c(f)=cc1ccccc1',
#  'ccc(cc)c(=o)ns(=o)(=o)c1cc([n+](=o)[o-])cc(c(f)(f)f)c1',
#  'ccc(cc)c(=o)ns(=o)(=o)c1ccc(c(f)(f)f)cc1n',
#  'ccc(cc)c(=o)nc1cc(c(f)(f)f)ccc1s(n)(=o)=o',
#  'nc1cccc(f)c1',
#  'ccc(cc)c1ccc(f)c(nc(=o)n(c)c(=o)nc)c1',
#  'nc1ccccc1c(f)(f)f',
#  'nc1ccccc1f',
#  'o=c(c=cc1ccc(cl)cc1)c(f)(f)f',
#  'o=c(c=cc1cccc(cl)c1)c(f)(f)f',
#  'o=c(c=cc1cccc([n+](=o)[o-])c1)c(f)(f)f',
#  'o=c(c=cc1ccccc1)c(f)(f)f',
#  'o=c(c=cc1ccccc1cl)c(f)(f)f',
#  'o=c(cf)nc(co)c(o)c1ccc([n+](=o)[o-])cc1',
#  'occ1ccccc1f',
#  'cccc(=o)occ(=o)nc1ccc(f)cc1cl',
#  'o=c(nc(co)c(o)c1ccc([n+](=o)[o-])cc1)c(f)(f)f',
#  'o=c(nc(co)c(o)c1ccc([n+](=o)[o-])cc1)c(f)f',
#  'o=c(ncc(o)c1ccc([n+](=o)[o-])cc1)c(f)(f)f',
#  'o=c(nc1ccc(br)cc1)c(f)(f)f',
#  'o=c(nc1ccc(cl)c(cl)c1)c(f)(f)f',
#  'o=c(nc1ccc(cl)c(cl)c1)c(f)f',
#  'o=c(nc1ccccc1)c(f)(f)f',
#  'o=c(o)coc1cc(f)cc(cl)c1',
#  'o=c(o)coc1cc(f)cc(i)c1',
#  'o=c(o)coc1ccc(f)cc1',
#  'o=c(o)coc1ccc(s(=o)(=o)f)cc1',
#  'o=c(o)coc1cccc(c(f)(f)f)c1',
#  'o=c(o)coc1cccc(f)c1',
#  'o=c(o)coc1cccc(oc(f)(f)f)c1',
#  'o=c(o)coc1cccc(s(=o)(=o)c(f)(f)f)c1',
#  'o=c(o)coc1cccc(s(f)(f)(f)(f)f)c1',
#  'o=c(o)coc1cccc(sc(f)(f)f)c1',
#  'o=c(o)coc1ccccc1f',
#  'o=c(o)cc1ccc(c(f)(f)f)cc1',
#  'o=c(o)cc1ccc(f)cc1',
#  'o=c(o)cc1ccc(s(=o)(=o)f)cc1',
#  'o=c(o)cc1cccc(c(f)(f)f)c1',
#  'o=c(o)cc1cccc(f)c1',
#  'o=c(o)cc1ccccc1f',
#  'o=c(o)c1c(f)cccc1cl',
#  'o=c(o)c1c(f)cccc1f',
#  'o=c(o)c1ccc(c(f)(f)f)cc1',
#  'o=c(o)c1ccc(f)cc1',
#  'o=c(o)c1cccc(c(f)(f)f)c1',
#  'o=c(o)c1cccc(f)c1',
#  'ccccn(cc)c1c([n+](=o)[o-])cc(c(f)(f)f)cc1[n+](=o)[o-]',
#  'o=c(o)c1ccccc1f',
#  'o=c(occnc(=o)c(f)(f)f)c1ccccc1',
#  'o=c(c1ccccc1)c(f)(f)f',
#  'cccn(ccc)c1c([n+](=o)[o-])cc(c(f)(f)f)c(n)c1[n+](=o)[o-]',
#  'cccn(ccc)c1c([n+](=o)[o-])cc(c(f)(f)f)cc1[n+](=o)[o-]',
#  'cccn(cccl)c1c([n+](=o)[o-])cc(c(f)(f)f)cc1[n+](=o)[o-]',
#  'cccnc1c([n+](=o)[o-])cc(c(f)(f)f)cc1[n+](=o)[o-]',
#  'o=cnc1ccc(f)cc1',
#  'o=cc1ccc(f)cc1',
#  'o=cc1cccc(c(f)(f)f)c1',
#  'o=s(=o)(cf)nc1ccc(cl)cc1',
#  'o=s(=o)(cf)nc1ccccc1',
#  'o=s(=o)(ncc1ccccc1)c(f)(f)f',
#  'o=s(=o)(nc1ccc(c(f)(f)f)cc1)c(f)(f)f',
#  'o=s(=o)(nc1ccc(cl)cc1)c(f)(f)f',
#  'o=s(=o)(nc1ccc(cl)cc1)c(f)f',
#  'o=s(=o)(nc1ccc(cl)cc1cl)c(f)(f)f',
#  'o=s(=o)(nc1ccc(f)cc1)c(f)(f)f',
#  'o=s(=o)(nc1ccc(f)cc1f)c(f)(f)f',
#  'o=s(=o)(nc1ccc(i)cc1)c(f)(f)f',
#  'o=s(=o)(nc1cccc(br)c1)c(f)(f)f',
#  'o=s(=o)(nc1cccc(c(f)(f)f)c1)c(f)(f)f',
#  'o=s(=o)(nc1cccc(cl)c1)c(f)(f)f',
#  'o=s(=o)(nc1cccc(f)c1)c(f)(f)f',
#  'o=s(=o)(nc1cccc(o)c1)c(f)(f)f',
#  'o=s(=o)(nc1ccccc1)c(f)(f)f',
#  'o=s(=o)(nc1ccccc1)c(f)f',
#  'o=s(=o)(c1ccccc1)c(f)(f)f',
#  'ccn(cc)ccnc(=o)c1cc(f)c(n)cc1oc',
#  'ccn(cc)ccnc(=o)c1cc(f)cc(cl)c1oc',
#  'ccn(cc)ccnc(=o)c1cc(f)ccc1oc',
#  'ccn(cc)ccoc(=o)c=cc1ccc(f)cc1',
#  'o=[n+]([o-])c1cc(c(f)(f)f)cc([n+](=o)[o-])c1cl',
#  'o=[n+]([o-])c1cc(c(f)(f)f)ccc1o',
#  'ccn(cc)c1c([n+](=o)[o-])cc(c(f)(f)f)c(n)c1[n+](=o)[o-]',
#  'o=[n+]([o-])c1cc(f)cc(f)c1',
#  'o=[n+]([o-])c1cc(f)ccc1f',
#  'o=[n+]([o-])c1cc([n+](=o)[o-])c(oncc(f)(f)f)c([n+](=o)[o-])c1',
#  'o=[n+]([o-])c1ccc(c(f)(f)f)cc1',
#  'o=[n+]([o-])c1ccc(cl)cc1c(f)(f)f',
#  'o=[n+]([o-])c1ccc(f)cc1',
#  'o=[n+]([o-])c1ccc(f)cc1o',
#  'o=[n+]([o-])c1cccc(c(f)(f)f)c1',
#  'o=[n+]([o-])c1cccc(f)c1',
#  'o=[n+]([o-])c1ccccc1c(f)(f)f',
#  'o=[n+]([o-])c1ccccc1f',
#  'ccnc(c)cc1cccc(c(f)(f)f)c1',
#  'ccoc(=o)c(=cc1ccc(f)cc1)c(=o)occ',
#  'ccoc(=o)c(=cc1cccc(f)c1)c(=o)occ',
#  'ccoc(=o)c(=cc1cccc(f)c1)c(c)=o',
#  'ccoc(=o)c(=cc1ccccc1f)c(=o)occ',
#  'ccoc(=o)c(c#n)=nnc1cc(c(f)(f)f)ccc1cl',
#  'ccoc(=o)c(c#n)=nnc1ccc(cl)c(c(f)(f)f)c1',
#  'oc(c1ccccc1)(c(f)(f)f)c(f)(f)f',
#  'ccoc(=o)c1ccc(nc(=o)c(f)(f)f)cc1',
#  'occ1c(f)cccc1f',
#  'occ1cccc(c(f)(f)f)c1',
#  'on=cc1ccc(f)cc1',
#  'oc1c(f)c(f)c(f)c(f)c1f',
#  'oc1c(f)cccc1f',
#  'cco[ph](=o)(=o)cc1ccc(f)cc1',
#  'oc1ccc(c(f)(f)f)cc1',
#  'oc1ccc(f)cc1',
#  'ccoc1ccc(nc(=o)oc(c)cf)cc1occ',
#  'ccoc1ccc(nc(=o)occf)cc1occ',
#  'oc1cccc(c(f)(f)f)c1',
#  'oc1cccc(f)c1',
#  'oc1ccccc1c(f)(f)f',
#  'oc1ccccc1f',
#  'occ1ccc(f)cc1',
#  'ccc1ccc(f)c(nc(=o)n(c)c(=o)nc)c1',
#  'cn(c(=o)c1c(f)c(f)c(f)c(f)c1f)c(c)(c)c',
#  'cn(c)/n=n/c1cccc(c(f)(f)f)c1',
#  'cn(c)c(=o)nc1ccc(f)cc1',
#  'cn(c)c(=o)nc1cccc(c(f)(f)f)c1',
#  'cn(c)c(=o)nc1cccc(f)c1',
#  'cn(c)c(=o)occ1ccc(c(f)(f)f)cc1',
#  'cn(c)c(=o)occ1ccc(f)cc1',
#  'cn(c)c(=o)oc1ccc(f)cc1',
#  'cn(c)c(=o)oc1cccc(f)c1',
#  'cn(c)c(n(c)c)=s(i)c1ccc(f)cc1',
#  'cn(c)c(n(c)c)=s(i)c1cccc(f)c1',
#  'cn(c)c(n(c)c)=s(i)c1ccccc1f',
#  'cn(c)n=nc1ccc(c(f)(f)f)cc1',
#  'cn(c)n=nc1cccc(c(f)(f)f)c1',
#  'cn(c)s(=o)(=o)n(sc(f)(cl)cl)c1ccccc1',
#  'cn(cc(f)(f)f)n=nc1ccc(c(n)=o)cc1',
#  'cn(cc(f)(f)f)oc1c([n+](=o)[o-])cc([n+](=o)[o-])cc1[n+](=o)[o-]',
#  'cn(cc1ccc(f)cc1)n=o',
#  'cn(cc1cccc(c(f)(f)f)c1)n=o',
#  'cn(n=o)c(=o)nc1ccc(f)cc1',
#  'cnc(=o)n(c)c(=o)nc1cc(c(=o)oc)ccc1f',
#  'cnc(=o)n(c)c(=o)nc1cc(c(c)(c)c)ccc1f',
#  'cnc(=o)n(c)c(=o)nc1cc(c(c)=o)ccc1f',
#  'cnc(=o)n(c)c(=o)nc1cc(c(c)c)ccc1f',
#  'cnc(=o)n(c)c(=o)nc1cc(f)ccc1f',
#  'cnc(=o)n(c)c(=o)nc1cc(i)ccc1f',
#  'cnc(=o)n(c)c(=o)nc1cc(oc(c)c)ccc1f',
#  'cnc(=o)n(c)c(=o)nc1cc(oc)ccc1f',
#  'cnc(=o)n(c)c(=o)nc1cc(s(=o)(=o)c(c)c)ccc1f',
#  'cnc(=o)n(c)c(=o)nc1cc([n+](=o)[o-])ccc1f',
#  'cnc(=o)n(c)c(=o)nc1ccccc1f',
#  'cnc(=o)oc1ccc(f)cc1',
#  'cnc(=o)oc1cccc(c(f)(f)f)c1',
#  'cnc(=o)oc1cccc(f)c1',
#  'cnc(=o)oc1ccccc1f',
#  'coc(=o)c(c#n)=nnc1c(cl)cc(c(f)(f)f)cc1cl',
#  'coc(=o)c(c#n)=nnc1cc(c(f)(f)f)cc(c(f)(f)f)c1',
#  'coc(=o)c(c#n)=nnc1cc(c(f)(f)f)ccc1cl',
#  'coc(=o)c(c#n)=nnc1ccc(c(f)(f)f)cc1',
#  'coc(=o)c(c#n)=nnc1ccc(c(f)(f)f)cc1[n+](=o)[o-]',
#  'coc(=o)c(c#n)=nnc1ccc(cl)c(c(f)f)c1',
#  'coc(=o)c(c#n)=nnc1ccc(cl)cc1c(f)(f)f',
#  'coc(=o)c(c#n)=nnc1ccc(s(=o)(=o)c(f)(f)f)cc1',
#  'coc(=o)c(c#n)=nnc1ccc(sc(f)(f)f)cc1',
#  'coc(=o)c(c#n)=nnc1cccc(c(f)(f)f)c1',
#  'coc(=o)c(c#n)=nnc1ccccc1c(f)(f)f',
#  'coc(=o)nc1ccc(f)cc1',
#  'coc(=o)nc1cccc(c(f)(f)f)c1',
#  'coc(=o)nc1cccc(f)c1',
#  'coc(=o)nc1ccccc1c(f)(f)f',
#  'coc(=o)nc1ccccc1f',
#  'coc(=o)c1c(f)cccc1cl',
#  'coc(=o)c1c(f)cccc1f',
#  'coc(=o)c1ccc(f)cc1',
#  'coc(=o)c1ccccc1f',
#  'cocccnc(=o)c1ccccc1c(f)(f)f',
#  'con(c)c(=o)nc1ccc(f)cc1',
#  'con(c)c(=o)nc1cccc(c(f)(f)f)c1',
#  'con(c)c(=o)nc1cccc(f)c1',
#  'coc1ccc(c=cc(=o)c(f)(f)f)cc1',
#  'coc1ccc(f)cc1',
#  'coc1ccc(ns(=o)(=o)c(f)(f)f)cc1',
#  'coc1cccc(c=cc(=o)c(f)(f)f)c1',
#  'coc1cccc(f)c1',
#  'coc1cccc(ns(=o)(=o)c(f)(f)f)c1',
#  'coc1ccccc1c=cc(=o)c(f)(f)f',
#  'coc1ccccc1f',
#  'cs(=o)(=o)c1c(f)c(f)c(f)c(f)c1f',
#  'cs(=o)(=o)c1ccc(ns(=o)(=o)c(f)(f)f)cc1',
#  'cs(=o)(=o)c1cccc(ns(=o)(=o)c(f)(f)f)c1',
#  'csc(c)=noc(=o)n(c)sn(c)c(=o)c1cccc(c(f)(f)f)c1',
#  'csc1ccc(ns(=o)(=o)c(f)(f)f)cc1',
#  'nc1cccc(c(f)(f)f)c1',
#  'fc(f)(f)c1ccc(-n2cc3ccccc3n2)cc1',
#  'cc1cc2c3cc=c4cc(=o)c=cc4(c)c3(f)c(o)cc2(c)c1(o)c(=o)coc1oc(co)c(o)c(o)c1o',
#  'fc(f)(f)c1cccc(n2ccncc2)c1',
#  'fc1ccc(n2ccncc2)cc1',
#  'cn1cc(-c2ccccc2)c(=o)c(-c2cccc(c(f)(f)f)c2)c1',
#  'o=c(cccn1ccc(n2c(=o)[nh]c3ccccc32)cc1)c1ccc(f)cc1',
#  'ns(=o)(=o)c1cc2cc(cnccf)sc2o1',
#  'n=c1ccn(c2cccc(c(f)(f)f)c2)n1',
#  'cc1c(f)c(f)c(coc(=o)c2c(c=c(cl)c(f)(f)f)c2(c)c)c(f)c1f',
#  'cc1(c)c(c=c(cl)cl)c1c(=o)occ1c(f)c(f)cc(f)c1f',
#  'cn(c1nc2ccccc2s1)c1ccn(ccccoc2ccc(f)cc2)cc1',
#  'fc1ccc(c2(cn3cncn3)oc2c2ccccc2cl)cc1',
#  'ccn(c(=o)coc(=o)/c(=c/c1ccc(cl)cc1)c1ccc(f)cc1)[c@@h]1ccs(=o)(=o)c1',
#  'o=c(ncccco)c(f)(f)cn1ccnc1[n+](=o)[o-]',
#  'o=c(nccco)c(f)(f)cn1ccnc1[n+](=o)[o-]',
#  'o=c(ncco)c(f)(f)cn1ccnc1[n+](=o)[o-]',
#  'nc(=o)ccnc(=o)c(f)(f)cn1ccnc1[n+](=o)[o-]',
#  'cocc(f)cn1ccnc1[n+](=o)[o-]',
#  'cn(cccn1ccnc1c=no)s(=o)(=o)c(f)(f)f',
#  'o=[n+]([o-])c1nccn1cc(f)(f)co',
#  'o=[n+]([o-])c1nccn1cc(f)co',
#  'o=[n+]([o-])c1nccn1cc(o)cf',
#  'o=[n+]([o-])c1nccn1cc(o)cocc(f)(f)f',
#  'cc1onc(-c2c(f)cccc2cl)c1c(=o)occ(=o)n1[c@h](c)ccc[c@h]1c',
#  'cs(=o)(=o)c1cc(c(f)(f)f)ccc1c(=o)c1cnoc1c1cc1',
#  'cnc(=o)n(c)c1nnc(c(f)(f)f)s1',
#  'oc1(c2ccc(cl)cc2)ccn(cccc2(c3ccc(f)cc3)occo2)cc1',
#  'cc1c(cn(c)c(=o)c(c)n2nc(c(f)f)c(br)c2c)cnn1c',
#  'coc1cc([c@h]2nc(=o)n=c(c)c2c(=o)oc(c)c)ccc1oc(f)f',
#  'o=c(nc1ccccc1c(f)(f)f)c1ccc1',
#  'o=c(cccn1ccc(o)(c2ccc(cl)cc2)cc1)c1ccc(f)cc1',
#  'coc1cc2c(c(oc)c1oc)-c1ccc(=o)c(oc)cc1c(nc(=o)c(f)(f)f)cc2',
#  'o=[n+]([o-])c1ncn(cc(f)(f)co)n1',
#  'o=[n+]([o-])c1ncn(cc(f)co)n1',
#  'o=[n+]([o-])c1ncn(cc(o)cf)n1',
#  'cocc(f)cn1cnc([n+](=o)[o-])n1',
#  'cocccnc(=o)c(f)(f)cn1cnc([n+](=o)[o-])n1',
#  'cocccnc(=s)c(f)(f)cn1cnc([n+](=o)[o-])n1',
#  'coccnc(=o)c(f)(f)cn1cnc([n+](=o)[o-])n1',
#  'coccnc(=s)c(f)(f)cn1cnc([n+](=o)[o-])n1',
#  'cc(o)cnc(=o)c(f)(f)cn1cnc([n+](=o)[o-])n1',
#  'cscccnc(=o)c(f)(f)cn1cnc([n+](=o)[o-])n1',
#  'csccnc(=o)c(f)(f)cn1cnc([n+](=o)[o-])n1',
#  'o=c(nccco)c(f)(f)cn1cnc([n+](=o)[o-])n1',
#  'o=c(ncco)c(f)(f)cn1cnc([n+](=o)[o-])n1',
#  'ccn1ccc(cn(c)c(=o)c2ccccc2coc2ccc(f)cc2f)n1',
#  'o=c(cn1ccccc1)nc1ccc(f)cc1',
#  'o=c(cn1ccccc1)nc1cccc(f)c1',
#  'o=c(cn1ccccc1)nc1ccccc1f',
#  'c=ccn1c(scc(=o)nc2ccc(c)c(f)c2)nnc1-c1cccs1',
#  'o=nn(ccf)c(=o)nc1ccscc1',
#  'cc(c)coc1ccc(c(=o)n2n=c(c(f)f)c[c@@]2(o)c(f)f)cc1',
#  'o=c(cnc(=o)c1ccccc1)oc1cccc(f)c1',
#  'o=c(cnc(=o)c1ccccc1)oc1ccc(f)cc1',
#  'o=c(cnc(=o)c1ccccc1)oc1cccc(c(f)(f)f)c1',
#  'o=c(ccn1ccc(o)(c2ccc(cl)cc2)cc1)c1ccc(f)cc1',
#  'o=c1c2ccccc2c(=o)c1c1ccc(c(f)(f)f)cc1',
#  'o=c1c2ccccc2c(=o)c1c1cccc(c(f)(f)f)c1',
#  'o=c(c1ccc(f)cc1)c1ccn(ccn2c(=o)[nh]c3ccccc3c2=o)cc1',
#  'fc(f)(c1ccccc1)c(f)(f)c1ccccc1',
#  'ccoc(o)=c1[nh]c(=c2c(=o)c3ccccc3c2=o)c2c(o)n(n(c)c3ncc(c(f)(f)f)cc3cl)c(o)c12',
#  'o=c(ncc1ccc(f)cc1)c1nn2c(c1br)nc(c1cccs1)c[c@h]2c(f)(f)f',
#  'cc(c)oc(=o)c1cc(oc(=o)n2cccc2)c(f)cc1cl',
#  'c#ccoc1cc(oc(=o)n2ccc(f)(f)c2)c(cl)cc1cl',
#  'o=c(nccn1ccc(o)(c2ccc(cl)cc2)cc1)c1ccc(f)cc1',
#  'coc(=o)c1cnn2c(c(f)(f)f)cc(-c3cc(oc)c(oc)c(oc)c3)nc12',
#  'o=c(nccn1ccc(n2c(=o)[nh]c3cc(cl)ccc32)cc1)c1ccc(f)cc1',
#  'fcc1co1',
#  'coc1ccc(occos(=o)(=o)c2ccc(c)cc2)c(cn(c(c)=o)c2cc(f)ccc2oc2ccccc2)c1',
#  'o=c(c1cccc(cocc(f)(f)c(f)f)c1)n1cc[c@@h](c(f)(f)f)n2nccc21',
#  'o=c(oc1ccccc1)n1c(=o)[nh]cc(f)c1=o',
#  'cc(c(=o)nc1ccc2c(c(f)(f)f)cc(=o)oc2c1)n1nc(c(f)(f)f)c(cl)c1c1cc1',
#  'ns(=o)(=o)c1cc2c(cc1c(f)(f)c(f)(f)f)n=cns2(=o)=o',
#  'ns(=o)(=o)c1cc2c(cc1c(f)(f)f)n=cns2(=o)=o',
#  'ns(=o)(=o)c1cc2c(cc1f)n=cns2(=o)=o',
#  'fc(f)c(f)(f)occ(cn1cncn1)c1ccc(cl)cc1cl',
#  'coc1cc(c=o)ccc1os(=o)(=o)c1ccc(f)c(f)c1',
#  'cc12c=cc(=o)c=c1c(f)cc1c2c(o)cc2(c)c1ccc2(o)c(=o)co',
#  'cc12c=cc(=o)c=c1ccc1c3cc(o)c(o)(c(=o)co)c3(c)cc(o)c12f',
#  'cc12c=cc(=o)c=c1ccc1c3ccc(o)(c(=o)co)c3(c)cc(o)c12f',
#  'n=c1[nh]c(=n)c2ncn(c3cc(f)c(co)o3)c2[nh]1',
#  'cn1c(=o)cn=c(c2ccc(cl)cc2)c2cc(f)ccc21',
#  'cn1c(=o)cn=c(c2ccccc2c(f)(f)f)c2cc([n+](=o)[o-])ccc21',
#  'cn1c(=o)cn=c(c2ccccc2f)c2cc(cl)ccc21',
#  'cn1c(=o)cn=c(c2ccccc2f)c2cc(f)ccc21',
#  'cn1c(=o)cn=c(c2ccccc2f)c2cc(i)ccc21',
#  'cn1c(=o)cn=c(c2ccccc2f)c2cc(n)ccc21',
#  'o=c1cn=c(c2ccccc2)c2cc(cl)ccc2n1cc(f)(f)f',
#  'o=c1cn=c(c2ccccc2f)c2cc(cl)ccc2n1cc(f)(f)f',
#  'o=c1cn=c(c2ccccc2f)c2cc(cl)ccc2n1cc(o)co',
#  'o=c1cn=c(c2ccccc2f)c2cc(i)ccc2n1cc(o)co',
#  'cocn1c(=o)cn=c(c2ccccc2f)c2cc(n)ccc21',
#  'cc(c)ncc(o)coc1ccc(occoccc2ccc(f)cc2)cc1',
#  'cc1(c)oc2cc3c4cc=c5cc(=o)c=cc5(c)c4(f)c(o)cc3(c)c2(c(=o)co)o1',
#  'cc(=o)occ(=o)c12oc(c)(c)oc1cc1c3cc(f)=c4cc(=o)c=cc4(c)c3(f)c(o)cc12c',
#  'cc1(c)oc2cc3c4cc(f)=c5cc(=o)c(cl)=cc5(c)c4(f)c(o)cc3(c)c2(c(=o)co)o1',
#  'cc1(c)oc2cc3c4cc(f)=c5cc(=o)c=cc5(c)c4(f)c(o)cc3(c)c2(c(=o)co)o1',
#  'cc1cc(oc(=o)coc2ccc(f)cc2)cc(c)(c)c1',
#  'cc(c)(c)c1cc(c(f)(f)f)nc(sccnc(=o)c2ccccc2)n1',
#  'cc(sc1nnnn1-c1ccc(cl)cc1)c(=o)ncc(=o)nc1ccc(f)c(f)c1f',
#  'cc(c)(c)n(nc(=o)c1ccccc1)c(=o)c1c(f)c(f)c(f)c(f)c1f',
#  'cc(c)(c)n(nc(=o)c1ccccc1)c(=o)c1c(f)cccc1cl',
#  'cc(c)(c)n(nc(=o)c1ccccc1)c(=o)c1c(f)cccc1f',
#  'cc(c)(c)n(nc(=o)c1ccccc1)c(=o)c1cc(f)c(f)c(f)c1f',
#  'cc(c)(c)n(nc(=o)c1ccccc1)c(=o)c1ccc(c(f)(f)f)cc1',
#  'cc(c)(c)n(nc(=o)c1ccccc1)c(=o)c1ccc(f)cc1',
#  'cc(c)(c)n(nc(=o)c1ccccc1)c(=o)c1cccc(c(f)(f)f)c1',
#  'cc(c)(c)n(nc(=o)c1ccccc1)c(=o)c1cccc(f)c1',
#  'cc(c)(c)n(nc(=o)c1ccccc1)c(=o)c1ccccc1c(f)(f)f',
#  'cc(c)(c)n(nc(=o)c1ccccc1)c(=o)c1ccccc1f',
#  'cc(c)(c)n(nc(=o)c1ccccc1f)c(=o)c1ccccc1cl',
#  'cc(c)(c)n(nc(=o)c1ccc(f)cc1)c(=o)c1ccccc1cl',
#  'cc(c)(c)n(nc(=o)c1cccc(f)c1)c(=o)c1ccccc1cl',
#  'cc1nn(c)cc1-c1cc(c(f)(f)f)n2ncc(c(=o)n(c3ccccc3)c3ccccc3)c2n1',
#  'o=[n+]([o-])c1cc[n+]([o-])c2c(f)cccc12',
#  'cn1c(=s)[nh]nc(-c2ccc(oc(f)(f)f)c(cl)c2)c1=o',
#  'cn1c(=s)[nh]nc(-c2ccc(f)cc2)c1=o',
#  'cc1(c2ccc(f)cc2)oc2cc3c4cc=c5cc(=o)ccc5c4ccc3(c)c2(c(=o)co)o1',
#  'cc(=o)c12oc(c)(c3ccc(f)cc3)oc1cc1c3cc=c4cc(=o)ccc4(c)c3ccc12c',
#  'o=c(occ1ccccc1)n1cc(f)c(=o)[nh]c1=o',
#  'ns(=o)(=o)c1nn2c(=nc3ccc(f)cc3)snc2s1',
#  'ns(=o)(=o)c1nn2c(=nc3cccc(f)c3)snc2s1',
#  'fc1ccc(oc2ccnc3cc(cl)cc(cl)c23)cc1',
#  'n#cc1[nh]n(-c2c(cl)cc(c(f)(f)f)cc2cl)c(=n)c1s(=o)c(f)(f)f',
#  'cc(=o)c(c#n)=nnc1ccc2c(c1)oc(f)(f)c(f)(f)o2',
#  'coc(=o)c(c#n)=nnc1ccc2c(c1)oc(f)(f)c(f)(f)o2',
#  'cn(c1nc2ccccc2s1)c1ccn(cc(o)coc2ccc(f)cc2)cc1',
#  'o=c(c1ccccc1)n1c(=o)[nh]cc(f)c1=o',
#  'cc12ccc(=o)c=c1ccc1c3ccc(o)(c(=o)co)c3(c)cc(=o)c12f',
#  'o=c1/c(=c/c2ccsc2)sc(=s)n1c1cccc(c(f)(f)f)c1',
#  '[o-][n+]1cnc2c(c1)ncn2c1oc(co)cc1f',
#  'o=c(cccn1ccn(c2ccccn2)cc1)c1ccc(f)cc1',
#  'fc(f)(f)c1nc(-c2ccc(-c3noc(c(f)(f)f)n3)cc2)no1',
#  'oc(cn1ccocc1)(c1ccc(f)cc1)c1ccc(-c2ccncc2)cc1',
#  'o=c1c(cl)c(ccl)cn1c1cccc(c(f)(f)f)c1',
#  'cc1cc(c(f)(f)f)nn1c(c)c1n[nh]c(=nc2ccn(cc3ccccc3)n2)s1',
#  'o=c1[nh]c2c(o)ccc(ccnccccccncc(f)(f)c3ccccc3)c2s1',
#  'fc1cncnc1',
#  'fc1ncccn1',
#  'cs(=o)(=o)n(cc(=o)nc1c(f)cccc1f)c1cc(cl)c(cl)cc1cl',
#  'cc1cn1c1=c(f)c(=o)c(n2cc2c)=c(f)c1=o',
#  'nc(=o)c1(n2ccccc2)ccn(cccc(=o)c2ccc(f)cc2)cc1',
#  'o=c(ncc1ccco1)c1cc2nc(c3cc3)cc(c(f)(f)f)n2n1',
#  'coc1ccc([c@@h]2c3c(=o)c[c@@h](c4ccco4)cc3=nc3ccccc3n2c(=o)c(f)(f)f)cc1',
#  'o=c(nc1ccc(c(f)(f)f)cc1)c1ccc2ccccc2o1',
#  'coc1cccc(cnc(=o)c2(o)c(c)cc3c4cc=c5cc(=o)c=cc5(c)c4(f)c(o)cc32c)c1',
#  'cc1cc2c3cc=c4cc(=o)c=cc4(c)c3(f)c(o)cc2(c)c1(o)c(=o)ncc1ccc([n+](=o)[o-])cc1',
#  'cc1cc2c3cc=c4cc(=o)c=cc4(c)c3(f)c(o)cc2(c)c1(o)c(=o)ncc1ccccc1',
#  'cc1cc2c3cc=c4cc(=o)c=cc4(c)c3(f)c(o)cc2(c)c1(o)c(=o)nc(co)c1ccccc1',
#  'o=nn(ccf)c(=o)nc1cscsc1',
#  'coc1n(c2cc(f)c(co)o2)c(=o)nc(=o)c1(c)br',
#  'coc1n(c2cc(f)c(co)o2)c(=o)nc(=o)c1(c)cl',
#  'coc1n(c2cc(f)c(co)o2)c(=o)nc(=o)c1(c)i',
#  'cc1c(c(=o)nc2ccc(s(=o)(=o)n3cccccc3)cc2)oc2ccc(f)cc12',
#  'coc1ccc(ccnc(=o)csc2nc3c(c(=o)n(c)c(=o)n3c)n2cc2ccccc2f)cc1oc',
#  'oc(cncc(o)c1ccc2cc(f)ccc2o1)c1ccc2cc(f)ccc2o1',
#  'c[c@h]1cn(c(=n)ns(=o)(=o)c2cc(c(f)(f)f)cc(c(f)(f)f)c2)c[c@@h](c)o1',
#  'ccoc(=o)c(c)oc1ccc(oc2cnc3cc(c(f)(f)f)ccc3n2)cc1',
#  'ccoc(=o)c(c)oc1ccc(oc2cnc3cc(f)ccc3n2)cc1',
#  'n=c1[nh]c(=o)c2ncn(c3cc(f)c(co)o3)c2[nh]1',
#  'n=c1[nh]c(=o)c2ncn(c3oc(co)cc3f)c2[nh]1',
#  'cc(oc1ccc(f)cc1f)c(=o)c1cn(-c2ccc(oc(f)(f)f)cc2)nn1',
#  'c#ccc(o)(c1ccc(f)cc1)c1cccnc1',
#  'n=c1ncc(cn2ccn(c3ccc(f)cc3)cc2)o1',
#  'n=c1ncc(cn2ccn(c3cccc(c(f)(f)f)c3)cc2)o1',
#  'o=c(o)c(c1ccccc1f)n1cccc1',
#  'cc1cccc(c)c1nc(=o)csc1nnnn1-c1ccc(oc(f)(f)f)cc1',
#  'o=c(nc1cccc(cl)c1)c1cc2n(n1)[c@h](c(f)(f)f)cc(c1ccccc1)n2',
#  'coc(=o)c1cc(s(=o)c2ccc(c(f)(f)f)cc2cl)ccc1[n+](=o)[o-]',
#  'o=c(coc(=o)c1ccccc1f)nc1ccccc1',
#  'cccocc(=nc1ccc(cl)cc1c(f)(f)f)n1ccnc1',
#  'coc1ccc(c2cc(=o)c3c(=nc4ccccc4n(c(=o)c(f)(f)f)c3c3cc(oc)c(oc)c(oc)c3)c2)cc1',
#  'coc1ccccc1n1ccn(cccoc2ccc(f)cc2)cc1',
#  'cnc(=o)n(c)c(=o)nc1cc(cc2ccccc2)ccc1f',
#  'occ#cc(o)(c1ccc(f)cc1)c1ccc(f)cc1',
#  'cc[n+](c)(c)[n-]c(=o)c(o)(c1ccc(f)cc1)c1ccc(f)cc1',
#  'coc1ccc(c(c2ccc(oc)cc2)c(f)(f)f)cc1',
#  'o=c(nc(=o)c1c(f)cccc1f)nc1ccc(con=c(c2ccc(cl)cc2)c2cc2)cc1',
#  'coc1ccc(o)c(cn(c(c)=o)c2cc(f)ccc2oc2ccccc2)c1',
#  'ccoc(=o)/c=c1/s/c(=c/c2c(f)cccc2f)c(=o)n1cc(=o)n(c)c',
#  'coc1cccc(-c2ccc3c(n)c(c(=o)nc4ccc(f)c(f)c4)sc3n2)c1',
#  'o=c(csc1ncnc2sc3c(c12)ccc3)nc1ccc(f)cc1',
#  'ccccocc(c)oc(=o)coc1[nh]c(f)c(cl)c(=n)c1cl',
#  'nn=c1c(f)c(f)[nh]c(f)c1f',
#  'ccccccc(c)oc(=o)coc1[nh]c(f)c(cl)c(=n)c1cl',
#  'o=c(nc1ccc(n2ccn(c(=o)c3ccco3)cc2)c(cl)c1)c1c(f)c(f)c(f)c(f)c1f',
#  'o=c(c1ccc(c(f)(f)f)cc1)c1ccc2n1ccc2c(=o)o',
#  'o=c(c1ccc(f)cc1)c1ccc2n1ccc2c(=o)o',
#  'o=c(c1ccc(f)cc1f)c1ccc2n1ccc2c(=o)o',
#  'cc1cc2n(c1c(=o)c1ccc(f)cc1)ccc2c(=o)o',
#  'o=c(c1cccc(c(f)(f)f)c1)c1ccc2n1ccc2c(=o)o',
#  'o=c(c1c(f)c(f)c(f)c(f)c1f)c1ccc2n1ccc2c(=o)o',
#  'o=c(c1c(f)cccc1f)c1ccc2n1ccc2c(=o)o',
#  'ccc1cc2n(c1c(=o)c1ccc(f)cc1)ccc2c(=o)o',
#  'coc(=o)c1c(nc(nc(=o)c2cccnc2)(c(f)(f)f)c(f)(f)f)sc2c1ccccc2',
#  'cc(c)c(sc1nnc(c(f)(f)f)n1c)c(=o)nc(n)=o',
#  'ccoc(=o)c1c[nh]c2c(c(c)nn2c)c1=nc1ccc(f)cc1',
#  'nc(cc1ccc(o)c(o)c1)c(=o)occ1cccc(c(f)(f)f)c1',
#  'cn(cc1ccccc1)s(=o)(=o)c1ccc(nc(=o)cc2ccc(f)cc2)cc1',
#  'coc1ccccc1n1ccn(ccnc(=o)c2ccc(f)cc2)cc1',
#  'ccoc(=o)c1c(c)=nc(=o)n[c@h]1c1ccc(-c2cc(c(f)(f)f)cc(c(f)(f)f)c2)o1',
#  'o=c(coc(=o)/c=c/c1ccc(f)cc1)nc1cc(c(f)(f)f)ccc1n1ccocc1',
#  'o=c1[nh]c(=o)n(-c2ccc(cl)cc2cl)cc1f',
#  'cc1nc2sccn2c(=o)c1ccn1ccc(=c(c2ccc(f)cc2)c2ccc(f)cc2)cc1',
#  'c#ccn1c(=o)coc2cc(f)c(-n3c(o)c4c(c3o)ccc=c4)cc21',
#  'o=c(c1ccccc1)c1ccc(n2ccn(c(=o)c3c(f)cccc3f)cc2)c(f)c1',
#  'o=c(nn=cc1ccccc1o)c1cccc(f)c1',
#  'cc(c)(c)oc(=o)n1cccc1c(=o)oc1ccc2c(=o)c(-c3ccc(f)cc3)coc2c1',
#  'cc1c(cl)c(c(f)(f)f)nn1c(c)c(=o)n1ccocc1',
#  'cc(c)(c)c1cc(-c2nc(-c3ccc(c(f)(f)f)cn3)no2)n(cc2ccccc2)n1',
#  'cn(n=cc1ccc(f)cc1)p(=o)(n1cc1)n1cc1',
#  'o=p(nn=cc1ccc(f)cc1)(n1cc1)n1cc1',
#  'o=c(c1cc2ccccc2s1)n1cccn(c2ccc(c(f)(f)f)cn2)cc1',
#  'coc1cc([c@h]2c3c(c)n[nh]c3oc(=n)c2c#n)ccc1occ1cccc(f)c1',
#  'ccc1nc(s(=o)(=o)nc2c(f)cccc2f)nn1-c1ccccc1',
#  'coc1ccc(c=o)cc1coc1c(f)c(f)cc(f)c1f',
#  'fc1ccc(scc2ccc(cccn3ccocc3)cc2)cc1',
#  'ccccc1cccc(c2(c(oc3nc(c)cc(c)n3)c(=o)o)ncc(=o)n(cc3c(f)cc(f)cc3f)c3ccccc32)c1',
#  'nc1ccc(s(=o)(=o)c2ccc(f)cc2)cc1',
#  'coc(=o)c1cc(s(=o)(=o)c2ccc(c(f)(f)f)cc2cl)ccc1[n+](=o)[o-]',
#  'o=c(nc1ccccc1)n1cc(f)c(=o)[nh]c1=o',
#  'occ1oc(oc2cccc(c(f)(f)f)c2)c(o)c(o)c1o',
#  'oc1ccc(c2(o)ccn(cccsc3ccc(f)cc3)cc2)cc1',
#  'oc1c(f)cc(cn2cc[nh]c2=s)cc1f',
#  'fc1cc(f)cc(cn2cc[nh]c2=s)c1',
#  'fc1ccccc1cn1cc[nh]c1=s',
#  'oc1ccc(cn2cc[nh]c2=s)cc1f',
#  'ccoc(=o)nc1=ncc(c2cccc(f)c2)n1c',
#  'coc(=o)nc1=ncc(c2ccccc2f)n1c',
#  'ccoc(=o)nc1=ncc(c2ccc(f)cc2)n1c',
#  'o=c1[nh]cc(f)c(=o)n1oc1ccccc1',
#  'fn(f)c(c1ccccc1)(c1ccccc1)c1ccccc1',
#  'coc1cccc(c(=o)nc2ccn(cc3ccc(f)cc3)cc2)c1oc',
#  'o=c(n=c1[nh]cnc2c1ncn2c1oc(co)cc1f)c1ccccc1',
#  'cn1ccn(c2cc3c(cc2f)c(=o)c(c(=o)o)cn3-c2ccc(f)cc2)cc1',
#  'ccccccc1nc2cc(c(f)(f)f)c(s(n)(=o)=o)cc2s(=o)(=o)n1',
#  'ns(=o)(=o)c1cc2c(cc1c(f)(f)f)ncns2(=o)=o',
#  'cn1c(cscc(f)(f)f)nc2cc(cl)c(s(n)(=o)=o)cc2s1(=o)=o',
#  'ns(=o)(=o)c1cc2c(cc1cl)nc(c(f)(f)f)ns2(=o)=o',
#  'cccc(=nc(=o)c(cc1ccccc1)ns(=o)(=o)n1ccocc1)c(=o)nc(coc(f)(f)c(=o)nccn1ccocc1)cc1ccccc1',
#  'o=c1nc(n=cn2cccc2)ccn1c1cc(f)c(co)o1',
#  'fc(f)(f)c1nc2c(cl)c(cl)c(cl)cc2[nh]1',
#  'fc(f)(f)c1ccc2cccnc2c1',
#  'fc(f)(f)c1cccc2cccnc12',
#  'fc1cccc2cccnc12',
#  'o=c(nc1cccc2cccnc12)c(f)(f)f',
#  'oc1ccc(f)c2cccnc12',
#  'coc1cc2c(cc1oc)[c@@h](coc1ccc(f)cc1)n(c(=o)/c=c/c1ccccc1)cc2',
#  'coc(=o)nc1=nc(c2cccc(f)c2)cn1',
#  'c[c@]12co[c@]3(c(=o)ncc(f)(f)f)c[c@h]1cc[c@]23c',
#  'csc1ccc([c@@h]2c3c(c(o)n(-c4cccc(c(f)(f)f)c4)c3o)on2c2ccccc2)cc1',
#  'o=c(nc1cc1)c1ccc(coc2c(f)c(f)cc(f)c2f)o1',
#  'cc1nc(=n)c2ncn(c3oc(co)cc3f)c2[nh]1',
#  'fc1ccc(scc2ccccc2cccn2ccocc2)cc1',
#  'n=c1nc(cl)c2ncn(c3oc(co)cc3f)c2[nh]1',
#  'n=c1nc(f)c2ncn(c3ccc(co)o3)c2[nh]1',
#  'o=c(cc(o)cc(o)c=cn1c(c(f)(f)f)nc(-c2ccc(f)cc2)c1-c1ccc(f)cc1)o[na]',
#  'cc(c)c1nc(-c2ccc(f)cc2)c(-c2ccc(f)cc2)n1c=cc(o)cc(o)cc(=o)o[na]',
#  'cc1cc(-c2nc(c(c)c)n(c=cc(o)cc(o)cc(=o)o[na])c2-c2ccc(f)cc2)cc(c)c1cl',
#  'oc(cn1cncn1)(c1ccc(f)cc1)c1ccccc1f',
#  'o=c(cn1cc(c(f)(f)f)cc(cl)c1=o)n1ccn(c(=o)c2ccco2)cc1',
#  'o=c(coc(=o)c1cccc(s(=o)(=o)n2ccc3ccccc32)c1)nc1ccc(f)c(f)c1f',
#  'o=c(nc1ccc(oc(f)f)cc1)c1ccc(coc2ccc(i)cc2)o1',
#  'fc(f)(f)c1cccc(cn2cncn2)c1',
#  'fc1ccc(cn2cncn2)cc1',
#  'cc1cc2c3cc=c4cc(=o)c=cc4(c)c3(f)c(o)cc2(c)c1(o)c(=o)nccc1ccccc1',
#  'ccc1ccc2c(c1)=c(c1ccccc1f)ncc(=o)n=2',
#  'cc(=o)c1ccc2c(c1)=c(c1ccccc1f)ncc(=o)n=2',
#  'o=c(oc1ccccc1)n1cc(f)c(=o)[nh]c1=o',
#  'n#cc1c[nh]cc1-c1cccc2c1oc(f)(f)o2',
#  'fc1ccccc1c1occ2on=c(c3ccccc3)c2co1',
#  'fc(f)(f)c1ccccc1c1occ2on=c(c3ccccc3)c2co1',
#  'oc(cn1ccnc1)(c1ccc(f)cc1)c1ccc(-c2ccccn2)cc1',
#  'oc(cn1ccnc1)(c1ccc(-c2ccccn2)cc1)c1ccc(f)cc1f',
#  'c=c1[nh]cc(co)c(=cnnc(=o)c2cccc(f)c2)c1=o',
#  'n=c1nc(-c2cc(br)ccc2f)[nh]c(=n)[nh]1',
#  'n=c1nc(-c2cc(c(f)(f)f)ccc2cl)[nh]c(=n)[nh]1',
#  'n=c1nc(-c2cc(cl)ccc2f)[nh]c(=n)[nh]1',
#  'n=c1nc(-c2cc(f)ccc2br)[nh]c(=n)[nh]1',
#  'n=c1nc(-c2cc(f)ccc2cl)[nh]c(=n)[nh]1',
#  'n=c1nc(-c2ccc(f)cc2)[nh]c(=n)[nh]1',
#  'n=c1nc(-c2cccc(c(f)(f)f)c2)[nh]c(=n)[nh]1',
#  'n=c1nc(-c2cccc(f)c2)[nh]c(=n)[nh]1',
#  'n=c1nc(-c2cccc(sc(f)(f)f)c2)[nh]c(=n)[nh]1',
#  'coc1cc(/c=c/c(=o)nc2ccc(n3ccccc3)cc2)ccc1oc(f)f',
#  'coc1cc(c(=o)c2ccc(f)cc2)cc(c(=o)c2ccc(f)cc2)c1',
#  'fc(f)(f)c1nc2ccncc2[nh]1',
#  'coc1cc([c@@h]2c3=c(cccc3=o)n(c3ccccc3c(f)(f)f)c(=n)c2c(=o)c2ccccc2)cc(oc)c1oc',
#  'coc1ccc([c@h]2c(c(=o)nc3ccc(f)cc3f)c3cc(oc)c(oc)cc3c(=o)n2c)cc1oc',
#  'o=c(c1nn2c(c1br)nc(c1cccs1)c[c@h]2c(f)(f)f)n1cccc1',
#  'fc1cccc(cl)c1nc1=nccn1',
#  'fc1cccc(f)c1nc1=nccn1',
#  'fc1cccc(nc2=nccn2)c1cl',
#  'cc1ccc(f)cc1nc1=nccn1',
#  'fc(f)(f)c1ccccc1nc1=nccn1',
#  'fc1ccc(cl)c(nc2=nccn2)c1',
#  'nc1ccc(c(=o)oc2ccc(f)cc2)c(o)c1',
#  'nc1ccc(c(=o)oc2cccc(c(f)(f)f)c2)c(o)c1',
#  'nc1ccc(c(=o)oc2cccc(f)c2)c(o)c1',
#  'nc1ccc(c(=o)oc2ccccc2f)c(o)c1',
#  'n=c1[nh][nh]c(=nc(=o)c(f)(f)c(f)(f)c(f)(f)f)[nh]1',
#  'o=c1c[c@@h](c2c(f)cccc2cl)c2cc3c(cc2n1)occo3',
#  'fc(f)(f)c(=nocc1occo1)c1ccc(cl)cc1',
#  'coc1ccccc1n1ccn(ccocc2ccc(f)cc2)cc1',
#  'cc1cc2c3cc=c4cc(=o)c=cc4(c)c3(f)c(=o)cc2(c)c1(o)c(=o)ccl',
#  'ccc(=o)oc1(c(=o)cbr)c(c)cc2c3cc=c4cc(=o)c=cc4(c)c3(f)c(=o)cc21c',
#  'cccc(=o)oc1(c(=o)ccl)c(c)cc2c3cc=c4cc(=o)c=cc4(c)c3(f)c(=o)cc21c',
#  'ccc(=o)oc1(c(=o)ccl)c(c)cc2c3cc=c4cc(=o)c=cc4(c)c3(f)c(=o)cc21c',
#  'ccc(=o)oc1(c(c)=o)c(c)cc2c3cc=c4cc(=o)c=cc4(c)c3(f)c(=o)cc21c',
#  'o=c(o)c(c1ccc(-c2ccccc2)cc1)c(o)c1cccc(f)c1',
#  'o=c(o)c(c1ccc(-c2ccccc2)cc1)c(o)c1ccccc1f',
#  'o=c(cn1c(=o)/c(=c2\\sc(=s)n(cc3ccco3)c2=o)c2ccccc21)nc1ccc(f)cc1',
#  'fc1ccc(-c2ccoc2-c2ccc(f)cc2)cc1',
#  'coc1ccccc1n=c1nc(occ(f)(f)f)[nh]c(occ(f)(f)f)n1',
#  'o=c(oc1ccccc1)n1cc(f)c(=o)[nh]c1=o',
#  'cc1nn(c)cc1-c1cc(c(f)(f)f)n2nc(c(=o)n3c[c@h](c)o[c@h](c)c3)cc2n1',
#  'cc1(c)c=c2c(c(=o)c1)[c@@h](c1cccc(cl)c1)c(c#n)c(=n)n2c1c(f)cccc1f',
#  'nc1cc2cc1c1cc(c(f)(f)f)ccc12',
#  'nc1cc2cc1c1ccc(c(f)(f)f)cc12',
#  'o=c1ccc=c2oc3=cccc(=o)c3c(c3ccc(occ4ccccc4f)cc3)c12',
#  'cnc1oc(-c2ccccc2)c(o)c1-c1ccccc1c(f)(f)f',
#  'nnc(=o)c1ccnc(f)c1',
#  'fc1cccc(f)n1',
#  'fc1ccccn1',
#  'fc1cccnc1',
#  'csc(=o)c1c(c(f)f)nc(c(f)(f)f)c(c(=o)sc)c1cc(c)c',
#  'ccop(=s)(occ)oc1cccc(f)n1',
#  'o=c(csc1nnc(-c2ccccc2f)n1ccc1ccccc1)n1ccocc1',
#  'cc(sc1nnc(-c2ccc(f)cc2)n1-c1ccccc1)c(n)=o',
#  'o=c(o[na])c1ccc(cl)cc1nc1cccc(c(f)(f)f)c1',
#  'o=c(o[na])c1ccccc1nc1cccc(c(f)(f)f)c1',
#  'coc1(nc(=o)csc(f)f)c(=o)n2c(c(=o)ococ(=o)c(c)(c)c)=c(csc3nnnn3c)csc21',
#  'o=[n+]([o-])c1cc([n+](=o)[o-])c(n=c2[nh]cc(cl)cc2cl)c(c(f)(f)f)c1',
#  'o=[n+]([o-])c1cc([n+](=o)[o-])c(n=c2[nh]cc([n+](=o)[o-])cc2cl)c(c(f)(f)f)c1',
#  'o=c(o)c1ccc[nh]c1=nc1cccc(c(f)(f)f)c1',
#  'o=[n+]([o-])c1cc(c(f)(f)f)c(cl)c([n+](=o)[o-])c1n=c1[nh]cc(c(f)(f)f)cc1cl',
#  'o=[n+]([o-])c1cc(c(f)f)c(n=c2[nh]cc(c(f)(f)f)cc2cl)c([n+](=o)[o-])c1',
#  'o=[n+]([o-])c1cc(cl)c(n=c2[nh]cc(c(f)(f)f)cc2cl)c([n+](=o)[o-])c1',
#  'cc1[nh]c(=nc2c([n+](=o)[o-])cc([n+](=o)[o-])cc2c(f)(f)f)c(c#n)cc1c#n',
#  'o=c(occ1ccccc1)n1c(=o)[nh]cc(f)c1=o',
#  'cc(=o)oc1cccc(nc(=o)n(ccf)n=o)c1',
#  'o=nn(ccf)c(=o)nc1ccc(nc(=o)n(ccf)n=o)cc1',
#  'coc1(c(f)(f)f)c(cl)c(cl)c(cl)c(cl)c1cl',
#  'fc(f)(f)coc1c(cl)c(cl)c(cl)c(cl)c1cl',
#  'fc1(f)c(f)(f)c(f)(f)c(f)(f)c(f)(f)c1(f)f',
#  'fc1c(cl)c(cl)c(cl)c(cl)c1br',
#  'fc1c(cl)c(cl)c(cl)c(cl)c1cl',
#  'cc12ccc(=o)c=c1ccc1c3ccc(o)(c(=o)co)c3(c)cc(o)c12f',
#  'cc12ccc(=o)c=c1c(f)cc1c2c(o)cc2(c)c1ccc2(o)c(=o)co',
#  'o=c1nc(n=cn2ccccc2)ccn1c1cc(f)c(co)o1',
#  'nc(=o)cccn=c(c1ccc(cl)cc1)c1cc(f)ccc1o',
#  'cc1cnc(-c2ccc(f)cc2)c(-c2ccc(f)cc2)n1',
#  'occn1ccn(cccc2c3ccc(f)cc3sc3ccc(c(f)(f)f)cc32)cc1',
#  'o=c(nc(=o)c1c(f)cccc1f)nc1ccc(cl)cc1',
#  'o=c(nc(=o)c1c(f)cccc1f)nc1ccc(f)cc1',
#  'o=c(nc(=o)c1c(f)cccc1f)nc1ccc(oc(f)(f)c(f)oc(f)(f)f)c(cl)c1',
#  'o=c(nc(=o)c1ccccc1cl)nc1ccc(oc(f)(f)f)cc1',
#  'o=c(nc(=o)c1c(f)cccc1f)nc1cc(cl)c(f)c(cl)c1f',
#  'o=c(nc(=o)c1c(f)cccc1f)nc1cc(cl)c(oc(f)(f)c(f)c(f)(f)f)cc1cl',
#  'o=c(nc(=o)c1c(f)cccc1f)nc1cc(cl)c(oc(f)(f)c(f)f)c(cl)c1',
#  'oc(c1ccc(f)cc1)(c1cncnc1)c1ccccc1cl',
#  'cc1(c)c=c2oc(=n)c(c#n)[c@@h](c3ccc(c(f)(f)f)cc3)c2c(=o)c1',
#  'o=c(ncc1ccc(f)cc1)c(=o)c1c[nh]c2ccccc12',
#  'o=c1nc(n=cn2ccocc2)ccn1c1cc(f)c(co)o1',
#  'cc1(o)ccc2c3ccc4cc(=o)ccc4(c)c3(f)c(o)cc21c',
#  'cc1=cc(c(f)(f)f)(c(f)(f)f)c(c#n)c(=n)n1c1ccc(c(n)=o)cc1',
#  'c#ccoc(=o)c(c)oc1ccc(oc2ncc(cl)cc2f)cc1',
#  'coc(=o)c(c)oc1ccc(oc2ncc(c(f)(f)f)cc2cl)cc1',
#  'cc(oc1ccc(oc2ccc(c(f)(f)f)cn2)cc1)c(=o)o',
#  'ccccoc(=o)c(c)oc1ccc(oc2ccc(c(f)(f)f)cn2)cc1',
#  'ccoccoc(=o)c(c)oc1ccc(oc2ncc(c(f)(f)f)cc2cl)cc1',
#  'coc1cccc(oc)c1c(=o)n=c1[nh]nc(-c2ccc(f)cc2)s1',
#  'coc(=o)c1c(c(f)f)nc(c(f)(f)f)c(c2=nccs2)c1cc(c)c',
#  'cc(c)c1nc(-c2cccnc2)c(-c2ccc(f)cc2)n1c=cc(o)cc(o)cc(=o)o[na]',
#  'fc1cccc(f)c1-c1nnc(-c2ccccc2cl)nn1',
#  'o=c1[nh]cnc2c1ncn2c1oc(co)cc1f',
#  'o=c(nn=cc1c(o)ccc2ccccc12)c1cccc(f)c1',
#  'o=c(c1ccccn1)n1c(=o)[nh]cc(f)c1=o',
#  'cc1(c)n=c(n)n=c(n)n1c1ccc(c(f)(f)f)cc1',
#  'cc1(c)n=c(n)n=c(n)n1c1ccc(f)cc1',
#  'o=[n+]([o-])c1ccc(oc2ccc(c(f)(f)f)cc2cl)cc1oc1ccoc1',
#  'oc(cn1ccnc1)(c1ccc(f)cc1)c1cccc(-c2ccncc2)c1',
#  'n=c1ccn(c2oc(co)cc2f)c(=o)[nh]1',
#  'n=c1ccn(c2cc(f)c(co)o2)c(=o)[nh]1',
#  'n=c1[nh]c(=o)n(c2ccc(co)o2)cc1f',
#  'n=c1[nh]c(=o)n(c2oc(co)cc2f)cc1cl',
#  'n=c1[nh]c(=o)n(c2oc(co)cc2f)cc1f',
#  'ccoc(=o)c(cl)cc1cc(-n2nc(c)n(c(f)f)c2=o)c(f)cc1cl',
#  'cc1nn(-c2cc(ns(c)(=o)=o)c(cl)cc2cl)c(=o)n1c(f)f',
#  'ccc1ccccc1n=c1[nh]c(csc2nnc(-c3ccc(oc(f)f)cc3)n2n)nc(=n)[nh]1',
#  'o=c(ncc1ccccn1)c1cc(occ(f)(f)f)ccc1occ(f)(f)f',
#  'ccc1cc2c3cc=c4cc(=o)ccc4c3ccc2(c)c1c(=o)cf',
#  'cc1(o)ccc2c3cc=c4cc(=o)ccc4(c)c3(f)c(o)cc21c',
#  'oc(cn1cccc1)(c1ccc(f)cc1)c1ccc(-c2ccncc2)cc1',
#  'cc(c)c(c(=o)oc(c#n)c1cccc(oc2ccccc2)c1)c1ccc(oc(f)f)cc1',
#  'coc1c(o)cc2ccc(=nc(=o)c(f)(f)f)c3c(c2c1oc)ccc(sc)c(=o)c3',
#  'o=p(occ(f)(f)f)(occ(f)(f)f)n1ccocc1',
#  'occn1ccn(c2cc(c3ccc(f)cc3)c3ccc(c(f)(f)f)cc32)cc1',
#  'coc(=o)c1cc(sc2ccc(c(f)(f)f)cc2cl)ccc1[n+](=o)[o-]',
#  'o=c1c(f)=c(n2cc2)c(=o)c(n2cc2)=c1n1cc1',
#  'coc1ccc2c(c1)o[c@](o)(c(f)(f)f)cc2=o',
#  'o=c1[nh]c(=o)n(cc2ccccc2)cc1f',
#  'cc1ccc(cn2cc(f)c(=o)[nh]c2=o)cc1',
#  'coc1ccc(cn2cc(f)c(=o)[nh]c2=o)cc1',
#  'o=c1[nh]c(=o)n(cc2ccc(cl)cc2)cc1f',
#  'nn1c(coc2ccccc2)nnc1sc(f)f',
#  'o=c1[nh]c2c(o)ccc(ccnccs(=o)(=o)cccoccc3ccc(f)cc3)c2s1',
#  'o=c(nc(co)c(o)c1ccc(-c2ccccn2)cc1)c(f)(f)f',
#  'ccoc(=o)c1cn(c(c)(c)c)c(o)c1nc1ccc(oc(=o)nc2ccc(oc(f)(f)f)cc2)cc1',
#  'o=c(nc(=o)c1c(f)cccc1f)nc1ccc(cl)c(oc2ncc(c(f)(f)f)cc2cl)c1',
#  'occn1ccn(ccc=c2c3ccccc3sc3ccc(c(f)(f)f)cc32)cc1',
#  'o=c(c1ccc(f)cc1)c1cc1',
#  'cs(=o)c1nc(-c2ccccc2)cc(c(f)(f)f)n1',
#  'n#cccn(n)c1nc2cc(c(f)(f)f)ccc2o1',
#  'coc1ccccc1n1ccn(cccc(=o)c2ccc(f)cc2)cc1',
#  'fc1ccc(c(c2ccc(f)cc2)n2ccn(cc=cc3ccccc3)cc2)cc1',
#  'o=c(nc1ccccc1c(f)(f)f)nc1ccccc1',
#  'n#ccsc1nc2ccccc2c(=o)n1-c1ccc(oc(f)f)cc1',
#  'cc1cc(c(f)(f)f)n2nc(-c3nnc(-c4cccc(c(f)(f)f)c4)o3)cc2n1',
#  'coc1ccc(-c2nnc(scc(=o)c3c(n)n(c)c(=o)n(c)c3=o)n2-c2cccc(c(f)(f)f)c2)cc1',
#  'coc1ccc([c@@h]2c(c(=o)n3cccccc3)c3ccccc3c(=o)n2cc2ccc(f)cc2)cc1',
#  'o=c(np(=o)(n1cc1)n1cc1)c1ccc(f)cc1',
#  'coc1ccc(s(n)(=o)=o)cc1c(=o)ncc1cccn1cc1ccc(f)cc1',
#  'occoccn1ccn(cccn2c3ccccc3sc3ccc(c(f)(f)f)cc32)cc1',
#  'fc(f)oc1ccc(nc(=s)nc[c@@h]2ccco2)cc1cl',
#  'cn=c1[nh]c(c)nc2c1ncn2c1oc(co)cc1f',
#  'n=c1[nh]c(f)nc2c1ncn2c1oc(co)c(o)c1o',
#  'cc1nc2c(=n)[nh]cnc2n1c1oc(co)cc1f',
#  'n=c1[nh]cnc2c1nc(f)n2c1ccc(co)o1',
#  'cn=c1[nh]cnc2c1ncn2c1oc(co)cc1f',
#  'n=c1[nh]cnc2c1ncn2c1cc(f)c(co)o1',
#  'n=c1[nh]cnc2c1ncn2c1oc(co)cc1f',
#  'ccn1c(scc2nc3c4cnn(c)c4ncn3n2)nnc1-c1cc(c(f)(f)f)n(c)n1',
#  'cc(c)c(o)(c1ccc(oc(f)(f)f)cc1)c1cncnc1',
#  'o=c1cc[nh]c2cc(c(f)(f)f)ccc12',
#  'nc(=o)c1cn(cc(=o)nc2c(cl)cccc2cl)ccn1cccc(c1ccc(f)cc1)c1ccc(f)cc1',
#  'cc1cccc(c)c1nc(=o)cn1ccn(cccc(c2ccc(f)cc2)c2ccc(f)cc2)cc1',
#  'coc1ccccc1n1ccn(cccc(o)c2ccc(f)cc2)cc1',
#  'coc1ccccc1n1ccn(ccccc2ccc(f)cc2)cc1',
#  'c#cc1(o)c(f)cc2c3ccc4cc(o)ccc4c3ccc21c',
#  'coc1cc2(c)c(o)c(f)cc2c2ccc3cc(o)ccc3c12',
#  'c#cc1(o)c(f)cc2c3ccc4cc(o)ccc4c3c(cc)cc21c',
#  'c#cc1(o)c(f)cc2c3ccc4cc(o)ccc4c3c(oc)cc21c',
#  'ccoc(=o)c1c(c)[nh]c(c)c1c(=o)coc(=o)c1ccc(f)c(s(=o)(=o)n2ccocc2)c1',
#  'o=c1cc(c2ccc(c(f)(f)f)cc2)cc2c1c(=o)c1cc(cl)ccc1n2o',
#  'oc(cn1ccnc1)(c1ccc(-c2cccnc2)cc1)c1ccc(f)cc1f',
#  'o=c(coc(=o)c1cccc(n2c(=o)c3ccccc3c2=o)c1)c1ccc(f)cc1',
#  'cc(c)(c)c(coc1ccc(f)cc1)oc(=s)n1ccnc1',
#  'o=c(ocn1c(=o)[nh]cc(f)c1=o)oc1ccccc1',
#  'cn=c1[nh]c(sc(f)f)nc(=nc(c)(c)c)[nh]1',
#  'cn=c1[nh]c(sc(f)f)nc(=nc(c)c)[nh]1',
#  'cn=c1nc(sc(f)f)[nh]c(=nc)[nh]1',
#  'cc(c)n=c1[nh]c(sc(f)f)nc(=nc(c)(c)c)[nh]1',
#  'cc(c)n=c1nc(sc(f)f)[nh]c(=nc(c)c)[nh]1',
#  'ccn=c1[nh]c(sc(f)f)nc(=nc(c)(c)c)[nh]1',
#  'ccn=c1[nh]c(sc(f)f)nc(=nc(c)c)[nh]1',
#  'ccn=c1[nh]c(sc(f)f)nc(=nc)[nh]1',
#  'ccn=c1[nh]c(sc(f)f)nc(=ncc(c)c)[nh]1',
#  'ccn=c1nc(sc(f)f)[nh]c(=ncc)[nh]1',
#  'ccccn=c1[nh]c(sc(f)f)nc(=nc(c)c)[nh]1',
#  'ccccn=c1[nh]c(sc(f)f)nc(=nc)[nh]1',
#  'ccccn=c1[nh]c(sc(f)f)nc(=ncc)[nh]1',
#  'cccn=c1[nh]c(sc(f)f)nc(=nc(c)c)[nh]1',
#  'cccn=c1[nh]c(sc(f)f)nc(=nc)[nh]1',
#  'cccn=c1[nh]c(sc(f)f)nc(=ncc)[nh]1',
#  'cccccn=c1[nh]c(sc(f)f)nc(=nc(c)c)[nh]1',
#  'cccccn=c1[nh]c(sc(f)f)nc(=nc)[nh]1',
#  'cccccn=c1[nh]c(sc(f)f)nc(=ncc)[nh]1',
#  'cc1cc2c3cc=c4cc(=o)c=cc4(c)c3(f)c(o)cc2(c)c1(o)c(=o)nc1ccccc1',
#  'cc(c(=o)o)c1ccc(-c2nc(c(f)(f)f)cs2)cc1',
#  'cc(c(=o)o)c1ccc(-c2nccs2)c(c(f)(f)f)c1',
#  'cc(c(=o)o)c1ccc(-c2nccs2)c(f)c1',
#  'ccccc1csc(-c2ccc(c(c)c(=o)o)cc2f)n1',
#  'cc1cnc(-c2ccc(c(c)c(=o)o)cc2f)s1',
#  'cc1csc(-c2ccc(c(c)c(=o)o)cc2f)n1',
#  'cc(c)c1csc(-c2ccc(c(c)c(=o)o)cc2f)n1',
#  'ccc1cnc(-c2ccc(c(c)c(=o)o)cc2f)s1',
#  'cc1nc(-c2ccc(c(c)c(=o)o)cc2f)sc1c',
#  'ccc1csc(-c2ccc(c(c)c(=o)o)cc2f)n1',
#  'ccc1nc(-c2ccc(c(c)c(=o)o)cc2f)sc1c',
#  'ccoc1ccc(c2(c(=o)oc)cc(f)(f)c2(f)f)cc1',
#  'o=c(nc(=o)c1c(f)cccc1f)nc1cc(cl)c(oc2ncc(c(f)(f)f)cc2cl)c(cl)c1',
#  'coc1cc2ccc(=nc(=o)c(f)(f)f)c3c(c2c(oc)c1oc)ccc(=o)c(o)c3',
#  'cc12ccc(=o)c=c1ccc1c3ccc4(ccc(=o)o4)c3(c)cc(o)c12f',
#  'o=c1nc(=o)c2(ccoc3ccc(f)cc32)n1',
#  'o=c1c(nc(o)c2ccc(cl)cc2)cc2c(o)cccc2n1ccn=c1[nh]cc(c(f)(f)f)cc1cl',
#  'cc1(c)oc[c@h](coc2c(f)c(n3ccocc3)nc(f)c2cl)o1',
#  'ccn1c(scc2ccccc2f)nc2sc(c)c(c)c2c1=o',
#  'fc1cncc(cl)n1',
#  'fc1cncc(f)n1',
#  'fc1cnccn1',
#  'c[c@@h](nc(=o)c1ccn(c(=o)c2ccc(f)cc2)cc1)c1ccccc1',
#  'o=c1[nh]c2ccccc2n1c1ccn(cccc(c2ccc(f)cc2)c2ccc(f)cc2)cc1',
#  'o=c1[nh]c2cc(cl)ccc2n1c1ccn(cccc(c2ccc(f)cc2)c2ccc(f)cc2)cc1',
#  'o=s1(=o)n=c(c(f)(f)f)nc2cc(cl)ccc21',
#  'o=c(o)ccc1=ns(=o)(=o)c2ccc(c(f)(f)f)cc2n1',
#  'o=c(o)cccc1=ns(=o)(=o)c2ccc(c(f)(f)f)cc2n1',
#  'cc1=ns(=o)(=o)c2cc(c(f)(f)f)ccc2n1',
#  'o=c(o)ccsc1=ns(=o)(=o)c2ccc(c(f)(f)f)cc2n1',
#  'cc1=ns(=o)(=o)c2cc(f)ccc2n1',
#  'cc1=ns(=o)(=o)c2ccc(c(f)(f)f)cc2n1',
#  'o=c(o)csc1=ns(=o)(=o)c2ccc(c(f)(f)f)cc2n1',
#  'cccc(=o)ocn1cc(f)c(=o)[nh]c1=o',
#  'o=c1[nh]cc(c(f)(f)f)c(=o)[nh]1',
#  'cccc(=o)n1c(=o)[nh]cc(f)c1=o',
#  'o=c1[nh]cc(f)c(=o)[nh]1',
#  'coc(=o)n1cc(f)c(=o)[nh]c1=o',
#  'cnc(=o)n1cc(f)c(=o)[nh]c1=o',
#  'o=c(occcl)n1cc(f)c(=o)[nh]c1=o',
#  'ccc(=o)n1c(=o)[nh]cc(f)c1=o',
#  'ccccnc(=o)n1cc(f)c(=o)[nh]c1=o',
#  'ccoc(=o)ocn1c(=o)[nh]cc(f)c1=o',
#  'ccoc(=o)ocn1cc(f)c(=o)[nh]c1=o',
#  'ccccoc(=o)n1cc(f)c(=o)[nh]c1=o',
#  'ccoc(=o)n1c(=o)[nh]cc(f)c1=o',
#  'cc(c)coc(=o)n1cc(f)c(=o)[nh]c1=o',
#  'ccoc(=o)n1cc(f)c(=o)[nh]c1=o',
#  'cc(=o)n1c(=o)[nh]cc(f)c1=o',
#  'ccccccccnc(=o)n1cc(f)c(=o)[nh]c1=o',
#  'ccnc(=o)n1cc(f)c(=o)[nh]c1=o',
#  'cc(c)oc(=o)n1cc(f)c(=o)[nh]c1=o',
#  'ccccccnc(=o)n1cc(f)c(=o)[nh]c1=o',
#  'cn(c)c(=o)n1cc(f)c(=o)[nh]c1=o',
#  'ccccccoc(=o)n1cc(f)c(=o)[nh]c1=o',
#  'cc1[nh]c(=o)[nh]c(=o)c1n(ccf)cccl',
#  'o=c1c2ccccc2c(=o)n1c1ccccc1c(f)(f)f',
#  'o=c1c2ccccc2c(=o)n1c1ccccc1s(=o)c(f)(f)f',
#  'o=c1c(cl)=c(cl)c(=o)n1c1ccc(f)cc1',
#  'n#cc1nc2c(s(=o)(=o)c3ccccc3)c(n)n(cc3ccc(f)cc3)c2nc1c#n',
#  'o=c(cn1cc(c(=o)c(f)(f)f)c2cc(br)ccc21)n1cccccc1',
#  'cc1[nh]n(-c2ccccc2)c(=nc2ccc(c(f)(f)f)cc2)c1[n+](=o)[o-]',
#  'cccn(cc1cc1)c1c([n+](=o)[o-])cc(c(f)(f)f)cc1[n+](=o)[o-]',
#  'c[c@h]1ccc2[nh]c(=nc(=o)c3ccc(f)c(f)c3)sc2c1',
#  'cc1cc(c)c(nc(=o)csc2nnc(-c3ccc(oc(f)f)cc3)n2n)c(c)c1',
#  'coc1ccc(oc2c(c(f)(f)f)oc3cc(oc(=o)n4ccocc4)ccc3c2=o)cc1',
#  'o=c(nc1ccc(f)cc1f)c1cccnc1oc1cccc(c(f)(f)f)c1',
#  'cn1c([n+](=o)[o-])cnc1-c1ccc(f)cc1',
#  'o=[n+]([o-])c1cnc(-c2ccc(f)cc2)n1cco',
#  'cc1=c(cc(=o)o)c2cc(f)ccc2c1=cc1ccc(s(c)=o)cc1',
#  'cc(n1ccnc1)c(o)(c1ccc(f)cc1)c1ccc(f)cc1',
#  'oc(cn1ccnc1)(c1ccc(f)cc1)c1ccc(br)cc1',
#  'oc(cn1ccnc1)(c1ccc(f)cc1)c1ccc(f)cc1',
#  'oc(cn1ccnc1)(c1cccc(br)c1)c1ccc(f)cc1f',
#  'cc(c)n(c=nc1ccn(c2cc(f)c(co)o2)c(=o)n1)c(c)c',
#  'cn(c)c=nc1ccn(c2cc(f)c(co)o2)c(=o)n1',
#  'cccn(c=nc1ccn(c2cc(f)c(co)o2)c(=o)n1)ccc',
#  'ccn(c=nc1ccn(c2cc(f)c(co)o2)c(=o)n1)cc',
#  'o=c(cc1ccccc1)nc1ccc(f)cc1',
#  'o=c(cc1ccccc1)nc1cccc(c(f)(f)f)c1',
#  'o=c(cc1ccccc1)nc1cccc(f)c1',
#  'o=c(cc1ccccc1)nc1ccccc1f',
#  'cc(c)nc(=s)n1ccn(s(=o)(=o)c2cccc(c(f)(f)f)c2)cc1',
#  'ccc1coc(cn2cncn2)(c2ccc(nc(=o)c(f)(f)f)cc2)o1',
#  'nn1c(scc(=o)nc2ccccc2-c2ccccc2)nnc1-c1ccc(oc(f)f)cc1',
#  'o=c(cc(=o)c(f)(f)f)c1cccs1',
#  'cc1cc(c)n(c2=nccn2s(=o)(=o)c2cc(c(f)(f)f)cc(c(f)(f)f)c2)n1',
#  'o=c1[nh]c2c(o)ccc(ccnccc(f)(f)cccoccc3ccccc3)c2s1',
#  'coc(=o)csc1cc(n=c2sc(=o)n3n2cccc3)c(f)cc1cl',
#  'n=c1nc(c(f)(f)f)(c(f)(f)f)nc1(c(f)(f)f)c(f)(f)f',
#  'o=c1c=nc(c2ccccc2)c2cc(c(f)(f)f)ccc2n1',
#  'o=c1c=nc(c2ccccc2)c2cc(f)ccc2n1',
#  'o=c1c=nc(c2ccccc2)c2ccc(c(f)(f)f)cc2n1',
#  'o=c1c=nc(c2ccccc2c(f)(f)f)c2cc([n+](=o)[o-])ccc2n1',
#  'o=c1c=nc(c2ccccc2c(f)(f)f)c2ccccc2n1',
#  'o=c1c=nc(c2ccccc2f)c2cc(br)ccc2n1',
#  'o=c1c=nc(c2ccccc2f)c2cc(cl)c(cl)cc2n1',
#  'o=c1c=nc(c2ccccc2f)c2cc(cl)ccc2n1',
#  'o=c1c=nc(c2ccccc2f)c2cc([n+](=o)[o-])ccc2n1',
#  'o=c1c=nc(c2ccccc2f)c2ccccc2n1',
#  'o=c1c=nc(c2c(f)cccc2f)c2cc(cl)ccc2n1',
#  'o=c1c=nc(c2c(f)cccc2f)c2ccc(cl)cc2n1',
#  'o=c1c=nc(c2ccc(c(f)(f)f)cc2)c2ccccc2n1',
#  'o=c1c=nc(c2ccc(f)cc2)c2cc(cl)ccc2n1',
#  ...]

# %%
for our_smile in our_smiles:
    if our_smile.lower() in all_smiles:
        print(our_smile)
